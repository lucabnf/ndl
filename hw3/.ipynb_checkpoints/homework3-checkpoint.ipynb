# %% [markdown]
# # **Homework III** - Network Dynamics and Learning
# In this homework, you will simulate the pandemic with the goal of learning the network structure characteristics and disease dynamics parameters of the influenza H1N1 pandemic in Sweden in 2009.

# %%
import networkx as nx 
import numpy as np 
import scipy as sp
import matplotlib.pyplot as plt 
from itertools import product

# %% [markdown]
# ## **1) Preliminary parts**
# Two preliminary parts:
# - first one will involve simulating an epidemic on a given graph
# - second one will be to generate a random graph with preferential attachment
#
# ### 1.1 Epidemic on a known graph
# We are asked simulate an epidemic on a symmetric $k$-regular graph $G = (V, E)$, with $|V| = 500$ nodes and $k = 4$. We consider $\beta = 0.3$ and $\rho = 0.7$. With one week being one unit of time, simulate the epidemic for 15 weeks.As initial configuration, we start with 10 infected nodes selected at random from the node set $V$.
#
# We need to repeat this experiments $N=100$ times, considering:
# - average number of newly infected individuals each week
# - average total number of susceptible, infected, and recovered individuals at each week
#
# First of all, we need to create the $4$-regular graph $G$.

# %%
N = 500 # number of nodes
k = 4 # number of nodes connected for each node

G = nx.Graph()
sources = np.arange(N)

for i in range(1, int(k/2) + 1):
    targets = np.roll(sources, i)
    G.add_edges_from(zip(sources, targets))

# %% [markdown]
# Now we need to define the Markov chain by constructing its transition matrix Lambda, which is used to simulate the spread of the epidemic. Since we are dealing with large network ($N=500$), instead of precomputing the transition matrix $\Lambda$, we compute its rows when needed. In particular, when the process is at some configuration $x$, row $x$ of $\Lambda$ is computed and used to compute the probabilities of transitions from $x$ and to pick the next visited configuration.

# %%
# Paramters initialization 
beta = 0.3
rho= 0.7
n_steps = 100 # number of the step of the simulation
n_weeks = 15 # weeks of simulation
initial_I = 10 # initial infected people
n_states = 3 # SIR model

simulations = np.zeros([n_steps,n_weeks, N])

# Simulation loop
for i in range(n_steps):
        
    states = np.zeros([n_weeks, N])
    
    # Initial condition 
    x0 = np.zeros(N)
    
    # randomly choose 10 initial infected
    idx = np.random.choice(list(G.nodes), size=initial_I)
    for j in idx:
        x0[j] = 1
        
    # Save initial states for each node
    states[0] = x0
    
    for j in range(1,n_weeks):
        # Take last configuration
        x = np.copy( states[j-1] )        
        
        rates = np.zeros([N,n_states])
    
        for agent in range(N) :
            if x[agent] == 0:
                m=0
                for neig in dict(G.adj[agent]).keys() :
                    if x[neig] == 1:
                        m+=1
            else: 
                m=0
                
            if x[agent] == 0 :
                rates[agent] = np.array([(1-beta)**m,  1 - (1-beta)**m, 0])
    
            if x[agent] == 1 :
                rates[agent] = np.array([0,  1-rho, rho])
    
            elif x[agent] == 2:
                rates[agent] = np.array([0, 0, 1])
    
        
        # Chose the next configuration 
        next_pos = np.argmax(np.cumsum(rates,axis=1) > np.random.rand(N,1), axis=1)
        states[j] = next_pos
        
    simulations[i] = states

# %% [markdown]
# Now we need to find the average of the newly infected individuals each week

# %%
simulation_week_i = np.zeros([n_steps, n_weeks])

for i in range(simulations.shape[0]):
    
    cases_i = np.zeros(simulations[i].shape[0])
    
    for case in range(simulations[i].shape[0]):
        
        states = case
        
        if case == 0:
            cases_i[case] = int(np.argwhere(simulations[i, case] == 1).shape[0])
        else:
            cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i,case-1]<simulations[i,case]) ) ).shape[0]) 
    
    simulation_week_i[i] =  cases_i
    
avg_x_week = np.mean(simulation_week_i ,axis=0)

plt.figure(figsize = (8 ,5))
plt.plot(range(n_weeks), avg_x_week) 
plt.xlabel("weeks")
plt.ylabel("cases")
plt.grid()
plt.savefig("1-1.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Now we need to find how many individuals in total that are susceptible/infected/recovered at each week (on the average).

# %%
total_SIR = np.zeros([n_weeks, n_states])

for simulation in simulations :
    total_x_simulation = np.zeros([simulation.shape[0],n_states])
    
    for i in range(simulation.shape[0]):
        for j in range(n_states):
            total_x_simulation[i,j] = int(np.argwhere(simulation[i] == j).shape[0])
    
    total_SIR = total_SIR + total_x_simulation
    
avg_SIR = total_SIR / n_steps

plt.figure(figsize = (8 ,5))
plt.plot(range(n_weeks), avg_SIR[:,0], label = "S") 
plt.plot(range(n_weeks), avg_SIR[:,1], label = "I") 
plt.plot(range(n_weeks), avg_SIR[:,2], label = "R")
plt.xlabel("week")
plt.ylabel("cases")
plt.legend()
plt.grid()
plt.savefig("1-2.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 1.2 Generate random graph
# We are asked to generate a random graph of a large size (at least 900 nodes) with average degree $k \in Z^+$, given an initial graph $G_1 = (V_1, E_1)$ that's a complete graph with $|V_1| = k_0 = k+1$ nodes

# %%
k = 4
random_G = nx.generators.classic.complete_graph(k + 1)

for i in range(k+1, 900):
    
    w = np.array(random_G.degree)[:,1]
    prob = w / np.sum(w) 
    c = (k + (i % 2)) // 2

    idx = np.random.choice(random_G.nodes(), size=c, replace=False, p=prob)
    random_G.add_node(i)
    
    for link in range(c):
        random_G.add_edge(i, idx[link]) 

print("Average degree =",np.mean(np.array(random_G.degree)[:,1]))
# Out:
# Average degree = 4.0

# %% [markdown]
# As we can see we can change the average degreee by only changing the value of $k$.
#
# ## **2) Simulate a pandemic without vaccination**
#
# In this second exercise, we are asked to simulate once again the spread of the pandemic, as  in exercise 1.1, but this time considering the random graph generate in point 1.2.
#
# First of all, we  need to generate a random graph $G = (V, E)$ with $|V|=500$ nodes, with average degree $k = 6$.

# %%
N = 500
k = 6

random_G = nx.generators.classic.complete_graph(k + 1)

for i in range(k+1, N):
    
    w = np.array(random_G.degree)[:,1]
    prob = w / np.sum(w) 
    c = (k + (i % 2)) // 2

    idx = np.random.choice(random_G.nodes(), size=c, replace=False, p=prob)
    random_G.add_node(i)
    
    for link in range(c):
        random_G.add_edge(i, idx[link])

# %% [markdown]
# Then, we need to simulate the pandemic for 15 weeks (one week being one unit of time) on $G$, with $\beta = 0.3$ and $\rho = 0.7$, and 10 initial infected people (same identical simulation loop).

# %%
# Parameters initialization 
beta = 0.3
rho= 0.7
n_steps = 100 # number of the step of the simulation
n_weeks = 15 # weeks of simulation
initial_I = 10 # initial infected people
n_states = 3 # SIR model

simulations = np.zeros([n_steps,n_weeks, N])

# Simulation loop
for i in range(n_steps):
        
    states = np.zeros([n_weeks, N])
    
    # Initial condition 
    x0 = np.zeros(N)
    
    # randomly choose 10 initial infected
    idx = np.random.choice(list(random_G.nodes), size=initial_I)  
    for j in idx:
        x0[j] = 1
        
    # Save initial states for each node
    states[0] = x0
    
    for j in range(1,n_weeks):
        # Take last configuration
        x = np.copy( states[j-1] )        
        
        rates = np.zeros([N,n_states])
    
        for agent in range(N) :
            if x[agent] == 0:
                m=0
                for neig in dict(random_G.adj[agent]).keys() :
                    if x[neig] == 1:
                        m+=1
            else:
                m=0
                
            if x[agent] == 0 :
                rates[agent] = np.array([(1-beta)**m,  1 - (1-beta)**m, 0])
    
            if x[agent] == 1 :
                rates[agent] = np.array([0,  1-rho, rho])
    
            elif x[agent] == 2:
                rates[agent] = np.array([0, 0, 1])
    
        
        # Chose the next configuration 
        next_pos = np.argmax(np.cumsum(rates,axis=1) > np.random.rand(N,1), axis=1)
        states[j] = next_pos
        
    simulations[i] = states

# %% [markdown]
# Once again, as before, we are asked to find the average number of newly infected people each week.

# %%
simulation_week_i = np.zeros([n_steps, n_weeks])

for i in range(simulations.shape[0]):
    
    cases_i = np.zeros(simulations[i].shape[0])
    
    for case in range(simulations[i].shape[0]):
                
        if case == 0:
            cases_i[case] = int(np.argwhere(simulations[i, case] == 1).shape[0])
        
        else:
            cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i,case-1]<simulations[i,case]) ) ).shape[0]) 
    
    simulation_week_i[i] =  cases_i
    
avg_x_week = np.mean(simulation_week_i ,axis=0)

plt.figure(figsize = (8,5))
plt.plot(range(n_weeks), avg_x_week) 
plt.xlabel("weeks")
plt.ylabel("cases")
plt.grid()
plt.savefig("2-1.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# And again, how many individuals in total that are susceptible/infected/recovered at each week (on the average).

# %%
total_SIR = np.zeros([n_weeks, n_states])

for simulation in simulations :
    total_x_simulation = np.zeros([simulation.shape[0],n_states])
    
    for i in range(simulation.shape[0]):
        for j in range(n_states):
            total_x_simulation[i,j] = int(np.argwhere(simulation[i] == j).shape[0])
    
    total_SIR = total_SIR + total_x_simulation
    
avg_SIR = total_SIR / n_steps

plt.figure(figsize = (8 ,5))
plt.plot(range(n_weeks), avg_SIR[:,0], label = "S") 
plt.plot(range(n_weeks), avg_SIR[:,1], label = "I") 
plt.plot(range(n_weeks), avg_SIR[:,2], label = "R")
plt.xlabel("week")
plt.ylabel("cases")
plt.legend()
plt.grid()
plt.savefig("2-2.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **3) Simulate a pandemic with vaccination**
#
# In this third exercise, we are asked to simulate the pandemic as before, but now taking into account vaccination effect: in particular, during each week, some parts of the population will receive vaccination (once a person is vaccinated it cannot be infected). We assume that, regardless of the state of an individual prior to the vaccination, once vaccinated the individual will not be able to become infected nor infect any other individuals.
#
# Once again, we need to generate a random graph $G = (V, E)$ with $|V| = 500$ nodes, average degree $k=6$.

# %%
N = 500
k = 6

random_G = nx.generators.classic.complete_graph(k + 1)

for i in range(k+1, N):
    
    w = np.array(random_G.degree)[:,1]
    prob = w / np.sum(w) 
    c = (k + (i % 2)) // 2

    idx = np.random.choice(random_G.nodes(), size=c, replace=False, p=prob)
    random_G.add_node(i)
    
    for link in range(c):
        random_G.add_edge(i, idx[link])

# %% [markdown]
# We need to simulation the pandemic for 15 weeks (one week being one unit of time) on $G$, with $\beta = 0.3$ and $\rho = 0.7$, and 10 initial infected people. However, this time we need to use the following vaccination scheme:
# \begin{equation}
#     \text{Vacc}(t) = [0,5,15,25,35,45,55,60,60,60,60,60,60,60,60]
# \end{equation}

# %%
# Paramters initialization 
beta = 0.3
rho= 0.7
n_steps = 100 # number of the step of the simulation
n_weeks = 15 # weeks of simulation
initial_I = 10 # initial infected people
n_states = 4 # SIR + Vaccinated model
vax_scheme = [0,5,15,25,35,45,55,60,60,60,60,60,60,60,60]

simulations = np.zeros([n_steps, n_weeks, N])

# Simulation loop considering vaccination
for i in range(n_steps):
    # ------------- INITIALIZATION PHASE -------------
    states = np.zeros([n_weeks, N])

    # Initial condition 
    x0 = np.zeros(N)
    
    # randomly choose 10 initial infected
    idx = np.random.choice(list(random_G.nodes), size=initial_I)
    for j in idx:
        x0[j] = 1
        
    # Save initial states for each node
    states[0] = x0
    
    for j in range(1,n_weeks):
        # ------------- VACCINATION PHASE -------------
        # vaccinated during this week
        vax_in_this_week = vax_scheme[j] - vax_scheme[j-1]
            
        # find the first eligible to be vaccinated
        states_of_week = np.copy(states[j-1])
        first_sir = np.where(states_of_week < 3)[0]
        
        # people that are to be vaccinated in this week (rounded to the nearest integer)
        total_to_be_vax = round((N*vax_in_this_week)/100)
        idx_to_be_vax = np.random.choice(first_sir, size=total_to_be_vax, replace=False)
        
        # define the new state (that considers vaccinated people)
        for idx in idx_to_be_vax:
            states_of_week[idx] = 3
        
        # consider the new state with the vaccinated in this week 
        x = np.copy(states_of_week)        
        
        # ------------- PANDEMIC SIMULATION PHASE -------------
        rates = np.zeros([N, n_states])
    
        for agent in range(N) :
            if x[agent] == 0:
                m=0
                for neig in dict(random_G.adj[agent]).keys() :
                    if x[neig] == 1:
                        m+=1
            else:
                m = 0
        
            if x[agent] == 0:
                rates[agent] = np.array([(1-beta)**m,  1 - (1-beta)**m, 0, 0])
    
            elif x[agent] == 1 :
                rates[agent] = np.array([0,  1-rho, rho, 0])
    
            elif x[agent] == 2:
                rates[agent] = np.array([0, 0, 1, 0])
                
            elif x[agent] == 3:
                rates[agent] = np.array([0, 0, 0, 1])
            
        
        # Chose the next configuration 
        next_pos = np.argmax(np.cumsum(rates,axis=1) > np.random.rand(N,1), axis=1)
        states[j] = next_pos
        
    simulations[i] = states

# %% [markdown]
# In this case, we are asked to find and plot the average number of newly infected and newly vaccinated individuals for each week.

# %%
simulation_week_i = np.zeros([n_steps, n_weeks])
simulation_week_v = np.zeros([n_steps, n_weeks])

for i in range(simulations.shape[0]):
    
    cases_i = np.zeros(simulations[i].shape[0])
    cases_v = np.zeros(simulations[i].shape[0])
    
    for case in range(simulations[i].shape[0]):
                
        if case == 0:
            cases_i[case] = int(np.argwhere(simulations[i, case] == 1).shape[0])
            cases_v[case] = int(np.argwhere(simulations[i, case] == 3).shape[0])
            
        else:
            cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i,case-1]<simulations[i,case]))).shape[0])
            cases_v[case] = int(np.argwhere(((simulations[i, case]==3) & (simulations[i,case-1]<simulations[i,case]))).shape[0])
            
    
    simulation_week_i[i] =  cases_i
    simulation_week_v[i] =  cases_v
    
avg_x_week_i = np.mean(simulation_week_i ,axis=0)
avg_x_week_v = np.mean(simulation_week_v ,axis=0)

plt.figure(figsize = (8,5))
plt.plot(range(n_weeks), avg_x_week_i, label = "I") 
plt.plot(range(n_weeks), avg_x_week_v, label = "V") 
plt.xlabel("weeks")
plt.ylabel("cases")
plt.legend()
plt.grid()
plt.savefig("3-1.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# And finally, the average total number of susceptible, infected, recovered and vaccinated individuals at each week.

# %%
total_SIR = np.zeros([n_weeks, n_states])

for simulation in simulations :
    total_x_simulation = np.zeros([simulation.shape[0],n_states])
    
    for i in range(simulation.shape[0]):
        for j in range(n_states):
            total_x_simulation[i,j] = int(np.argwhere(simulation[i] == j).shape[0])
    
    total_SIR = total_SIR + total_x_simulation
    
avg_SIR = total_SIR / n_steps

plt.figure(figsize = (8 ,5))
plt.plot(range(n_weeks), avg_SIR[:,0], label = "S") 
plt.plot(range(n_weeks), avg_SIR[:,1], label = "I") 
plt.plot(range(n_weeks), avg_SIR[:,2], label = "R")
plt.plot(range(n_weeks), avg_SIR[:,3], label = "V")
plt.xlabel("week")
plt.ylabel("cases")
plt.legend()
plt.grid()
plt.savefig("3-2.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **4) The H1N1 pandemic in Sweden 2009**
# In this fourth exercise, we exploit all the previous parts in order to estimate the social structure of the Swedish population and the disease-spread parameters during the H1N1 pandemic. We will simulate the pandemic between week 42, 2009 and week 5, 2010. During these weeks, the fraction of population that had received vaccination was:
# \begin{equation}
# \text{Vacc}(t) = [5, 9, 16, 24, 32, 40, 47, 54, 59, 60, 60, 60, 60, 60, 60, 60]
# \end{equation}
# To reduce simulation time, we will scale down the population of Sweden to $n = |V| = 934$. For the scaled version, the number of newly infected individuals each week in the period between week 42, 2009 and week 5, 2010 was:
# \begin{equation}
# I_0(t) = [1, 1, 3, 5, 9, 17, 32, 32, 17, 5, 2, 1, 0, 0, 0, 0]
# \end{equation}
# The following algorithm will do a gradient-based search over the parameter space of $k$, $\beta$, and $\rho$ in order to find the set of parameters that best matches the real pandemic.
#
# Since this algorithm requires, for each set of paramters ($k, \beta, \rho$), multiple repetitive and redundant steps, we define some function in order to lighten the pipeline.
#
# ### 1) Function to generate a random graph
# We firstly define a function to generate a random graph using the preferential attachment.

# %%
def generate_random_graph(k, n):
    
    np.random.seed(0)    
    random_G = nx.generators.classic.complete_graph(k + 1)

    for i in range(k+1, n):
    
        w = np.array(random_G.degree)[:,1]
        prob = w / np.sum(w) 
        c = (k + (i % 2)) // 2

        idx = np.random.choice(random_G.nodes(), size=c, replace=False, p=prob)
        random_G.add_node(i)
    
        for link in range(c):
            random_G.add_edge(i, idx[link]) 

    return random_G

# %% [markdown]
# ### 2) Function to simulate the pandemic
# We then define a function to simulate the pandemic, using the method aleready developed in section 3 ("Simulate pandemic with vaccination").

# %%
def simulate_pandemic(random_G, beta, rho, n_steps, n_weeks, initial_I, n_states, vax_scheme):
    
    N = len(random_G)
    simulations = np.zeros([n_steps, n_weeks, N])

    # Simulation loop considering vaccination
    for i in range(n_steps):
        # ------------- INITIALIZATION PHASE -------------
        states = np.zeros([n_weeks, N])
        # Initial condition 
        x0 = np.zeros([N])
        # randomly choose "initial_I" infected
        idx = np.random.choice(list(random_G.nodes), size=initial_I)
        for j in idx:
            x0[j] = 1
           
        # ------------- FIRST ROUND OF VACCINATION -------------
        # In this case we have 5% already at step 0       
        first_sir = np.where(x0 < 3 )[0]
        total_to_be_vax = round((N*vax_scheme[0])/100)
        idx_to_be_vax = np.random.choice(first_sir, size=total_to_be_vax, replace=False)

        # define the new state (that considers vaccinated people)
        for idx in idx_to_be_vax:
            x0[idx] = 3
    
        # Save initial states for each node
        states[0] = x0
        
        for j in range(1,n_weeks):
            # ------------- FURTHER VACCINATION PHASESCannot take a larger sample than population when 'replace=False' -------------
            # vaccinated during this week
            vax_in_this_week = vax_scheme[j] - vax_scheme[j-1]

            # find the first eligble to be vaccinated
            states_current_week = np.copy(states[j-1])
            first_sir = np.where(states_current_week < 3)[0]

            # people that are to be vaccinated in this week (rounded to the nearest integer)
            total_to_be_vax = round((N*vax_in_this_week)/100)
            idx_to_be_vax = np.random.choice(first_sir, size=total_to_be_vax, replace=False)

            # define the new state (that considers vaccinated people)
            for idx in idx_to_be_vax:
                states_current_week[idx] = 3

            # consider the new state with the vaccinated in this week 
            x = np.copy(states_current_week)        
            
            # ------------- PANDEMIC SIMULATION PHASE -------------
            rates = np.zeros([N, n_states])

            for agent in range(N) :
                if x[agent] == 0:
                    m=0
                    for neig in dict(random_G.adj[agent]).keys():
                        if x[neig] == 1:
                            m+=1
                else:
                    m = 0

                if x[agent] == 0:
                    rates[agent] = np.array([(1-beta)**m,  1 - (1-beta)**m, 0, 0])

                elif x[agent] == 1 :
                    rates[agent] = np.array([0,  1-rho, rho, 0])

                elif x[agent] == 2:
                    rates[agent] = np.array([0, 0, 1, 0])

                elif x[agent] == 3:
                    rates[agent] = np.array([0, 0, 0, 1])


            # Chose the next configuration 
            next_pos = np.argmax(np.cumsum(rates,axis=1) > np.random.rand(N,1), axis=1)
            states[j] = next_pos

        simulations[i] = states
    
    return simulations

# %% [markdown]
# ## 3) Function to search best configuration of $(k, \beta, \rho)$
# Finally, we can define the function that will exploit the previous ones to carry out the algorithm for the search of the best configuration of the parameter. Basically, the algorithm, starting from an initial guess for the parameters $(k_0, \beta_0, \rho_0)$, follows these steps:
# 1. for each set of parameter $(k, \beta, \rho)$ in the parameter-space:
#     - gnerate a random graph, using the `generate_random_graph()` function;
#     - simulate the pandemic, with the `simulate_pandemic()` function;
#     - compute the root-mean-square error (RMSE) as:
#     \begin{equation}
#     \text{RMSE} = \sqrt{\frac{1}{15}\sum_{t=1}^{15}(I(t)-I_0(t))^2}
#     \end{equation}
#     where $I(t)$ is the average number of newly infected individuals each week in the simulation and $I_0(t)$ is the true value of newly infected individuals each week.
# 2. Update $k_0 , \beta_0, \rho_0$ to the set of parameters yielding the lowest RMSE. We stop when these do not improve from the previous step.

# %%
def search_algorithm(pandemic, params):
    
    # Neighborhood generation
    k = [params["k"]-params["delta_k"], params["k"], params["k"]+params["delta_k"]]
    beta = [params["beta"]-params["delta_beta"], params["beta"], params["beta"]+params["delta_beta"]]
    rho= [params["rho"]-params["delta_rho"], params["rho"], params["rho"]+params["delta_rho"]]
        
    combinations = list(product(k, beta, rho))    
    results = []
    
    # Neighborhood loop 
    for combination in combinations:
        
        # Graph Generation
        G = generate_random_graph(combination[0], pandemic["N"])
        
        # Pandemic simulation
        simulations = simulate_pandemic(G, combination[1], combination[2],pandemic["n_steps"], 
                                        pandemic["n_weeks"], pandemic["I0"][0],
                                        pandemic["n_states"], pandemic["vax_scheme"])
        
        # Compute the average number of newly infected individuals each week      
        simulation_week_i = np.zeros([pandemic["n_steps"], pandemic["n_weeks"]])

        for i in range(simulations.shape[0]):

            cases_i = np.zeros(simulations[i].shape[0])

            for case in range(simulations[i].shape[0]):

                if case == 0:
                    cases_i[case] = int(np.argwhere(simulations[i,case] == 1).shape[0])

                else:
                    cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i, case-1]<simulations[i,case]))).shape[0]) 

            simulation_week_i[i] =  cases_i

        avg_x_week = np.mean(simulation_week_i, axis=0)
        
        # Compute RMSE 
        rmse = np.sqrt((np.sum((avg_x_week[1:] - pandemic["I0"][1:])**2))/15)
        results.append(rmse)
        
        print("(k, beta, rho) = ({:.3f}, {:.3f}, {:.3f}) with rmse:{:.3f}".format(combination[0], combination[1], combination[2], rmse))

    # Chose the parameters that minimize the RMSE
    results = np.array(results)
    best_index = np.argmin(results)
    best_combination = combinations[best_index]
    
    return best_combination[0], best_combination[1], best_combination[2], results[best_index]

# %% [markdown]
# Now that we have defined the different functions, we can exploit the algorithm to estimate the average degree $k$ and the disease-spread parameters $\beta$ and $\rho$ for the pandemic.
#
# First of all, we define the parameters for our simulation.

# %%
# Parameters for the pandemic spread
pandemic = {
    "I0": [1, 1, 3, 5, 9, 17, 32, 32, 17, 5, 2, 1, 0, 0, 0, 0],
    "N": 934,
    "vax_scheme": [5, 9, 16, 24, 32, 40, 47, 54, 59, 60, 60, 60, 60, 60, 60, 60], 
    "n_steps": 10,
    "n_weeks": 16,
    "n_states": 4
}
# Parameters to search
params = {
    "k": 10, "beta": 0.3, "rho": 0.6, 
    "delta_k": 1, "delta_beta": 0.1, "delta_rho": 0.1,
}

# %% [markdown]
# And now we can start of search loop

# %%
best_parameters = [params["k"], params["beta"], params["rho"]]

lowest_rmse = np.inf

# Loop of deltas reduction search
while True : 
    last_rmse = np.inf
    
    k, beta, rho = best_parameters[0],  best_parameters[1],  best_parameters[2]
    
    # Loop of around search
    while True  :
        params["k"], params["beta"], params["rho"], current_rmse = search_algorithm(pandemic, params)
    
        print("(k, beta, rho)=({:.3f}, {:.3f}, {:.3f}) with rmse:{:.3f}".format(k, beta, rho, current_rmse))
    
        # If no better solution find go on
        if np.round(current_rmse, 2) >= np.round(last_rmse, 2):
            break
    
        last_rmse = current_rmse
        local_best_parameters = [params["k"], params["beta"],params["rho"]]
        
    # If no better solution found halve the deltasa
    if np.round(current_rmse, 2) >= np.round(lowest_rmse, 2):
        break
    
    params["delta_k"] = round(params["delta_k"]/2)
    params["delta_beta"] = params["delta_beta"]/2
    params["delta_rho"]= params["delta_rho"]/2
    
    print("Deltas updated!")
    
    lowest_rmse = last_rmse
    global_best_parameters = local_best_parameters
    
print("BEST (k, beta, rho)={:.3f} with rmse: {:.3f}]".format(global_best_parameters[0], global_best_parameters[1], global_best_parameters[2], lowest_rmse))
# Out:
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.200, 0.700) with rmse:6.138
# (k, beta, rho) = (9.000, 0.300, 0.500) with rmse:18.171
# (k, beta, rho) = (9.000, 0.300, 0.600) with rmse:16.572
# (k, beta, rho) = (9.000, 0.300, 0.700) with rmse:16.156
# (k, beta, rho) = (9.000, 0.400, 0.500) with rmse:43.054
# (k, beta, rho) = (9.000, 0.400, 0.600) with rmse:41.749
# (k, beta, rho) = (9.000, 0.400, 0.700) with rmse:40.974
# (k, beta, rho) = (10.000, 0.200, 0.500) with rmse:8.523
# (k, beta, rho) = (10.000, 0.200, 0.600) with rmse:8.650
# (k, beta, rho) = (10.000, 0.200, 0.700) with rmse:9.024
# (k, beta, rho) = (10.000, 0.300, 0.500) with rmse:24.936
# (k, beta, rho) = (10.000, 0.300, 0.600) with rmse:24.178
# (k, beta, rho) = (10.000, 0.300, 0.700) with rmse:23.473
# (k, beta, rho) = (10.000, 0.400, 0.500) with rmse:34.711
# (k, beta, rho) = (10.000, 0.400, 0.600) with rmse:34.126
# (k, beta, rho) = (10.000, 0.400, 0.700) with rmse:33.470
# (k, beta, rho) = (11.000, 0.200, 0.500) with rmse:11.471
# (k, beta, rho) = (11.000, 0.200, 0.600) with rmse:10.270
# (k, beta, rho) = (11.000, 0.200, 0.700) with rmse:9.094
# (k, beta, rho) = (11.000, 0.300, 0.500) with rmse:34.022
# (k, beta, rho) = (11.000, 0.300, 0.600) with rmse:32.972
# (k, beta, rho) = (11.000, 0.300, 0.700) with rmse:31.676
# (k, beta, rho) = (11.000, 0.400, 0.500) with rmse:68.014
# (k, beta, rho) = (11.000, 0.400, 0.600) with rmse:67.295
# (k, beta, rho) = (11.000, 0.400, 0.700) with rmse:66.524
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:5.022
# (k, beta, rho) = (8.000, 0.100, 0.400) with rmse:12.110
# (k, beta, rho) = (8.000, 0.100, 0.500) with rmse:12.560
# (k, beta, rho) = (8.000, 0.100, 0.600) with rmse:12.609
# (k, beta, rho) = (8.000, 0.200, 0.400) with rmse:8.818
# (k, beta, rho) = (8.000, 0.200, 0.500) with rmse:8.479
# (k, beta, rho) = (8.000, 0.200, 0.600) with rmse:8.276
# (k, beta, rho) = (8.000, 0.300, 0.400) with rmse:27.389
# (k, beta, rho) = (8.000, 0.300, 0.500) with rmse:25.553
# (k, beta, rho) = (8.000, 0.300, 0.600) with rmse:23.848
# (k, beta, rho) = (9.000, 0.100, 0.400) with rmse:12.690
# (k, beta, rho) = (9.000, 0.100, 0.500) with rmse:13.099
# (k, beta, rho) = (9.000, 0.100, 0.600) with rmse:13.434
# (k, beta, rho) = (9.000, 0.200, 0.400) with rmse:5.817
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.300, 0.400) with rmse:22.605
# (k, beta, rho) = (9.000, 0.300, 0.500) with rmse:18.171
# (k, beta, rho) = (9.000, 0.300, 0.600) with rmse:16.572
# (k, beta, rho) = (10.000, 0.100, 0.400) with rmse:11.818
# (k, beta, rho) = (10.000, 0.100, 0.500) with rmse:11.956
# (k, beta, rho) = (10.000, 0.100, 0.600) with rmse:12.222
# (k, beta, rho) = (10.000, 0.200, 0.400) with rmse:8.414
# (k, beta, rho) = (10.000, 0.200, 0.500) with rmse:8.523
# (k, beta, rho) = (10.000, 0.200, 0.600) with rmse:8.650
# (k, beta, rho) = (10.000, 0.300, 0.400) with rmse:26.118
# (k, beta, rho) = (10.000, 0.300, 0.500) with rmse:24.936
# (k, beta, rho) = (10.000, 0.300, 0.600) with rmse:24.178
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:5.022
# I'm here, internal loop
# Deltas updated!
# (k, beta, rho) = (9.000, 0.150, 0.450) with rmse:11.979
# (k, beta, rho) = (9.000, 0.150, 0.500) with rmse:12.062
# (k, beta, rho) = (9.000, 0.150, 0.550) with rmse:12.095
# (k, beta, rho) = (9.000, 0.200, 0.450) with rmse:5.634
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.250, 0.450) with rmse:9.084
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.150, 0.450) with rmse:11.979
# (k, beta, rho) = (9.000, 0.150, 0.500) with rmse:12.062
# (k, beta, rho) = (9.000, 0.150, 0.550) with rmse:12.095
# (k, beta, rho) = (9.000, 0.200, 0.450) with rmse:5.634
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.250, 0.450) with rmse:9.084
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.150, 0.450) with rmse:11.979
# (k, beta, rho) = (9.000, 0.150, 0.500) with rmse:12.062
# (k, beta, rho) = (9.000, 0.150, 0.550) with rmse:12.095
# (k, beta, rho) = (9.000, 0.200, 0.450) with rmse:5.634
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.250, 0.450) with rmse:9.084
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:4.897
# (k, beta, rho) = (9.000, 0.150, 0.500) with rmse:12.062
# (k, beta, rho) = (9.000, 0.150, 0.550) with rmse:12.095
# (k, beta, rho) = (9.000, 0.150, 0.600) with rmse:12.114
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.600) with rmse:6.102
# (k, beta, rho) = (9.000, 0.150, 0.500) with rmse:12.062
# (k, beta, rho) = (9.000, 0.150, 0.550) with rmse:12.095
# (k, beta, rho) = (9.000, 0.150, 0.600) with rmse:12.114
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.600) with rmse:6.102
# (k, beta, rho) = (9.000, 0.150, 0.500) with rmse:12.062
# (k, beta, rho) = (9.000, 0.150, 0.550) with rmse:12.095
# (k, beta, rho) = (9.000, 0.150, 0.600) with rmse:12.114
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.600) with rmse:6.102
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:4.897
# I'm here, internal loop
# Deltas updated!
# (k, beta, rho) = (9.000, 0.175, 0.525) with rmse:9.441
# (k, beta, rho) = (9.000, 0.175, 0.550) with rmse:9.861
# (k, beta, rho) = (9.000, 0.175, 0.575) with rmse:9.864
# (k, beta, rho) = (9.000, 0.200, 0.525) with rmse:5.003
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.575) with rmse:5.744
# (k, beta, rho) = (9.000, 0.225, 0.525) with rmse:4.415
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.575) with rmse:4.413
# (k, beta, rho) = (9.000, 0.175, 0.525) with rmse:9.441
# (k, beta, rho) = (9.000, 0.175, 0.550) with rmse:9.861
# (k, beta, rho) = (9.000, 0.175, 0.575) with rmse:9.864
# (k, beta, rho) = (9.000, 0.200, 0.525) with rmse:5.003
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.575) with rmse:5.744
# (k, beta, rho) = (9.000, 0.225, 0.525) with rmse:4.415
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.575) with rmse:4.413
# (k, beta, rho) = (9.000, 0.175, 0.525) with rmse:9.441
# (k, beta, rho) = (9.000, 0.175, 0.550) with rmse:9.861
# (k, beta, rho) = (9.000, 0.175, 0.575) with rmse:9.864
# (k, beta, rho) = (9.000, 0.200, 0.525) with rmse:5.003
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.575) with rmse:5.744
# (k, beta, rho) = (9.000, 0.225, 0.525) with rmse:4.415
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.575) with rmse:4.413
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:4.362
# (k, beta, rho) = (9.000, 0.200, 0.525) with rmse:5.003
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.575) with rmse:5.744
# (k, beta, rho) = (9.000, 0.225, 0.525) with rmse:4.415
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.575) with rmse:4.413
# (k, beta, rho) = (9.000, 0.250, 0.525) with rmse:7.067
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.575) with rmse:6.127
# (k, beta, rho) = (9.000, 0.200, 0.525) with rmse:5.003
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.575) with rmse:5.744
# (k, beta, rho) = (9.000, 0.225, 0.525) with rmse:4.415
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.575) with rmse:4.413
# (k, beta, rho) = (9.000, 0.250, 0.525) with rmse:7.067
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.575) with rmse:6.127
# (k, beta, rho) = (9.000, 0.200, 0.525) with rmse:5.003
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.575) with rmse:5.744
# (k, beta, rho) = (9.000, 0.225, 0.525) with rmse:4.415
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.575) with rmse:4.413
# (k, beta, rho) = (9.000, 0.250, 0.525) with rmse:7.067
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.575) with rmse:6.127
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:4.362
# I'm here, internal loop
# Deltas updated!
# (k, beta, rho) = (9.000, 0.212, 0.538) with rmse:4.110
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.225, 0.538) with rmse:4.371
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.562) with rmse:4.413
# (k, beta, rho) = (9.000, 0.237, 0.538) with rmse:4.776
# (k, beta, rho) = (9.000, 0.237, 0.550) with rmse:4.746
# (k, beta, rho) = (9.000, 0.237, 0.562) with rmse:4.779
# (k, beta, rho) = (9.000, 0.212, 0.538) with rmse:4.110
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.225, 0.538) with rmse:4.371
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.562) with rmse:4.413
# (k, beta, rho) = (9.000, 0.237, 0.538) with rmse:4.776
# (k, beta, rho) = (9.000, 0.237, 0.550) with rmse:4.746
# (k, beta, rho) = (9.000, 0.237, 0.562) with rmse:4.779
# (k, beta, rho) = (9.000, 0.212, 0.538) with rmse:4.110
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.225, 0.538) with rmse:4.371
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.562) with rmse:4.413
# (k, beta, rho) = (9.000, 0.237, 0.538) with rmse:4.776
# (k, beta, rho) = (9.000, 0.237, 0.550) with rmse:4.746
# (k, beta, rho) = (9.000, 0.237, 0.562) with rmse:4.779
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.958
# (k, beta, rho) = (9.000, 0.200, 0.538) with rmse:4.931
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.562) with rmse:5.676
# (k, beta, rho) = (9.000, 0.212, 0.538) with rmse:4.110
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.225, 0.538) with rmse:4.371
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.562) with rmse:4.413
# (k, beta, rho) = (9.000, 0.200, 0.538) with rmse:4.931
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.562) with rmse:5.676
# (k, beta, rho) = (9.000, 0.212, 0.538) with rmse:4.110
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.225, 0.538) with rmse:4.371
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.562) with rmse:4.413
# (k, beta, rho) = (9.000, 0.200, 0.538) with rmse:4.931
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.562) with rmse:5.676
# (k, beta, rho) = (9.000, 0.212, 0.538) with rmse:4.110
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.225, 0.538) with rmse:4.371
# (k, beta, rho) = (9.000, 0.225, 0.550) with rmse:4.362
# (k, beta, rho) = (9.000, 0.225, 0.562) with rmse:4.413
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.958
# I'm here, internal loop
# Deltas updated!
# (k, beta, rho) = (9.000, 0.206, 0.544) with rmse:4.021
# (k, beta, rho) = (9.000, 0.206, 0.550) with rmse:4.011
# (k, beta, rho) = (9.000, 0.206, 0.556) with rmse:4.027
# (k, beta, rho) = (9.000, 0.212, 0.544) with rmse:3.966
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.219, 0.544) with rmse:4.184
# (k, beta, rho) = (9.000, 0.219, 0.550) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.206, 0.544) with rmse:4.021
# (k, beta, rho) = (9.000, 0.206, 0.550) with rmse:4.011
# (k, beta, rho) = (9.000, 0.206, 0.556) with rmse:4.027
# (k, beta, rho) = (9.000, 0.212, 0.544) with rmse:3.966
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.219, 0.544) with rmse:4.184
# (k, beta, rho) = (9.000, 0.219, 0.550) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.206, 0.544) with rmse:4.021
# (k, beta, rho) = (9.000, 0.206, 0.550) with rmse:4.011
# (k, beta, rho) = (9.000, 0.206, 0.556) with rmse:4.027
# (k, beta, rho) = (9.000, 0.212, 0.544) with rmse:3.966
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.219, 0.544) with rmse:4.184
# (k, beta, rho) = (9.000, 0.219, 0.550) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.915
# (k, beta, rho) = (9.000, 0.206, 0.550) with rmse:4.011
# (k, beta, rho) = (9.000, 0.206, 0.556) with rmse:4.027
# (k, beta, rho) = (9.000, 0.206, 0.562) with rmse:4.484
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.219, 0.550) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.219, 0.562) with rmse:4.375
# (k, beta, rho) = (9.000, 0.206, 0.550) with rmse:4.011
# (k, beta, rho) = (9.000, 0.206, 0.556) with rmse:4.027
# (k, beta, rho) = (9.000, 0.206, 0.562) with rmse:4.484
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.219, 0.550) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.219, 0.562) with rmse:4.375
# (k, beta, rho) = (9.000, 0.206, 0.550) with rmse:4.011
# (k, beta, rho) = (9.000, 0.206, 0.556) with rmse:4.027
# (k, beta, rho) = (9.000, 0.206, 0.562) with rmse:4.484
# (k, beta, rho) = (9.000, 0.212, 0.550) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.562) with rmse:4.238
# (k, beta, rho) = (9.000, 0.219, 0.550) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.219, 0.562) with rmse:4.375
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.915
# I'm here, internal loop
# Deltas updated!
# (k, beta, rho) = (9.000, 0.209, 0.553) with rmse:3.890
# (k, beta, rho) = (9.000, 0.209, 0.556) with rmse:3.912
# (k, beta, rho) = (9.000, 0.209, 0.559) with rmse:4.233
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.559) with rmse:4.087
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.559) with rmse:4.024
# (k, beta, rho) = (9.000, 0.209, 0.553) with rmse:3.890
# (k, beta, rho) = (9.000, 0.209, 0.556) with rmse:3.912
# (k, beta, rho) = (9.000, 0.209, 0.559) with rmse:4.233
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.559) with rmse:4.087
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.559) with rmse:4.024
# (k, beta, rho) = (9.000, 0.209, 0.553) with rmse:3.890
# (k, beta, rho) = (9.000, 0.209, 0.556) with rmse:3.912
# (k, beta, rho) = (9.000, 0.209, 0.559) with rmse:4.233
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.559) with rmse:4.087
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.559) with rmse:4.024
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.852
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.559) with rmse:4.087
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.559) with rmse:4.024
# (k, beta, rho) = (9.000, 0.219, 0.553) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.219, 0.559) with rmse:4.261
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.559) with rmse:4.087
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.559) with rmse:4.024
# (k, beta, rho) = (9.000, 0.219, 0.553) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.219, 0.559) with rmse:4.261
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.559) with rmse:4.087
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.559) with rmse:4.024
# (k, beta, rho) = (9.000, 0.219, 0.553) with rmse:4.174
# (k, beta, rho) = (9.000, 0.219, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.219, 0.559) with rmse:4.261
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.852
# I'm here, internal loop
# Deltas updated!
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.556) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.558) with rmse:3.865
# (k, beta, rho) = (9.000, 0.216, 0.555) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.558) with rmse:3.882
# (k, beta, rho) = (9.000, 0.217, 0.555) with rmse:4.131
# (k, beta, rho) = (9.000, 0.217, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.217, 0.558) with rmse:4.161
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.556) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.558) with rmse:3.865
# (k, beta, rho) = (9.000, 0.216, 0.555) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.558) with rmse:3.882
# (k, beta, rho) = (9.000, 0.217, 0.555) with rmse:4.131
# (k, beta, rho) = (9.000, 0.217, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.217, 0.558) with rmse:4.161
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.556) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.558) with rmse:3.865
# (k, beta, rho) = (9.000, 0.216, 0.555) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.558) with rmse:3.882
# (k, beta, rho) = (9.000, 0.217, 0.555) with rmse:4.131
# (k, beta, rho) = (9.000, 0.217, 0.556) with rmse:4.131
# (k, beta, rho) = (9.000, 0.217, 0.558) with rmse:4.161
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.834
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.555) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.214, 0.553) with rmse:3.880
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.556) with rmse:3.834
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.555) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.555) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.214, 0.553) with rmse:3.880
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.556) with rmse:3.834
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.555) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho) = (9.000, 0.212, 0.553) with rmse:3.958
# (k, beta, rho) = (9.000, 0.212, 0.555) with rmse:3.915
# (k, beta, rho) = (9.000, 0.212, 0.556) with rmse:3.915
# (k, beta, rho) = (9.000, 0.214, 0.553) with rmse:3.880
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.556) with rmse:3.834
# (k, beta, rho) = (9.000, 0.216, 0.553) with rmse:3.902
# (k, beta, rho) = (9.000, 0.216, 0.555) with rmse:3.852
# (k, beta, rho) = (9.000, 0.216, 0.556) with rmse:3.852
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.834
# I'm here, internal loop
# Deltas updated!
# (k, beta, rho) = (9.000, 0.213, 0.554) with rmse:3.952
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.214, 0.554) with rmse:3.865
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.215, 0.554) with rmse:3.896
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.213, 0.554) with rmse:3.952
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.214, 0.554) with rmse:3.865
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.215, 0.554) with rmse:3.896
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.213, 0.554) with rmse:3.952
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.214, 0.554) with rmse:3.865
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.215, 0.554) with rmse:3.896
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.834
# (k, beta, rho) = (9.000, 0.213, 0.554) with rmse:3.952
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.214, 0.554) with rmse:3.865
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.215, 0.554) with rmse:3.896
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.213, 0.554) with rmse:3.952
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.214, 0.554) with rmse:3.865
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.215, 0.554) with rmse:3.896
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.213, 0.554) with rmse:3.952
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.213, 0.555) with rmse:3.924
# (k, beta, rho) = (9.000, 0.214, 0.554) with rmse:3.865
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.214, 0.555) with rmse:3.834
# (k, beta, rho) = (9.000, 0.215, 0.554) with rmse:3.896
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho) = (9.000, 0.215, 0.555) with rmse:3.867
# (k, beta, rho)=(10.000, 0.300, 0.600) with rmse:3.834
# I'm here, internal loop
# I'm here, external loop
# BEST (k, beta, rho)=9.000 with rmse: 0.214]

# %% [markdown]
# Now that the simulation has found the best configuration of $(k, \beta, \rho)$, we can run the best simulation of the H1N1 pandemic in Sweden 2009. Specifically:
# 1. initialize our best configuration of parameters;
# 2. generate a new random graph with the best k we found;
# 3. simulate our pandemic once again, for 15 weeks, considering 100 iterations to have more stable results.

# %%
# 1) Best paramters (k, beta, rho)
best_k_beta_rho = [9, 0.21406249999999996, 0.5546875]
#best_k_beta_rho = global_best_parameters
print("Our best parameters (k, beta, rho)=", best_k_beta_rho)

# 2) Generate a new random graph with the new k 
random_G = generate_random_graph(best_k_beta_rho[0], pandemic["N"])

# 3) Our best simulation
# Increase number of steps to have more stable results
pandemic["n_steps"] = 100

# Simulation loop
simulations = simulate_pandemic(random_G, best_k_beta_rho[1], best_k_beta_rho[2], 
                                pandemic["n_steps"], pandemic["n_weeks"],
                                pandemic["I0"][0], pandemic["n_states"], pandemic["vax_scheme"])
# Out:
# Our best parameters (k, beta, rho)= [9, 0.21406249999999996, 0.5546875]

# %% [markdown]
# Now that we have run this simulation, we can plot the average number of newly infected individuals each week according to the model (with your best parameters) compared to the true value of newly infected individuals each week.

# %%
simulation_week_i = np.zeros([pandemic["n_steps"], pandemic["n_weeks"]])

for i in range(simulations.shape[0]):
    
    cases_i = np.zeros(simulations[i].shape[0])
    
    for case in range(simulations[i].shape[0]):
                
        if case == 0:
            cases_i[case] = int(np.argwhere(simulations[i, case] == 1).shape[0])
        
        else:
            cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i,case-1]<simulations[i,case]) ) ).shape[0]) 
    
    simulation_week_i[i] =  cases_i
    
avg_x_week = np.mean(simulation_week_i ,axis=0)

plt.figure(figsize = (8 ,5))
plt.plot(range(pandemic["n_weeks"]), avg_x_week, label="predicted") 
plt.plot(range(pandemic["n_weeks"]), pandemic["I0"], label = "actual") 
plt.xlabel("week")
plt.ylabel("cases")
plt.grid()
weeks_plot = [x for x in range(42, 53)] + [x for x in range(1,6)]
plt.xticks(range(pandemic["n_weeks"]), weeks_plot)
plt.legend()
plt.savefig("4-1.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# And finally we can, once again, plot the average total number of susceptible, infected, recovered and vaccinated individuals at each week for the H1N1 pandemic simulation.

# %%
total_SIR = np.zeros([pandemic["n_weeks"], pandemic["n_states"]])

for simulation in simulations :
    total_x_simulation = np.zeros([simulation.shape[0],pandemic["n_states"]])
    
    for i in range(simulation.shape[0]):
        for j in range(pandemic["n_states"]):
            total_x_simulation[i,j] = int(np.argwhere(simulation[i] == j).shape[0])
    
    total_SIR = total_SIR + total_x_simulation
    
avg_SIR = total_SIR / pandemic["n_steps"]

plt.figure(figsize = (8 ,5))
plt.plot(range(pandemic["n_weeks"]), avg_SIR[:,0], label = "S") 
plt.plot(range(pandemic["n_weeks"]), avg_SIR[:,1], label = "I") 
plt.plot(range(pandemic["n_weeks"]), avg_SIR[:,2], label = "R")
plt.plot(range(pandemic["n_weeks"]), avg_SIR[:,3], label = "V")
plt.xlabel("week")
plt.ylabel("cases")
weeks_plot = [x for x in range(42, 53)] + [x for x in range(1,6)]
plt.xticks(range(pandemic["n_weeks"]), weeks_plot)
plt.legend()
plt.grid()
plt.savefig("4-2.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## **5) Challenge**
# In this last exercise we try to find a better random graph (i.e. one that does not use preferential attachment) to represent the network for the pandemic. We will try to also find a better algorithm to estimate the parameters with respect to the one proposed in Exercise 4.
#
# ### 5.1) A better algorithm for the search
# First of all, we will try to exploit the tabu search to employ a better algorithm to find our best parameters to estimate our pandemic.

# %%
def neighbors(temp_sol):
    # Neighborhood generation
    k = temp_sol[0]
    k_n = [k-1, k-2, k, k+1, k+2]
    
    beta = temp_sol[1]
    beta_n = [  np.round(beta,3),
                np.round(beta-0.01,3), np.round(beta+ 0.01,3),
                np.round(beta-0.05,3), np.round(beta+ 0.05,3),
                np.round(beta-0.1, 3),  np.round(beta+ 0.1, 3),
             ]
    
    rho = temp_sol[2]
    rho_n = [   np.round(rho,3), 
               np.round(rho-0.01,3), np.round(rho+ 0.01,3),
               np.round(rho-0.05,3), np.round(rho+ 0.05,3),
               np.round(rho-0.1, 3),  np.round(rho+ 0.1, 3)
           ]
    
    combinations = list(product(k_n, beta_n, rho_n))   
    combinations.remove((k, np.round(beta,3), np.round(rho,3)))
    
    return combinations

# %%
def tabu_search_algorithm(combinations, pandemic, graph_type):
     
    results = []
    
    # Neighborhood loop 
    for combination in combinations:
        
        if combination[0]<= 1 : 
            continue

        if combination[1] <= 0 or combination[1] >= 1 :
            continue
            
        if combination[2] <= 0 or combination[2] >= 1 :
            continue
        
        # Graph Generation
        if graph_type == "pam":
            G = generate_random_graph(combination[0], pandemic["N"])
        elif graph_type == "sw" :
            G = nx.newman_watts_strogatz_graph(pandemic["N"], combination[0], p=0.5, seed=100)
        
        
        # Pandemic simulation
        simulations = simulate_pandemic(G, combination[1], combination[2],pandemic["n_steps"], 
                                        pandemic["n_weeks"], pandemic["I0"][0],
                                        pandemic["n_states"], pandemic["vax_scheme"])
        
        # Compute the average number of newly infected individuals each week      
        simulation_week_i = np.zeros([pandemic["n_steps"], pandemic["n_weeks"]])

        for i in range(simulations.shape[0]):

            cases_i = np.zeros(simulations[i].shape[0])

            for case in range(simulations[i].shape[0]):

                if case == 0:
                    cases_i[case] = int(np.argwhere(simulations[i,case] == 1).shape[0])

                else:
                    cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i, case-1]<simulations[i,case]))).shape[0]) 

            simulation_week_i[i] =  cases_i

        avg_x_week = np.mean(simulation_week_i, axis=0)
        
        # Compute RMSE 
        rmse = np.sqrt((np.sum((avg_x_week[1:] - pandemic["I0"][1:])**2))/15)
        results.append(rmse)
        
        print("(k, beta, rho) = ({:.3f}, {:.3f}, {:.3f}) with rmse:{:.3f}".format(combination[0], combination[1], combination[2], rmse))

    # Chose the parameters that minimize the RMSE
    results = np.array(results)
    best_index = np.argmin(results)
    best_combination = combinations[best_index]
    sorted_index = np.argsort(results)
    
    return [best_combination[0], best_combination[1], best_combination[2]], results[best_index], sorted_index

# %% [markdown]
# Now that we have defined these alternative functions, we can exploit the algorithm to estimate the average degree $k$ and the disease-spread parameters $\beta$ and $\rho$ for the pandemic.
#
# First of all, we define the new parameters for our simulation.

# %%
# Parameters for the pandemic spread
pandemic = {
    "I0": [1, 1, 3, 5, 9, 17, 32, 32, 17, 5, 2, 1, 0, 0, 0, 0],
    "N": 934,
    "vax_scheme": [5, 9, 16, 24, 32, 40, 47, 54, 59, 60, 60, 60, 60, 60, 60, 60], 
    "n_steps": 10,
    "n_weeks": 16,
    "n_states": 4
}
# Parameters to search
params = {
    "k0": 10, "beta0": 0.3, "rho0": 0.6, 
    "delta_k": 1, "delta_beta": 0.1, "delta_rho": 0.1,
}

# %% [markdown]
# And now we can start of search loop

# %%
initial_combination = [[params["k0"], params["beta0"], params["rho0"]]]
temp_sol, temp_rmse, _ = tabu_search_algorithm(initial_combination, pandemic, "pam")
best_sol, best_rmse = temp_sol, temp_rmse 

tabu_list = []
n_iter = 0
print("Starting...")

# Loop of deltas reduction search
while n_iter < 15: 
    print("iteration {}...".format(n_iter))
    
    # If the taboo list legth is equal to the maximum one remove the first element
    if len(tabu_list) == 50 :
        tabu_list.pop(0)
        
    # Generate the neighborhood
    list_neighbors = neighbors(temp_sol)
    
    # Evalute the neighborhood and get the best one with a list of indexes sorted by the RMSE
    temp_sol, temp_rmse, sorted_index = tabu_search_algorithm(list_neighbors,  pandemic, "pam")
    
    # If a better solution is found update
    if temp_rmse < best_rmse: 
        best_sol, best_rmse = temp_sol, temp_rmse 
        print("NEW BEST (k, beta, rho)={} with rmse = {:.3f}]".format(best_sol, best_rmse))
    
    # if no better solution is found prepare a taboo move
    else :
        
        # take a new solution if is note in taboo list 
        for i_s in sorted_index:
            temp_sol = list_neighbors[i_s]
            
            if temp_sol not in tabu_list:
                break
                
        # update the taboo list
        print("I'm moving...")
        tabu_list.append(temp_sol)
        print("(k, beta, rho)=({}, {}, {}) tabu".format(temp_sol[0], temp_sol[1], temp_sol[2]))
        
    n_iter += 1
# Out:
# (k, beta, rho) = (10.000, 0.300, 0.600) with rmse:24.178
# Starting...
# iteration 0...
# (k, beta, rho) = (9.000, 0.300, 0.600) with rmse:16.572
# (k, beta, rho) = (9.000, 0.300, 0.590) with rmse:16.670
# (k, beta, rho) = (9.000, 0.300, 0.610) with rmse:16.543
# (k, beta, rho) = (9.000, 0.300, 0.550) with rmse:17.558
# (k, beta, rho) = (9.000, 0.300, 0.650) with rmse:16.254
# (k, beta, rho) = (9.000, 0.300, 0.500) with rmse:18.171
# (k, beta, rho) = (9.000, 0.300, 0.700) with rmse:16.156
# (k, beta, rho) = (9.000, 0.290, 0.600) with rmse:13.375
# (k, beta, rho) = (9.000, 0.290, 0.590) with rmse:13.452
# (k, beta, rho) = (9.000, 0.290, 0.610) with rmse:13.361
# (k, beta, rho) = (9.000, 0.290, 0.550) with rmse:14.024
# (k, beta, rho) = (9.000, 0.290, 0.650) with rmse:13.093
# (k, beta, rho) = (9.000, 0.290, 0.500) with rmse:14.487
# (k, beta, rho) = (9.000, 0.290, 0.700) with rmse:13.092
# (k, beta, rho) = (9.000, 0.310, 0.600) with rmse:18.061
# (k, beta, rho) = (9.000, 0.310, 0.590) with rmse:18.151
# (k, beta, rho) = (9.000, 0.310, 0.610) with rmse:18.042
# (k, beta, rho) = (9.000, 0.310, 0.550) with rmse:19.030
# (k, beta, rho) = (9.000, 0.310, 0.650) with rmse:17.684
# (k, beta, rho) = (9.000, 0.310, 0.500) with rmse:19.608
# (k, beta, rho) = (9.000, 0.310, 0.700) with rmse:17.577
# (k, beta, rho) = (9.000, 0.250, 0.600) with rmse:6.102
# (k, beta, rho) = (9.000, 0.250, 0.590) with rmse:6.128
# (k, beta, rho) = (9.000, 0.250, 0.610) with rmse:6.088
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.650) with rmse:5.954
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.700) with rmse:6.058
# (k, beta, rho) = (9.000, 0.350, 0.600) with rmse:23.365
# (k, beta, rho) = (9.000, 0.350, 0.590) with rmse:23.421
# (k, beta, rho) = (9.000, 0.350, 0.610) with rmse:23.315
# (k, beta, rho) = (9.000, 0.350, 0.550) with rmse:24.112
# (k, beta, rho) = (9.000, 0.350, 0.650) with rmse:22.818
# (k, beta, rho) = (9.000, 0.350, 0.500) with rmse:24.647
# (k, beta, rho) = (9.000, 0.350, 0.700) with rmse:22.697
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.200, 0.590) with rmse:5.723
# (k, beta, rho) = (9.000, 0.200, 0.610) with rmse:5.723
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.650) with rmse:5.790
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.700) with rmse:6.138
# (k, beta, rho) = (9.000, 0.400, 0.600) with rmse:41.749
# (k, beta, rho) = (9.000, 0.400, 0.590) with rmse:41.891
# (k, beta, rho) = (9.000, 0.400, 0.610) with rmse:41.751
# (k, beta, rho) = (9.000, 0.400, 0.550) with rmse:42.329
# (k, beta, rho) = (9.000, 0.400, 0.650) with rmse:41.200
# (k, beta, rho) = (9.000, 0.400, 0.500) with rmse:43.054
# (k, beta, rho) = (9.000, 0.400, 0.700) with rmse:40.974
# (k, beta, rho) = (8.000, 0.300, 0.600) with rmse:23.848
# (k, beta, rho) = (8.000, 0.300, 0.590) with rmse:23.923
# (k, beta, rho) = (8.000, 0.300, 0.610) with rmse:23.797
# (k, beta, rho) = (8.000, 0.300, 0.550) with rmse:24.270
# (k, beta, rho) = (8.000, 0.300, 0.650) with rmse:22.677
# (k, beta, rho) = (8.000, 0.300, 0.500) with rmse:25.553
# (k, beta, rho) = (8.000, 0.300, 0.700) with rmse:21.183
# (k, beta, rho) = (8.000, 0.290, 0.600) with rmse:21.847
# (k, beta, rho) = (8.000, 0.290, 0.590) with rmse:21.930
# (k, beta, rho) = (8.000, 0.290, 0.610) with rmse:21.832
# (k, beta, rho) = (8.000, 0.290, 0.550) with rmse:22.232
# (k, beta, rho) = (8.000, 0.290, 0.650) with rmse:20.749
# (k, beta, rho) = (8.000, 0.290, 0.500) with rmse:23.575
# (k, beta, rho) = (8.000, 0.290, 0.700) with rmse:19.391
# (k, beta, rho) = (8.000, 0.310, 0.600) with rmse:26.213
# (k, beta, rho) = (8.000, 0.310, 0.590) with rmse:26.300
# (k, beta, rho) = (8.000, 0.310, 0.610) with rmse:26.194
# (k, beta, rho) = (8.000, 0.310, 0.550) with rmse:26.648
# (k, beta, rho) = (8.000, 0.310, 0.650) with rmse:25.385
# (k, beta, rho) = (8.000, 0.310, 0.500) with rmse:27.931
# (k, beta, rho) = (8.000, 0.310, 0.700) with rmse:23.925
# (k, beta, rho) = (8.000, 0.250, 0.600) with rmse:15.264
# (k, beta, rho) = (8.000, 0.250, 0.590) with rmse:15.345
# (k, beta, rho) = (8.000, 0.250, 0.610) with rmse:15.244
# (k, beta, rho) = (8.000, 0.250, 0.550) with rmse:15.770
# (k, beta, rho) = (8.000, 0.250, 0.650) with rmse:14.457
# (k, beta, rho) = (8.000, 0.250, 0.500) with rmse:16.188
# (k, beta, rho) = (8.000, 0.250, 0.700) with rmse:13.365
# (k, beta, rho) = (8.000, 0.350, 0.600) with rmse:36.006
# (k, beta, rho) = (8.000, 0.350, 0.590) with rmse:36.080
# (k, beta, rho) = (8.000, 0.350, 0.610) with rmse:35.983
# (k, beta, rho) = (8.000, 0.350, 0.550) with rmse:36.274
# (k, beta, rho) = (8.000, 0.350, 0.650) with rmse:35.206
# (k, beta, rho) = (8.000, 0.350, 0.500) with rmse:37.351
# (k, beta, rho) = (8.000, 0.350, 0.700) with rmse:33.659
# (k, beta, rho) = (8.000, 0.200, 0.600) with rmse:8.276
# (k, beta, rho) = (8.000, 0.200, 0.590) with rmse:8.285
# (k, beta, rho) = (8.000, 0.200, 0.610) with rmse:8.265
# (k, beta, rho) = (8.000, 0.200, 0.550) with rmse:8.391
# (k, beta, rho) = (8.000, 0.200, 0.650) with rmse:7.992
# (k, beta, rho) = (8.000, 0.200, 0.500) with rmse:8.479
# (k, beta, rho) = (8.000, 0.200, 0.700) with rmse:8.785
# (k, beta, rho) = (8.000, 0.400, 0.600) with rmse:43.418
# (k, beta, rho) = (8.000, 0.400, 0.590) with rmse:43.447
# (k, beta, rho) = (8.000, 0.400, 0.610) with rmse:43.391
# (k, beta, rho) = (8.000, 0.400, 0.550) with rmse:43.702
# (k, beta, rho) = (8.000, 0.400, 0.650) with rmse:42.690
# (k, beta, rho) = (8.000, 0.400, 0.500) with rmse:44.815
# (k, beta, rho) = (8.000, 0.400, 0.700) with rmse:41.008
# (k, beta, rho) = (10.000, 0.300, 0.590) with rmse:24.197
# (k, beta, rho) = (10.000, 0.300, 0.610) with rmse:24.093
# (k, beta, rho) = (10.000, 0.300, 0.550) with rmse:24.514
# (k, beta, rho) = (10.000, 0.300, 0.650) with rmse:23.638
# (k, beta, rho) = (10.000, 0.300, 0.500) with rmse:24.936
# (k, beta, rho) = (10.000, 0.300, 0.700) with rmse:23.473
# (k, beta, rho) = (10.000, 0.290, 0.600) with rmse:22.426
# (k, beta, rho) = (10.000, 0.290, 0.590) with rmse:22.439
# (k, beta, rho) = (10.000, 0.290, 0.610) with rmse:22.351
# (k, beta, rho) = (10.000, 0.290, 0.550) with rmse:22.745
# (k, beta, rho) = (10.000, 0.290, 0.650) with rmse:21.601
# (k, beta, rho) = (10.000, 0.290, 0.500) with rmse:23.178
# (k, beta, rho) = (10.000, 0.290, 0.700) with rmse:21.449
# (k, beta, rho) = (10.000, 0.310, 0.600) with rmse:25.760
# (k, beta, rho) = (10.000, 0.310, 0.590) with rmse:25.773
# (k, beta, rho) = (10.000, 0.310, 0.610) with rmse:25.688
# (k, beta, rho) = (10.000, 0.310, 0.550) with rmse:26.028
# (k, beta, rho) = (10.000, 0.310, 0.650) with rmse:25.177
# (k, beta, rho) = (10.000, 0.310, 0.500) with rmse:26.437
# (k, beta, rho) = (10.000, 0.310, 0.700) with rmse:24.993
# (k, beta, rho) = (10.000, 0.250, 0.600) with rmse:15.867
# (k, beta, rho) = (10.000, 0.250, 0.590) with rmse:15.899
# (k, beta, rho) = (10.000, 0.250, 0.610) with rmse:15.835
# (k, beta, rho) = (10.000, 0.250, 0.550) with rmse:16.079
# (k, beta, rho) = (10.000, 0.250, 0.650) with rmse:15.583
# (k, beta, rho) = (10.000, 0.250, 0.500) with rmse:16.479
# (k, beta, rho) = (10.000, 0.250, 0.700) with rmse:15.562
# (k, beta, rho) = (10.000, 0.350, 0.600) with rmse:30.465
# (k, beta, rho) = (10.000, 0.350, 0.590) with rmse:30.469
# (k, beta, rho) = (10.000, 0.350, 0.610) with rmse:30.404
# (k, beta, rho) = (10.000, 0.350, 0.550) with rmse:30.758
# (k, beta, rho) = (10.000, 0.350, 0.650) with rmse:29.939
# (k, beta, rho) = (10.000, 0.350, 0.500) with rmse:31.204
# (k, beta, rho) = (10.000, 0.350, 0.700) with rmse:29.757
# (k, beta, rho) = (10.000, 0.200, 0.600) with rmse:8.650
# (k, beta, rho) = (10.000, 0.200, 0.590) with rmse:8.677
# (k, beta, rho) = (10.000, 0.200, 0.610) with rmse:8.677
# (k, beta, rho) = (10.000, 0.200, 0.550) with rmse:8.559
# (k, beta, rho) = (10.000, 0.200, 0.650) with rmse:8.748
# (k, beta, rho) = (10.000, 0.200, 0.500) with rmse:8.523
# (k, beta, rho) = (10.000, 0.200, 0.700) with rmse:9.024
# (k, beta, rho) = (10.000, 0.400, 0.600) with rmse:34.126
# (k, beta, rho) = (10.000, 0.400, 0.590) with rmse:34.139
# (k, beta, rho) = (10.000, 0.400, 0.610) with rmse:34.092
# (k, beta, rho) = (10.000, 0.400, 0.550) with rmse:34.417
# (k, beta, rho) = (10.000, 0.400, 0.650) with rmse:33.756
# (k, beta, rho) = (10.000, 0.400, 0.500) with rmse:34.711
# (k, beta, rho) = (10.000, 0.400, 0.700) with rmse:33.470
# (k, beta, rho) = (11.000, 0.300, 0.600) with rmse:32.972
# (k, beta, rho) = (11.000, 0.300, 0.590) with rmse:33.188
# (k, beta, rho) = (11.000, 0.300, 0.610) with rmse:32.812
# (k, beta, rho) = (11.000, 0.300, 0.550) with rmse:33.555
# (k, beta, rho) = (11.000, 0.300, 0.650) with rmse:32.087
# (k, beta, rho) = (11.000, 0.300, 0.500) with rmse:34.022
# (k, beta, rho) = (11.000, 0.300, 0.700) with rmse:31.676
# (k, beta, rho) = (11.000, 0.290, 0.600) with rmse:31.602
# (k, beta, rho) = (11.000, 0.290, 0.590) with rmse:31.830
# (k, beta, rho) = (11.000, 0.290, 0.610) with rmse:31.413
# (k, beta, rho) = (11.000, 0.290, 0.550) with rmse:32.203
# (k, beta, rho) = (11.000, 0.290, 0.650) with rmse:30.665
# (k, beta, rho) = (11.000, 0.290, 0.500) with rmse:32.701
# (k, beta, rho) = (11.000, 0.290, 0.700) with rmse:30.269
# (k, beta, rho) = (11.000, 0.310, 0.600) with rmse:39.648
# (k, beta, rho) = (11.000, 0.310, 0.590) with rmse:39.853
# (k, beta, rho) = (11.000, 0.310, 0.610) with rmse:39.463
# (k, beta, rho) = (11.000, 0.310, 0.550) with rmse:40.188
# (k, beta, rho) = (11.000, 0.310, 0.650) with rmse:38.736
# (k, beta, rho) = (11.000, 0.310, 0.500) with rmse:40.818
# (k, beta, rho) = (11.000, 0.310, 0.700) with rmse:38.298
# (k, beta, rho) = (11.000, 0.250, 0.600) with rmse:22.004
# (k, beta, rho) = (11.000, 0.250, 0.590) with rmse:22.119
# (k, beta, rho) = (11.000, 0.250, 0.610) with rmse:21.926
# (k, beta, rho) = (11.000, 0.250, 0.550) with rmse:22.464
# (k, beta, rho) = (11.000, 0.250, 0.650) with rmse:21.222
# (k, beta, rho) = (11.000, 0.250, 0.500) with rmse:23.010
# (k, beta, rho) = (11.000, 0.250, 0.700) with rmse:20.571
# (k, beta, rho) = (11.000, 0.350, 0.600) with rmse:48.760
# (k, beta, rho) = (11.000, 0.350, 0.590) with rmse:48.897
# (k, beta, rho) = (11.000, 0.350, 0.610) with rmse:48.622
# (k, beta, rho) = (11.000, 0.350, 0.550) with rmse:49.356
# (k, beta, rho) = (11.000, 0.350, 0.650) with rmse:48.089
# (k, beta, rho) = (11.000, 0.350, 0.500) with rmse:49.824
# (k, beta, rho) = (11.000, 0.350, 0.700) with rmse:47.652
# (k, beta, rho) = (11.000, 0.200, 0.600) with rmse:10.270
# (k, beta, rho) = (11.000, 0.200, 0.590) with rmse:10.444
# (k, beta, rho) = (11.000, 0.200, 0.610) with rmse:10.188
# (k, beta, rho) = (11.000, 0.200, 0.550) with rmse:10.805
# (k, beta, rho) = (11.000, 0.200, 0.650) with rmse:9.703
# (k, beta, rho) = (11.000, 0.200, 0.500) with rmse:11.471
# (k, beta, rho) = (11.000, 0.200, 0.700) with rmse:9.094
# (k, beta, rho) = (11.000, 0.400, 0.600) with rmse:67.295
# (k, beta, rho) = (11.000, 0.400, 0.590) with rmse:67.339
# (k, beta, rho) = (11.000, 0.400, 0.610) with rmse:67.235
# (k, beta, rho) = (11.000, 0.400, 0.550) with rmse:67.733
# (k, beta, rho) = (11.000, 0.400, 0.650) with rmse:66.826
# (k, beta, rho) = (11.000, 0.400, 0.500) with rmse:68.014
# (k, beta, rho) = (11.000, 0.400, 0.700) with rmse:66.524
# (k, beta, rho) = (12.000, 0.300, 0.600) with rmse:19.892
# (k, beta, rho) = (12.000, 0.300, 0.590) with rmse:22.904
# (k, beta, rho) = (12.000, 0.300, 0.610) with rmse:18.836
# (k, beta, rho) = (12.000, 0.300, 0.550) with rmse:23.851
# (k, beta, rho) = (12.000, 0.300, 0.650) with rmse:16.036
# (k, beta, rho) = (12.000, 0.300, 0.500) with rmse:28.021
# (k, beta, rho) = (12.000, 0.300, 0.700) with rmse:15.203
# (k, beta, rho) = (12.000, 0.290, 0.600) with rmse:19.145
# (k, beta, rho) = (12.000, 0.290, 0.590) with rmse:22.179
# (k, beta, rho) = (12.000, 0.290, 0.610) with rmse:18.102
# (k, beta, rho) = (12.000, 0.290, 0.550) with rmse:23.020
# (k, beta, rho) = (12.000, 0.290, 0.650) with rmse:15.498
# (k, beta, rho) = (12.000, 0.290, 0.500) with rmse:27.019
# (k, beta, rho) = (12.000, 0.290, 0.700) with rmse:14.675
# (k, beta, rho) = (12.000, 0.310, 0.600) with rmse:22.376
# (k, beta, rho) = (12.000, 0.310, 0.590) with rmse:25.694
# (k, beta, rho) = (12.000, 0.310, 0.610) with rmse:21.026
# (k, beta, rho) = (12.000, 0.310, 0.550) with rmse:26.314
# (k, beta, rho) = (12.000, 0.310, 0.650) with rmse:17.846
# (k, beta, rho) = (12.000, 0.310, 0.500) with rmse:31.483
# (k, beta, rho) = (12.000, 0.310, 0.700) with rmse:17.433
# (k, beta, rho) = (12.000, 0.250, 0.600) with rmse:12.757
# (k, beta, rho) = (12.000, 0.250, 0.590) with rmse:15.711
# (k, beta, rho) = (12.000, 0.250, 0.610) with rmse:11.750
# (k, beta, rho) = (12.000, 0.250, 0.550) with rmse:16.307
# (k, beta, rho) = (12.000, 0.250, 0.650) with rmse:10.076
# (k, beta, rho) = (12.000, 0.250, 0.500) with rmse:21.440
# (k, beta, rho) = (12.000, 0.250, 0.700) with rmse:9.275
# (k, beta, rho) = (12.000, 0.350, 0.600) with rmse:27.291
# (k, beta, rho) = (12.000, 0.350, 0.590) with rmse:31.360
# (k, beta, rho) = (12.000, 0.350, 0.610) with rmse:27.193
# (k, beta, rho) = (12.000, 0.350, 0.550) with rmse:31.804
# (k, beta, rho) = (12.000, 0.350, 0.650) with rmse:24.415
# (k, beta, rho) = (12.000, 0.350, 0.500) with rmse:38.622
# (k, beta, rho) = (12.000, 0.350, 0.700) with rmse:24.127
# (k, beta, rho) = (12.000, 0.200, 0.600) with rmse:5.784
# (k, beta, rho) = (12.000, 0.200, 0.590) with rmse:7.782
# (k, beta, rho) = (12.000, 0.200, 0.610) with rmse:5.637
# (k, beta, rho) = (12.000, 0.200, 0.550) with rmse:8.146
# (k, beta, rho) = (12.000, 0.200, 0.650) with rmse:5.410
# (k, beta, rho) = (12.000, 0.200, 0.500) with rmse:11.371
# (k, beta, rho) = (12.000, 0.200, 0.700) with rmse:5.500
# (k, beta, rho) = (12.000, 0.400, 0.600) with rmse:44.569
# (k, beta, rho) = (12.000, 0.400, 0.590) with rmse:44.592
# (k, beta, rho) = (12.000, 0.400, 0.610) with rmse:44.464
# (k, beta, rho) = (12.000, 0.400, 0.550) with rmse:44.928
# (k, beta, rho) = (12.000, 0.400, 0.650) with rmse:42.880
# (k, beta, rho) = (12.000, 0.400, 0.500) with rmse:46.285
# (k, beta, rho) = (12.000, 0.400, 0.700) with rmse:42.712
# NEW BEST (k, beta, rho)=[9, 0.2, 0.55] with rmse: 4.897]
# iteration 1...
# (k, beta, rho) = (8.000, 0.200, 0.550) with rmse:8.391
# (k, beta, rho) = (8.000, 0.200, 0.540) with rmse:8.423
# (k, beta, rho) = (8.000, 0.200, 0.560) with rmse:8.335
# (k, beta, rho) = (8.000, 0.200, 0.500) with rmse:8.479
# (k, beta, rho) = (8.000, 0.200, 0.600) with rmse:8.276
# (k, beta, rho) = (8.000, 0.200, 0.450) with rmse:8.569
# (k, beta, rho) = (8.000, 0.200, 0.650) with rmse:7.992
# (k, beta, rho) = (8.000, 0.190, 0.550) with rmse:8.318
# (k, beta, rho) = (8.000, 0.190, 0.540) with rmse:8.322
# (k, beta, rho) = (8.000, 0.190, 0.560) with rmse:8.261
# (k, beta, rho) = (8.000, 0.190, 0.500) with rmse:8.363
# (k, beta, rho) = (8.000, 0.190, 0.600) with rmse:8.248
# (k, beta, rho) = (8.000, 0.190, 0.450) with rmse:8.428
# (k, beta, rho) = (8.000, 0.190, 0.650) with rmse:8.049
# (k, beta, rho) = (8.000, 0.210, 0.550) with rmse:8.861
# (k, beta, rho) = (8.000, 0.210, 0.540) with rmse:8.791
# (k, beta, rho) = (8.000, 0.210, 0.560) with rmse:8.775
# (k, beta, rho) = (8.000, 0.210, 0.500) with rmse:8.874
# (k, beta, rho) = (8.000, 0.210, 0.600) with rmse:8.739
# (k, beta, rho) = (8.000, 0.210, 0.450) with rmse:9.017
# (k, beta, rho) = (8.000, 0.210, 0.650) with rmse:8.255
# (k, beta, rho) = (8.000, 0.150, 0.550) with rmse:9.884
# (k, beta, rho) = (8.000, 0.150, 0.540) with rmse:9.882
# (k, beta, rho) = (8.000, 0.150, 0.560) with rmse:9.916
# (k, beta, rho) = (8.000, 0.150, 0.500) with rmse:9.677
# (k, beta, rho) = (8.000, 0.150, 0.600) with rmse:10.064
# (k, beta, rho) = (8.000, 0.150, 0.450) with rmse:9.017
# (k, beta, rho) = (8.000, 0.150, 0.650) with rmse:10.028
# (k, beta, rho) = (8.000, 0.250, 0.550) with rmse:15.770
# (k, beta, rho) = (8.000, 0.250, 0.540) with rmse:15.818
# (k, beta, rho) = (8.000, 0.250, 0.560) with rmse:15.435
# (k, beta, rho) = (8.000, 0.250, 0.500) with rmse:16.188
# (k, beta, rho) = (8.000, 0.250, 0.600) with rmse:15.264
# (k, beta, rho) = (8.000, 0.250, 0.450) with rmse:17.007
# (k, beta, rho) = (8.000, 0.250, 0.650) with rmse:14.457
# (k, beta, rho) = (8.000, 0.100, 0.550) with rmse:12.579
# (k, beta, rho) = (8.000, 0.100, 0.540) with rmse:12.578
# (k, beta, rho) = (8.000, 0.100, 0.560) with rmse:12.582
# (k, beta, rho) = (8.000, 0.100, 0.500) with rmse:12.560
# (k, beta, rho) = (8.000, 0.100, 0.600) with rmse:12.609
# (k, beta, rho) = (8.000, 0.100, 0.450) with rmse:12.157
# (k, beta, rho) = (8.000, 0.100, 0.650) with rmse:12.688
# (k, beta, rho) = (8.000, 0.300, 0.550) with rmse:24.270
# (k, beta, rho) = (8.000, 0.300, 0.540) with rmse:24.347
# (k, beta, rho) = (8.000, 0.300, 0.560) with rmse:24.032
# (k, beta, rho) = (8.000, 0.300, 0.500) with rmse:25.553
# (k, beta, rho) = (8.000, 0.300, 0.600) with rmse:23.848
# (k, beta, rho) = (8.000, 0.300, 0.450) with rmse:26.678
# (k, beta, rho) = (8.000, 0.300, 0.650) with rmse:22.677
# (k, beta, rho) = (7.000, 0.200, 0.550) with rmse:12.833
# (k, beta, rho) = (7.000, 0.200, 0.540) with rmse:12.833
# (k, beta, rho) = (7.000, 0.200, 0.560) with rmse:12.837
# (k, beta, rho) = (7.000, 0.200, 0.500) with rmse:12.763
# (k, beta, rho) = (7.000, 0.200, 0.600) with rmse:12.958
# (k, beta, rho) = (7.000, 0.200, 0.450) with rmse:12.732
# (k, beta, rho) = (7.000, 0.200, 0.650) with rmse:12.967
# (k, beta, rho) = (7.000, 0.190, 0.550) with rmse:12.833
# (k, beta, rho) = (7.000, 0.190, 0.540) with rmse:12.833
# (k, beta, rho) = (7.000, 0.190, 0.560) with rmse:12.837
# (k, beta, rho) = (7.000, 0.190, 0.500) with rmse:12.763
# (k, beta, rho) = (7.000, 0.190, 0.600) with rmse:12.958
# (k, beta, rho) = (7.000, 0.190, 0.450) with rmse:12.732
# (k, beta, rho) = (7.000, 0.190, 0.650) with rmse:12.967
# (k, beta, rho) = (7.000, 0.210, 0.550) with rmse:12.475
# (k, beta, rho) = (7.000, 0.210, 0.540) with rmse:12.472
# (k, beta, rho) = (7.000, 0.210, 0.560) with rmse:12.478
# (k, beta, rho) = (7.000, 0.210, 0.500) with rmse:12.397
# (k, beta, rho) = (7.000, 0.210, 0.600) with rmse:12.623
# (k, beta, rho) = (7.000, 0.210, 0.450) with rmse:12.273
# (k, beta, rho) = (7.000, 0.210, 0.650) with rmse:12.682
# (k, beta, rho) = (7.000, 0.150, 0.550) with rmse:13.132
# (k, beta, rho) = (7.000, 0.150, 0.540) with rmse:13.132
# (k, beta, rho) = (7.000, 0.150, 0.560) with rmse:13.132
# (k, beta, rho) = (7.000, 0.150, 0.500) with rmse:13.105
# (k, beta, rho) = (7.000, 0.150, 0.600) with rmse:13.550
# (k, beta, rho) = (7.000, 0.150, 0.450) with rmse:13.105
# (k, beta, rho) = (7.000, 0.150, 0.650) with rmse:13.550
# (k, beta, rho) = (7.000, 0.250, 0.550) with rmse:9.835
# (k, beta, rho) = (7.000, 0.250, 0.540) with rmse:9.782
# (k, beta, rho) = (7.000, 0.250, 0.560) with rmse:10.286
# (k, beta, rho) = (7.000, 0.250, 0.500) with rmse:9.721
# (k, beta, rho) = (7.000, 0.250, 0.600) with rmse:10.941
# (k, beta, rho) = (7.000, 0.250, 0.450) with rmse:9.484
# (k, beta, rho) = (7.000, 0.250, 0.650) with rmse:11.690
# (k, beta, rho) = (7.000, 0.100, 0.550) with rmse:13.249
# (k, beta, rho) = (7.000, 0.100, 0.540) with rmse:13.249
# (k, beta, rho) = (7.000, 0.100, 0.560) with rmse:13.249
# (k, beta, rho) = (7.000, 0.100, 0.500) with rmse:13.238
# (k, beta, rho) = (7.000, 0.100, 0.600) with rmse:13.559
# (k, beta, rho) = (7.000, 0.100, 0.450) with rmse:13.237
# (k, beta, rho) = (7.000, 0.100, 0.650) with rmse:13.559
# (k, beta, rho) = (7.000, 0.300, 0.550) with rmse:5.662
# (k, beta, rho) = (7.000, 0.300, 0.540) with rmse:5.615
# (k, beta, rho) = (7.000, 0.300, 0.560) with rmse:5.759
# (k, beta, rho) = (7.000, 0.300, 0.500) with rmse:5.204
# (k, beta, rho) = (7.000, 0.300, 0.600) with rmse:5.918
# (k, beta, rho) = (7.000, 0.300, 0.450) with rmse:4.741
# (k, beta, rho) = (7.000, 0.300, 0.650) with rmse:6.148
# (k, beta, rho) = (9.000, 0.200, 0.540) with rmse:4.875
# (k, beta, rho) = (9.000, 0.200, 0.560) with rmse:5.486
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.200, 0.450) with rmse:5.634
# (k, beta, rho) = (9.000, 0.200, 0.650) with rmse:5.790
# (k, beta, rho) = (9.000, 0.190, 0.550) with rmse:6.847
# (k, beta, rho) = (9.000, 0.190, 0.540) with rmse:6.867
# (k, beta, rho) = (9.000, 0.190, 0.560) with rmse:6.908
# (k, beta, rho) = (9.000, 0.190, 0.500) with rmse:6.371
# (k, beta, rho) = (9.000, 0.190, 0.600) with rmse:7.123
# (k, beta, rho) = (9.000, 0.190, 0.450) with rmse:6.704
# (k, beta, rho) = (9.000, 0.190, 0.650) with rmse:7.143
# (k, beta, rho) = (9.000, 0.210, 0.550) with rmse:3.912
# (k, beta, rho) = (9.000, 0.210, 0.540) with rmse:3.926
# (k, beta, rho) = (9.000, 0.210, 0.560) with rmse:4.245
# (k, beta, rho) = (9.000, 0.210, 0.500) with rmse:4.242
# (k, beta, rho) = (9.000, 0.210, 0.600) with rmse:4.462
# (k, beta, rho) = (9.000, 0.210, 0.450) with rmse:5.698
# (k, beta, rho) = (9.000, 0.210, 0.650) with rmse:4.310
# (k, beta, rho) = (9.000, 0.150, 0.550) with rmse:12.095
# (k, beta, rho) = (9.000, 0.150, 0.540) with rmse:12.109
# (k, beta, rho) = (9.000, 0.150, 0.560) with rmse:12.095
# (k, beta, rho) = (9.000, 0.150, 0.500) with rmse:12.062
# (k, beta, rho) = (9.000, 0.150, 0.600) with rmse:12.114
# (k, beta, rho) = (9.000, 0.150, 0.450) with rmse:11.979
# (k, beta, rho) = (9.000, 0.150, 0.650) with rmse:12.323
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:6.692
# (k, beta, rho) = (9.000, 0.250, 0.540) with rmse:6.748
# (k, beta, rho) = (9.000, 0.250, 0.560) with rmse:6.099
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:7.232
# (k, beta, rho) = (9.000, 0.250, 0.600) with rmse:6.102
# (k, beta, rho) = (9.000, 0.250, 0.450) with rmse:9.084
# (k, beta, rho) = (9.000, 0.250, 0.650) with rmse:5.954
# (k, beta, rho) = (9.000, 0.100, 0.550) with rmse:13.422
# (k, beta, rho) = (9.000, 0.100, 0.540) with rmse:13.422
# (k, beta, rho) = (9.000, 0.100, 0.560) with rmse:13.422
# (k, beta, rho) = (9.000, 0.100, 0.500) with rmse:13.099
# (k, beta, rho) = (9.000, 0.100, 0.600) with rmse:13.434
# (k, beta, rho) = (9.000, 0.100, 0.450) with rmse:12.964
# (k, beta, rho) = (9.000, 0.100, 0.650) with rmse:13.525
# (k, beta, rho) = (9.000, 0.300, 0.550) with rmse:17.558
# (k, beta, rho) = (9.000, 0.300, 0.540) with rmse:17.631
# (k, beta, rho) = (9.000, 0.300, 0.560) with rmse:17.122
# (k, beta, rho) = (9.000, 0.300, 0.500) with rmse:18.171
# (k, beta, rho) = (9.000, 0.300, 0.600) with rmse:16.572
# (k, beta, rho) = (9.000, 0.300, 0.450) with rmse:21.772
# (k, beta, rho) = (9.000, 0.300, 0.650) with rmse:16.254
# (k, beta, rho) = (10.000, 0.200, 0.550) with rmse:8.559
# (k, beta, rho) = (10.000, 0.200, 0.540) with rmse:8.629
# (k, beta, rho) = (10.000, 0.200, 0.560) with rmse:8.546
# (k, beta, rho) = (10.000, 0.200, 0.500) with rmse:8.523
# (k, beta, rho) = (10.000, 0.200, 0.600) with rmse:8.650
# (k, beta, rho) = (10.000, 0.200, 0.450) with rmse:8.280
# (k, beta, rho) = (10.000, 0.200, 0.650) with rmse:8.748
# (k, beta, rho) = (10.000, 0.190, 0.550) with rmse:8.327
# (k, beta, rho) = (10.000, 0.190, 0.540) with rmse:8.329
# (k, beta, rho) = (10.000, 0.190, 0.560) with rmse:8.330
# (k, beta, rho) = (10.000, 0.190, 0.500) with rmse:8.224
# (k, beta, rho) = (10.000, 0.190, 0.600) with rmse:8.380
# (k, beta, rho) = (10.000, 0.190, 0.450) with rmse:8.002
# (k, beta, rho) = (10.000, 0.190, 0.650) with rmse:8.545
# (k, beta, rho) = (10.000, 0.210, 0.550) with rmse:9.043
# (k, beta, rho) = (10.000, 0.210, 0.540) with rmse:9.141
# (k, beta, rho) = (10.000, 0.210, 0.560) with rmse:9.097
# (k, beta, rho) = (10.000, 0.210, 0.500) with rmse:8.960
# (k, beta, rho) = (10.000, 0.210, 0.600) with rmse:9.206
# (k, beta, rho) = (10.000, 0.210, 0.450) with rmse:8.843
# (k, beta, rho) = (10.000, 0.210, 0.650) with rmse:9.169
# (k, beta, rho) = (10.000, 0.150, 0.550) with rmse:9.249
# (k, beta, rho) = (10.000, 0.150, 0.540) with rmse:9.068
# (k, beta, rho) = (10.000, 0.150, 0.560) with rmse:9.246
# (k, beta, rho) = (10.000, 0.150, 0.500) with rmse:8.871
# (k, beta, rho) = (10.000, 0.150, 0.600) with rmse:9.462
# (k, beta, rho) = (10.000, 0.150, 0.450) with rmse:8.822
# (k, beta, rho) = (10.000, 0.150, 0.650) with rmse:9.901
# (k, beta, rho) = (10.000, 0.250, 0.550) with rmse:16.079
# (k, beta, rho) = (10.000, 0.250, 0.540) with rmse:16.244
# (k, beta, rho) = (10.000, 0.250, 0.560) with rmse:16.010
# (k, beta, rho) = (10.000, 0.250, 0.500) with rmse:16.479
# (k, beta, rho) = (10.000, 0.250, 0.600) with rmse:15.867
# (k, beta, rho) = (10.000, 0.250, 0.450) with rmse:16.846
# (k, beta, rho) = (10.000, 0.250, 0.650) with rmse:15.583
# (k, beta, rho) = (10.000, 0.100, 0.550) with rmse:12.066
# (k, beta, rho) = (10.000, 0.100, 0.540) with rmse:11.999
# (k, beta, rho) = (10.000, 0.100, 0.560) with rmse:12.066
# (k, beta, rho) = (10.000, 0.100, 0.500) with rmse:11.956
# (k, beta, rho) = (10.000, 0.100, 0.600) with rmse:12.222
# (k, beta, rho) = (10.000, 0.100, 0.450) with rmse:11.863
# (k, beta, rho) = (10.000, 0.100, 0.650) with rmse:12.449
# (k, beta, rho) = (10.000, 0.300, 0.550) with rmse:24.514
# (k, beta, rho) = (10.000, 0.300, 0.540) with rmse:24.630
# (k, beta, rho) = (10.000, 0.300, 0.560) with rmse:24.409
# (k, beta, rho) = (10.000, 0.300, 0.500) with rmse:24.936
# (k, beta, rho) = (10.000, 0.300, 0.600) with rmse:24.178
# (k, beta, rho) = (10.000, 0.300, 0.450) with rmse:25.390
# (k, beta, rho) = (10.000, 0.300, 0.650) with rmse:23.638
# (k, beta, rho) = (11.000, 0.200, 0.550) with rmse:10.805
# (k, beta, rho) = (11.000, 0.200, 0.540) with rmse:10.863
# (k, beta, rho) = (11.000, 0.200, 0.560) with rmse:10.741
# (k, beta, rho) = (11.000, 0.200, 0.500) with rmse:11.471
# (k, beta, rho) = (11.000, 0.200, 0.600) with rmse:10.270
# (k, beta, rho) = (11.000, 0.200, 0.450) with rmse:12.178
# (k, beta, rho) = (11.000, 0.200, 0.650) with rmse:9.703
# (k, beta, rho) = (11.000, 0.190, 0.550) with rmse:7.546
# (k, beta, rho) = (11.000, 0.190, 0.540) with rmse:7.636
# (k, beta, rho) = (11.000, 0.190, 0.560) with rmse:7.500
# (k, beta, rho) = (11.000, 0.190, 0.500) with rmse:8.241
# (k, beta, rho) = (11.000, 0.190, 0.600) with rmse:7.202
# (k, beta, rho) = (11.000, 0.190, 0.450) with rmse:8.852
# (k, beta, rho) = (11.000, 0.190, 0.650) with rmse:6.702
# (k, beta, rho) = (11.000, 0.210, 0.550) with rmse:12.160
# (k, beta, rho) = (11.000, 0.210, 0.540) with rmse:12.288
# (k, beta, rho) = (11.000, 0.210, 0.560) with rmse:12.086
# (k, beta, rho) = (11.000, 0.210, 0.500) with rmse:12.976
# (k, beta, rho) = (11.000, 0.210, 0.600) with rmse:11.653
# (k, beta, rho) = (11.000, 0.210, 0.450) with rmse:13.491
# (k, beta, rho) = (11.000, 0.210, 0.650) with rmse:11.174
# (k, beta, rho) = (11.000, 0.150, 0.550) with rmse:7.730
# (k, beta, rho) = (11.000, 0.150, 0.540) with rmse:7.705
# (k, beta, rho) = (11.000, 0.150, 0.560) with rmse:7.837
# (k, beta, rho) = (11.000, 0.150, 0.500) with rmse:8.359
# (k, beta, rho) = (11.000, 0.150, 0.600) with rmse:7.982
# (k, beta, rho) = (11.000, 0.150, 0.450) with rmse:8.771
# (k, beta, rho) = (11.000, 0.150, 0.650) with rmse:8.547
# (k, beta, rho) = (11.000, 0.250, 0.550) with rmse:22.464
# (k, beta, rho) = (11.000, 0.250, 0.540) with rmse:22.545
# (k, beta, rho) = (11.000, 0.250, 0.560) with rmse:22.383
# (k, beta, rho) = (11.000, 0.250, 0.500) with rmse:23.010
# (k, beta, rho) = (11.000, 0.250, 0.600) with rmse:22.004
# (k, beta, rho) = (11.000, 0.250, 0.450) with rmse:23.665
# (k, beta, rho) = (11.000, 0.250, 0.650) with rmse:21.222
# (k, beta, rho) = (11.000, 0.100, 0.550) with rmse:12.578
# (k, beta, rho) = (11.000, 0.100, 0.540) with rmse:12.579
# (k, beta, rho) = (11.000, 0.100, 0.560) with rmse:12.602
# (k, beta, rho) = (11.000, 0.100, 0.500) with rmse:12.437
# (k, beta, rho) = (11.000, 0.100, 0.600) with rmse:12.603
# (k, beta, rho) = (11.000, 0.100, 0.450) with rmse:12.290
# (k, beta, rho) = (11.000, 0.100, 0.650) with rmse:12.636
# (k, beta, rho) = (11.000, 0.300, 0.550) with rmse:33.555
# (k, beta, rho) = (11.000, 0.300, 0.540) with rmse:33.672
# (k, beta, rho) = (11.000, 0.300, 0.560) with rmse:33.434
# (k, beta, rho) = (11.000, 0.300, 0.500) with rmse:34.022
# (k, beta, rho) = (11.000, 0.300, 0.600) with rmse:32.972
# (k, beta, rho) = (11.000, 0.300, 0.450) with rmse:34.641
# (k, beta, rho) = (11.000, 0.300, 0.650) with rmse:32.087
# NEW BEST (k, beta, rho)=[9, 0.21, 0.55] with rmse: 3.912]
# iteration 2...
# (k, beta, rho) = (8.000, 0.210, 0.550) with rmse:8.861
# (k, beta, rho) = (8.000, 0.210, 0.540) with rmse:8.791
# (k, beta, rho) = (8.000, 0.210, 0.560) with rmse:8.775
# (k, beta, rho) = (8.000, 0.210, 0.500) with rmse:8.874
# (k, beta, rho) = (8.000, 0.210, 0.600) with rmse:8.739
# (k, beta, rho) = (8.000, 0.210, 0.450) with rmse:9.017
# (k, beta, rho) = (8.000, 0.210, 0.650) with rmse:8.255
# (k, beta, rho) = (8.000, 0.200, 0.550) with rmse:8.391
# (k, beta, rho) = (8.000, 0.200, 0.540) with rmse:8.423
# (k, beta, rho) = (8.000, 0.200, 0.560) with rmse:8.335
# (k, beta, rho) = (8.000, 0.200, 0.500) with rmse:8.479
# (k, beta, rho) = (8.000, 0.200, 0.600) with rmse:8.276
# (k, beta, rho) = (8.000, 0.200, 0.450) with rmse:8.569
# (k, beta, rho) = (8.000, 0.200, 0.650) with rmse:7.992
# (k, beta, rho) = (8.000, 0.220, 0.550) with rmse:9.862
# (k, beta, rho) = (8.000, 0.220, 0.540) with rmse:9.826
# (k, beta, rho) = (8.000, 0.220, 0.560) with rmse:9.685
# (k, beta, rho) = (8.000, 0.220, 0.500) with rmse:9.833
# (k, beta, rho) = (8.000, 0.220, 0.600) with rmse:9.670
# (k, beta, rho) = (8.000, 0.220, 0.450) with rmse:9.920
# (k, beta, rho) = (8.000, 0.220, 0.650) with rmse:9.131
# (k, beta, rho) = (8.000, 0.160, 0.550) with rmse:9.201
# (k, beta, rho) = (8.000, 0.160, 0.540) with rmse:9.190
# (k, beta, rho) = (8.000, 0.160, 0.560) with rmse:9.231
# (k, beta, rho) = (8.000, 0.160, 0.500) with rmse:9.071
# (k, beta, rho) = (8.000, 0.160, 0.600) with rmse:9.393
# (k, beta, rho) = (8.000, 0.160, 0.450) with rmse:8.859
# (k, beta, rho) = (8.000, 0.160, 0.650) with rmse:9.495
# (k, beta, rho) = (8.000, 0.260, 0.550) with rmse:17.269
# (k, beta, rho) = (8.000, 0.260, 0.540) with rmse:17.329
# (k, beta, rho) = (8.000, 0.260, 0.560) with rmse:16.986
# (k, beta, rho) = (8.000, 0.260, 0.500) with rmse:18.456
# (k, beta, rho) = (8.000, 0.260, 0.600) with rmse:16.771
# (k, beta, rho) = (8.000, 0.260, 0.450) with rmse:19.335
# (k, beta, rho) = (8.000, 0.260, 0.650) with rmse:16.000
# (k, beta, rho) = (8.000, 0.110, 0.550) with rmse:11.547
# (k, beta, rho) = (8.000, 0.110, 0.540) with rmse:11.538
# (k, beta, rho) = (8.000, 0.110, 0.560) with rmse:11.549
# (k, beta, rho) = (8.000, 0.110, 0.500) with rmse:11.488
# (k, beta, rho) = (8.000, 0.110, 0.600) with rmse:11.793
# (k, beta, rho) = (8.000, 0.110, 0.450) with rmse:10.943
# (k, beta, rho) = (8.000, 0.110, 0.650) with rmse:11.816
# (k, beta, rho) = (8.000, 0.310, 0.550) with rmse:26.648
# (k, beta, rho) = (8.000, 0.310, 0.540) with rmse:26.751
# (k, beta, rho) = (8.000, 0.310, 0.560) with rmse:26.394
# (k, beta, rho) = (8.000, 0.310, 0.500) with rmse:27.931
# (k, beta, rho) = (8.000, 0.310, 0.600) with rmse:26.213
# (k, beta, rho) = (8.000, 0.310, 0.450) with rmse:29.110
# (k, beta, rho) = (8.000, 0.310, 0.650) with rmse:25.385
# (k, beta, rho) = (7.000, 0.210, 0.550) with rmse:12.475
# (k, beta, rho) = (7.000, 0.210, 0.540) with rmse:12.472
# (k, beta, rho) = (7.000, 0.210, 0.560) with rmse:12.478
# (k, beta, rho) = (7.000, 0.210, 0.500) with rmse:12.397
# (k, beta, rho) = (7.000, 0.210, 0.600) with rmse:12.623
# (k, beta, rho) = (7.000, 0.210, 0.450) with rmse:12.273
# (k, beta, rho) = (7.000, 0.210, 0.650) with rmse:12.682
# (k, beta, rho) = (7.000, 0.200, 0.550) with rmse:12.833
# (k, beta, rho) = (7.000, 0.200, 0.540) with rmse:12.833
# (k, beta, rho) = (7.000, 0.200, 0.560) with rmse:12.837
# (k, beta, rho) = (7.000, 0.200, 0.500) with rmse:12.763
# (k, beta, rho) = (7.000, 0.200, 0.600) with rmse:12.958
# (k, beta, rho) = (7.000, 0.200, 0.450) with rmse:12.732
# (k, beta, rho) = (7.000, 0.200, 0.650) with rmse:12.967
# (k, beta, rho) = (7.000, 0.220, 0.550) with rmse:12.395
# (k, beta, rho) = (7.000, 0.220, 0.540) with rmse:12.395
# (k, beta, rho) = (7.000, 0.220, 0.560) with rmse:12.422
# (k, beta, rho) = (7.000, 0.220, 0.500) with rmse:12.314
# (k, beta, rho) = (7.000, 0.220, 0.600) with rmse:12.593
# (k, beta, rho) = (7.000, 0.220, 0.450) with rmse:12.200
# (k, beta, rho) = (7.000, 0.220, 0.650) with rmse:12.649
# (k, beta, rho) = (7.000, 0.160, 0.550) with rmse:13.120
# (k, beta, rho) = (7.000, 0.160, 0.540) with rmse:13.120
# (k, beta, rho) = (7.000, 0.160, 0.560) with rmse:13.118
# (k, beta, rho) = (7.000, 0.160, 0.500) with rmse:13.077
# (k, beta, rho) = (7.000, 0.160, 0.600) with rmse:13.536
# (k, beta, rho) = (7.000, 0.160, 0.450) with rmse:13.076
# (k, beta, rho) = (7.000, 0.160, 0.650) with rmse:13.536
# (k, beta, rho) = (7.000, 0.260, 0.550) with rmse:9.572
# (k, beta, rho) = (7.000, 0.260, 0.540) with rmse:9.520
# (k, beta, rho) = (7.000, 0.260, 0.560) with rmse:10.011
# (k, beta, rho) = (7.000, 0.260, 0.500) with rmse:9.456
# (k, beta, rho) = (7.000, 0.260, 0.600) with rmse:10.753
# (k, beta, rho) = (7.000, 0.260, 0.450) with rmse:9.223
# (k, beta, rho) = (7.000, 0.260, 0.650) with rmse:11.505
# (k, beta, rho) = (7.000, 0.110, 0.550) with rmse:13.236
# (k, beta, rho) = (7.000, 0.110, 0.540) with rmse:13.236
# (k, beta, rho) = (7.000, 0.110, 0.560) with rmse:13.236
# (k, beta, rho) = (7.000, 0.110, 0.500) with rmse:13.223
# (k, beta, rho) = (7.000, 0.110, 0.600) with rmse:13.555
# (k, beta, rho) = (7.000, 0.110, 0.450) with rmse:13.223
# (k, beta, rho) = (7.000, 0.110, 0.650) with rmse:13.555
# (k, beta, rho) = (7.000, 0.310, 0.550) with rmse:9.000
# (k, beta, rho) = (7.000, 0.310, 0.540) with rmse:8.958
# (k, beta, rho) = (7.000, 0.310, 0.560) with rmse:9.021
# (k, beta, rho) = (7.000, 0.310, 0.500) with rmse:8.864
# (k, beta, rho) = (7.000, 0.310, 0.600) with rmse:8.526
# (k, beta, rho) = (7.000, 0.310, 0.450) with rmse:9.185
# (k, beta, rho) = (7.000, 0.310, 0.650) with rmse:8.378
# (k, beta, rho) = (9.000, 0.210, 0.540) with rmse:3.926
# (k, beta, rho) = (9.000, 0.210, 0.560) with rmse:4.245
# (k, beta, rho) = (9.000, 0.210, 0.500) with rmse:4.242
# (k, beta, rho) = (9.000, 0.210, 0.600) with rmse:4.462
# (k, beta, rho) = (9.000, 0.210, 0.450) with rmse:5.698
# (k, beta, rho) = (9.000, 0.210, 0.650) with rmse:4.310
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.540) with rmse:4.875
# (k, beta, rho) = (9.000, 0.200, 0.560) with rmse:5.486
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:5.022
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:5.675
# (k, beta, rho) = (9.000, 0.200, 0.450) with rmse:5.634
# (k, beta, rho) = (9.000, 0.200, 0.650) with rmse:5.790
# (k, beta, rho) = (9.000, 0.220, 0.550) with rmse:4.210
# (k, beta, rho) = (9.000, 0.220, 0.540) with rmse:4.230
# (k, beta, rho) = (9.000, 0.220, 0.560) with rmse:4.290
# (k, beta, rho) = (9.000, 0.220, 0.500) with rmse:4.612
# (k, beta, rho) = (9.000, 0.220, 0.600) with rmse:4.409
# (k, beta, rho) = (9.000, 0.220, 0.450) with rmse:6.151
# (k, beta, rho) = (9.000, 0.220, 0.650) with rmse:4.284
# (k, beta, rho) = (9.000, 0.160, 0.550) with rmse:11.537
# (k, beta, rho) = (9.000, 0.160, 0.540) with rmse:11.516
# (k, beta, rho) = (9.000, 0.160, 0.560) with rmse:11.537
# (k, beta, rho) = (9.000, 0.160, 0.500) with rmse:11.105
# (k, beta, rho) = (9.000, 0.160, 0.600) with rmse:11.600
# (k, beta, rho) = (9.000, 0.160, 0.450) with rmse:11.104
# (k, beta, rho) = (9.000, 0.160, 0.650) with rmse:11.804
# (k, beta, rho) = (9.000, 0.260, 0.550) with rmse:8.918
# (k, beta, rho) = (9.000, 0.260, 0.540) with rmse:8.987
# (k, beta, rho) = (9.000, 0.260, 0.560) with rmse:8.461
# (k, beta, rho) = (9.000, 0.260, 0.500) with rmse:9.501
# (k, beta, rho) = (9.000, 0.260, 0.600) with rmse:8.147
# (k, beta, rho) = (9.000, 0.260, 0.450) with rmse:11.050
# (k, beta, rho) = (9.000, 0.260, 0.650) with rmse:8.010
# (k, beta, rho) = (9.000, 0.110, 0.550) with rmse:13.326
# (k, beta, rho) = (9.000, 0.110, 0.540) with rmse:13.326
# (k, beta, rho) = (9.000, 0.110, 0.560) with rmse:13.326
# (k, beta, rho) = (9.000, 0.110, 0.500) with rmse:12.998
# (k, beta, rho) = (9.000, 0.110, 0.600) with rmse:13.338
# (k, beta, rho) = (9.000, 0.110, 0.450) with rmse:12.852
# (k, beta, rho) = (9.000, 0.110, 0.650) with rmse:13.429
# (k, beta, rho) = (9.000, 0.310, 0.550) with rmse:19.030
# (k, beta, rho) = (9.000, 0.310, 0.540) with rmse:19.135
# (k, beta, rho) = (9.000, 0.310, 0.560) with rmse:18.562
# (k, beta, rho) = (9.000, 0.310, 0.500) with rmse:19.608
# (k, beta, rho) = (9.000, 0.310, 0.600) with rmse:18.061
# (k, beta, rho) = (9.000, 0.310, 0.450) with rmse:23.239
# (k, beta, rho) = (9.000, 0.310, 0.650) with rmse:17.684
# (k, beta, rho) = (10.000, 0.210, 0.550) with rmse:9.043
# (k, beta, rho) = (10.000, 0.210, 0.540) with rmse:9.141
# (k, beta, rho) = (10.000, 0.210, 0.560) with rmse:9.097
# (k, beta, rho) = (10.000, 0.210, 0.500) with rmse:8.960
# (k, beta, rho) = (10.000, 0.210, 0.600) with rmse:9.206
# (k, beta, rho) = (10.000, 0.210, 0.450) with rmse:8.843
# (k, beta, rho) = (10.000, 0.210, 0.650) with rmse:9.169
# (k, beta, rho) = (10.000, 0.200, 0.550) with rmse:8.559
# (k, beta, rho) = (10.000, 0.200, 0.540) with rmse:8.629
# (k, beta, rho) = (10.000, 0.200, 0.560) with rmse:8.546
# (k, beta, rho) = (10.000, 0.200, 0.500) with rmse:8.523
# (k, beta, rho) = (10.000, 0.200, 0.600) with rmse:8.650
# (k, beta, rho) = (10.000, 0.200, 0.450) with rmse:8.280
# (k, beta, rho) = (10.000, 0.200, 0.650) with rmse:8.748
# (k, beta, rho) = (10.000, 0.220, 0.550) with rmse:12.231
# (k, beta, rho) = (10.000, 0.220, 0.540) with rmse:12.414
# (k, beta, rho) = (10.000, 0.220, 0.560) with rmse:12.229
# (k, beta, rho) = (10.000, 0.220, 0.500) with rmse:12.462
# (k, beta, rho) = (10.000, 0.220, 0.600) with rmse:12.231
# (k, beta, rho) = (10.000, 0.220, 0.450) with rmse:12.579
# (k, beta, rho) = (10.000, 0.220, 0.650) with rmse:11.966
# (k, beta, rho) = (10.000, 0.160, 0.550) with rmse:8.462
# (k, beta, rho) = (10.000, 0.160, 0.540) with rmse:8.312
# (k, beta, rho) = (10.000, 0.160, 0.560) with rmse:8.443
# (k, beta, rho) = (10.000, 0.160, 0.500) with rmse:7.911
# (k, beta, rho) = (10.000, 0.160, 0.600) with rmse:8.595
# (k, beta, rho) = (10.000, 0.160, 0.450) with rmse:8.025
# (k, beta, rho) = (10.000, 0.160, 0.650) with rmse:9.051
# (k, beta, rho) = (10.000, 0.260, 0.550) with rmse:16.859
# (k, beta, rho) = (10.000, 0.260, 0.540) with rmse:17.009
# (k, beta, rho) = (10.000, 0.260, 0.560) with rmse:16.788
# (k, beta, rho) = (10.000, 0.260, 0.500) with rmse:17.234
# (k, beta, rho) = (10.000, 0.260, 0.600) with rmse:16.643
# (k, beta, rho) = (10.000, 0.260, 0.450) with rmse:17.546
# (k, beta, rho) = (10.000, 0.260, 0.650) with rmse:16.333
# (k, beta, rho) = (10.000, 0.110, 0.550) with rmse:11.622
# (k, beta, rho) = (10.000, 0.110, 0.540) with rmse:11.590
# (k, beta, rho) = (10.000, 0.110, 0.560) with rmse:11.620
# (k, beta, rho) = (10.000, 0.110, 0.500) with rmse:11.581
# (k, beta, rho) = (10.000, 0.110, 0.600) with rmse:11.764
# (k, beta, rho) = (10.000, 0.110, 0.450) with rmse:11.539
# (k, beta, rho) = (10.000, 0.110, 0.650) with rmse:11.895
# (k, beta, rho) = (10.000, 0.310, 0.550) with rmse:26.028
# (k, beta, rho) = (10.000, 0.310, 0.540) with rmse:26.132
# (k, beta, rho) = (10.000, 0.310, 0.560) with rmse:25.933
# (k, beta, rho) = (10.000, 0.310, 0.500) with rmse:26.437
# (k, beta, rho) = (10.000, 0.310, 0.600) with rmse:25.760
# (k, beta, rho) = (10.000, 0.310, 0.450) with rmse:26.953
# (k, beta, rho) = (10.000, 0.310, 0.650) with rmse:25.177
# (k, beta, rho) = (11.000, 0.210, 0.550) with rmse:12.160
# (k, beta, rho) = (11.000, 0.210, 0.540) with rmse:12.288
# (k, beta, rho) = (11.000, 0.210, 0.560) with rmse:12.086
# (k, beta, rho) = (11.000, 0.210, 0.500) with rmse:12.976
# (k, beta, rho) = (11.000, 0.210, 0.600) with rmse:11.653
# (k, beta, rho) = (11.000, 0.210, 0.450) with rmse:13.491
# (k, beta, rho) = (11.000, 0.210, 0.650) with rmse:11.174
# (k, beta, rho) = (11.000, 0.200, 0.550) with rmse:10.805
# (k, beta, rho) = (11.000, 0.200, 0.540) with rmse:10.863
# (k, beta, rho) = (11.000, 0.200, 0.560) with rmse:10.741
# (k, beta, rho) = (11.000, 0.200, 0.500) with rmse:11.471
# (k, beta, rho) = (11.000, 0.200, 0.600) with rmse:10.270
# (k, beta, rho) = (11.000, 0.200, 0.450) with rmse:12.178
# (k, beta, rho) = (11.000, 0.200, 0.650) with rmse:9.703
# (k, beta, rho) = (11.000, 0.220, 0.550) with rmse:15.085
# (k, beta, rho) = (11.000, 0.220, 0.540) with rmse:15.215
# (k, beta, rho) = (11.000, 0.220, 0.560) with rmse:14.919
# (k, beta, rho) = (11.000, 0.220, 0.500) with rmse:15.698
# (k, beta, rho) = (11.000, 0.220, 0.600) with rmse:14.482
# (k, beta, rho) = (11.000, 0.220, 0.450) with rmse:16.195
# (k, beta, rho) = (11.000, 0.220, 0.650) with rmse:13.958
# (k, beta, rho) = (11.000, 0.160, 0.550) with rmse:7.174
# (k, beta, rho) = (11.000, 0.160, 0.540) with rmse:7.433
# (k, beta, rho) = (11.000, 0.160, 0.560) with rmse:7.367
# (k, beta, rho) = (11.000, 0.160, 0.500) with rmse:7.990
# (k, beta, rho) = (11.000, 0.160, 0.600) with rmse:7.487
# (k, beta, rho) = (11.000, 0.160, 0.450) with rmse:8.632
# (k, beta, rho) = (11.000, 0.160, 0.650) with rmse:7.416
# (k, beta, rho) = (11.000, 0.260, 0.550) with rmse:25.903
# (k, beta, rho) = (11.000, 0.260, 0.540) with rmse:26.007
# (k, beta, rho) = (11.000, 0.260, 0.560) with rmse:25.823
# (k, beta, rho) = (11.000, 0.260, 0.500) with rmse:26.480
# (k, beta, rho) = (11.000, 0.260, 0.600) with rmse:25.053
# (k, beta, rho) = (11.000, 0.260, 0.450) with rmse:27.150
# (k, beta, rho) = (11.000, 0.260, 0.650) with rmse:24.377
# (k, beta, rho) = (11.000, 0.110, 0.550) with rmse:12.031
# (k, beta, rho) = (11.000, 0.110, 0.540) with rmse:12.032
# (k, beta, rho) = (11.000, 0.110, 0.560) with rmse:12.315
# (k, beta, rho) = (11.000, 0.110, 0.500) with rmse:11.976
# (k, beta, rho) = (11.000, 0.110, 0.600) with rmse:12.305
# (k, beta, rho) = (11.000, 0.110, 0.450) with rmse:11.951
# (k, beta, rho) = (11.000, 0.110, 0.650) with rmse:12.300
# (k, beta, rho) = (11.000, 0.310, 0.550) with rmse:40.188
# (k, beta, rho) = (11.000, 0.310, 0.540) with rmse:40.287
# (k, beta, rho) = (11.000, 0.310, 0.560) with rmse:40.095
# (k, beta, rho) = (11.000, 0.310, 0.500) with rmse:40.818
# (k, beta, rho) = (11.000, 0.310, 0.600) with rmse:39.648
# (k, beta, rho) = (11.000, 0.310, 0.450) with rmse:41.532
# (k, beta, rho) = (11.000, 0.310, 0.650) with rmse:38.736
# I'm moving...
# (k, beta, rho)=(9, 0.21, 0.54) tabu
# iteration 3...
# (k, beta, rho) = (8.000, 0.210, 0.540) with rmse:8.791
# (k, beta, rho) = (8.000, 0.210, 0.530) with rmse:8.826
# (k, beta, rho) = (8.000, 0.210, 0.550) with rmse:8.861
# (k, beta, rho) = (8.000, 0.210, 0.490) with rmse:8.922
# (k, beta, rho) = (8.000, 0.210, 0.590) with rmse:8.732
# (k, beta, rho) = (8.000, 0.210, 0.440) with rmse:9.101
# (k, beta, rho) = (8.000, 0.210, 0.640) with rmse:8.430
# (k, beta, rho) = (8.000, 0.200, 0.540) with rmse:8.423
# (k, beta, rho) = (8.000, 0.200, 0.530) with rmse:8.450
# (k, beta, rho) = (8.000, 0.200, 0.550) with rmse:8.391
# (k, beta, rho) = (8.000, 0.200, 0.490) with rmse:8.501
# (k, beta, rho) = (8.000, 0.200, 0.590) with rmse:8.285
# (k, beta, rho) = (8.000, 0.200, 0.440) with rmse:8.575
# (k, beta, rho) = (8.000, 0.200, 0.640) with rmse:8.088
# (k, beta, rho) = (8.000, 0.220, 0.540) with rmse:9.826
# (k, beta, rho) = (8.000, 0.220, 0.530) with rmse:9.853
# (k, beta, rho) = (8.000, 0.220, 0.550) with rmse:9.862
# (k, beta, rho) = (8.000, 0.220, 0.490) with rmse:9.852
# (k, beta, rho) = (8.000, 0.220, 0.590) with rmse:9.659
# (k, beta, rho) = (8.000, 0.220, 0.440) with rmse:9.989
# (k, beta, rho) = (8.000, 0.220, 0.640) with rmse:9.319
# (k, beta, rho) = (8.000, 0.160, 0.540) with rmse:9.190
# (k, beta, rho) = (8.000, 0.160, 0.530) with rmse:9.159
# (k, beta, rho) = (8.000, 0.160, 0.550) with rmse:9.201
# (k, beta, rho) = (8.000, 0.160, 0.490) with rmse:9.062
# (k, beta, rho) = (8.000, 0.160, 0.590) with rmse:9.315
# (k, beta, rho) = (8.000, 0.160, 0.440) with rmse:8.850
# (k, beta, rho) = (8.000, 0.160, 0.640) with rmse:9.418
# (k, beta, rho) = (8.000, 0.260, 0.540) with rmse:17.329
# (k, beta, rho) = (8.000, 0.260, 0.530) with rmse:17.402
# (k, beta, rho) = (8.000, 0.260, 0.550) with rmse:17.269
# (k, beta, rho) = (8.000, 0.260, 0.490) with rmse:18.561
# (k, beta, rho) = (8.000, 0.260, 0.590) with rmse:16.849
# (k, beta, rho) = (8.000, 0.260, 0.440) with rmse:19.400
# (k, beta, rho) = (8.000, 0.260, 0.640) with rmse:16.268
# (k, beta, rho) = (8.000, 0.110, 0.540) with rmse:11.538
# (k, beta, rho) = (8.000, 0.110, 0.530) with rmse:11.538
# (k, beta, rho) = (8.000, 0.110, 0.550) with rmse:11.547
# (k, beta, rho) = (8.000, 0.110, 0.490) with rmse:11.055
# (k, beta, rho) = (8.000, 0.110, 0.590) with rmse:11.587
# (k, beta, rho) = (8.000, 0.110, 0.440) with rmse:10.943
# (k, beta, rho) = (8.000, 0.110, 0.640) with rmse:11.746
# (k, beta, rho) = (8.000, 0.310, 0.540) with rmse:26.751
# (k, beta, rho) = (8.000, 0.310, 0.530) with rmse:26.821
# (k, beta, rho) = (8.000, 0.310, 0.550) with rmse:26.648
# (k, beta, rho) = (8.000, 0.310, 0.490) with rmse:28.291
# (k, beta, rho) = (8.000, 0.310, 0.590) with rmse:26.300
# (k, beta, rho) = (8.000, 0.310, 0.440) with rmse:29.215
# (k, beta, rho) = (8.000, 0.310, 0.640) with rmse:25.832
# (k, beta, rho) = (7.000, 0.210, 0.540) with rmse:12.472
# (k, beta, rho) = (7.000, 0.210, 0.530) with rmse:12.432
# (k, beta, rho) = (7.000, 0.210, 0.550) with rmse:12.475
# (k, beta, rho) = (7.000, 0.210, 0.490) with rmse:12.397
# (k, beta, rho) = (7.000, 0.210, 0.590) with rmse:12.579
# (k, beta, rho) = (7.000, 0.210, 0.440) with rmse:12.224
# (k, beta, rho) = (7.000, 0.210, 0.640) with rmse:12.682
# (k, beta, rho) = (7.000, 0.200, 0.540) with rmse:12.833
# (k, beta, rho) = (7.000, 0.200, 0.530) with rmse:12.800
# (k, beta, rho) = (7.000, 0.200, 0.550) with rmse:12.833
# (k, beta, rho) = (7.000, 0.200, 0.490) with rmse:12.731
# (k, beta, rho) = (7.000, 0.200, 0.590) with rmse:12.930
# (k, beta, rho) = (7.000, 0.200, 0.440) with rmse:12.691
# (k, beta, rho) = (7.000, 0.200, 0.640) with rmse:12.967
# (k, beta, rho) = (7.000, 0.220, 0.540) with rmse:12.395
# (k, beta, rho) = (7.000, 0.220, 0.530) with rmse:12.351
# (k, beta, rho) = (7.000, 0.220, 0.550) with rmse:12.395
# (k, beta, rho) = (7.000, 0.220, 0.490) with rmse:12.314
# (k, beta, rho) = (7.000, 0.220, 0.590) with rmse:12.523
# (k, beta, rho) = (7.000, 0.220, 0.440) with rmse:12.128
# (k, beta, rho) = (7.000, 0.220, 0.640) with rmse:12.649
# (k, beta, rho) = (7.000, 0.160, 0.540) with rmse:13.120
# (k, beta, rho) = (7.000, 0.160, 0.530) with rmse:13.089
# (k, beta, rho) = (7.000, 0.160, 0.550) with rmse:13.120
# (k, beta, rho) = (7.000, 0.160, 0.490) with rmse:13.077
# (k, beta, rho) = (7.000, 0.160, 0.590) with rmse:13.186
# (k, beta, rho) = (7.000, 0.160, 0.440) with rmse:13.055
# (k, beta, rho) = (7.000, 0.160, 0.640) with rmse:13.536
# (k, beta, rho) = (7.000, 0.260, 0.540) with rmse:9.520
# (k, beta, rho) = (7.000, 0.260, 0.530) with rmse:9.486
# (k, beta, rho) = (7.000, 0.260, 0.550) with rmse:9.572
# (k, beta, rho) = (7.000, 0.260, 0.490) with rmse:9.219
# (k, beta, rho) = (7.000, 0.260, 0.590) with rmse:10.127
# (k, beta, rho) = (7.000, 0.260, 0.440) with rmse:9.148
# (k, beta, rho) = (7.000, 0.260, 0.640) with rmse:11.505
# (k, beta, rho) = (7.000, 0.110, 0.540) with rmse:13.236
# (k, beta, rho) = (7.000, 0.110, 0.530) with rmse:13.228
# (k, beta, rho) = (7.000, 0.110, 0.550) with rmse:13.236
# (k, beta, rho) = (7.000, 0.110, 0.490) with rmse:13.223
# (k, beta, rho) = (7.000, 0.110, 0.590) with rmse:13.267
# (k, beta, rho) = (7.000, 0.110, 0.440) with rmse:13.221
# (k, beta, rho) = (7.000, 0.110, 0.640) with rmse:13.555
# (k, beta, rho) = (7.000, 0.310, 0.540) with rmse:8.958
# (k, beta, rho) = (7.000, 0.310, 0.530) with rmse:8.886
# (k, beta, rho) = (7.000, 0.310, 0.550) with rmse:9.000
# (k, beta, rho) = (7.000, 0.310, 0.490) with rmse:9.008
# (k, beta, rho) = (7.000, 0.310, 0.590) with rmse:8.943
# (k, beta, rho) = (7.000, 0.310, 0.440) with rmse:9.263
# (k, beta, rho) = (7.000, 0.310, 0.640) with rmse:8.330
# (k, beta, rho) = (9.000, 0.210, 0.530) with rmse:4.100
# (k, beta, rho) = (9.000, 0.210, 0.550) with rmse:3.912
# (k, beta, rho) = (9.000, 0.210, 0.490) with rmse:4.308
# (k, beta, rho) = (9.000, 0.210, 0.590) with rmse:4.467
# (k, beta, rho) = (9.000, 0.210, 0.440) with rmse:5.722
# (k, beta, rho) = (9.000, 0.210, 0.640) with rmse:4.310
# (k, beta, rho) = (9.000, 0.200, 0.540) with rmse:4.875
# (k, beta, rho) = (9.000, 0.200, 0.530) with rmse:4.999
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:4.897
# (k, beta, rho) = (9.000, 0.200, 0.490) with rmse:5.045
# (k, beta, rho) = (9.000, 0.200, 0.590) with rmse:5.723
# (k, beta, rho) = (9.000, 0.200, 0.440) with rmse:5.530
# (k, beta, rho) = (9.000, 0.200, 0.640) with rmse:5.779
# (k, beta, rho) = (9.000, 0.220, 0.540) with rmse:4.230
# (k, beta, rho) = (9.000, 0.220, 0.530) with rmse:4.415
# (k, beta, rho) = (9.000, 0.220, 0.550) with rmse:4.210
# (k, beta, rho) = (9.000, 0.220, 0.490) with rmse:4.669
# (k, beta, rho) = (9.000, 0.220, 0.590) with rmse:4.344
# (k, beta, rho) = (9.000, 0.220, 0.440) with rmse:6.246
# (k, beta, rho) = (9.000, 0.220, 0.640) with rmse:4.294
# (k, beta, rho) = (9.000, 0.160, 0.540) with rmse:11.516
# ...
# (k, beta, rho) = (11.000, 0.210, 0.590) with rmse:11.783
# (k, beta, rho) = (11.000, 0.210, 0.690) with rmse:10.763
# (k, beta, rho) = (11.000, 0.210, 0.540) with rmse:12.288
# (k, beta, rho) = (11.000, 0.210, 0.740) with rmse:9.819
# (k, beta, rho) = (11.000, 0.230, 0.640) with rmse:17.021
# (k, beta, rho) = (11.000, 0.230, 0.630) with rmse:17.085
# (k, beta, rho) = (11.000, 0.230, 0.650) with rmse:16.945
# (k, beta, rho) = (11.000, 0.230, 0.590) with rmse:17.608
# (k, beta, rho) = (11.000, 0.230, 0.690) with rmse:16.361
# (k, beta, rho) = (11.000, 0.230, 0.540) with rmse:18.095
# (k, beta, rho) = (11.000, 0.230, 0.740) with rmse:15.662
# (k, beta, rho) = (11.000, 0.170, 0.640) with rmse:6.821
# (k, beta, rho) = (11.000, 0.170, 0.630) with rmse:6.816
# (k, beta, rho) = (11.000, 0.170, 0.650) with rmse:6.788
# (k, beta, rho) = (11.000, 0.170, 0.590) with rmse:6.895
# (k, beta, rho) = (11.000, 0.170, 0.690) with rmse:6.770
# (k, beta, rho) = (11.000, 0.170, 0.540) with rmse:6.966
# (k, beta, rho) = (11.000, 0.170, 0.740) with rmse:6.959
# (k, beta, rho) = (11.000, 0.270, 0.640) with rmse:27.231
# (k, beta, rho) = (11.000, 0.270, 0.630) with rmse:27.352
# (k, beta, rho) = (11.000, 0.270, 0.650) with rmse:27.108
# (k, beta, rho) = (11.000, 0.270, 0.590) with rmse:28.099
# (k, beta, rho) = (11.000, 0.270, 0.690) with rmse:26.611
# (k, beta, rho) = (11.000, 0.270, 0.540) with rmse:28.670
# (k, beta, rho) = (11.000, 0.270, 0.740) with rmse:25.990
# (k, beta, rho) = (11.000, 0.120, 0.640) with rmse:11.429
# (k, beta, rho) = (11.000, 0.120, 0.630) with rmse:11.429
# (k, beta, rho) = (11.000, 0.120, 0.650) with rmse:11.443
# (k, beta, rho) = (11.000, 0.120, 0.590) with rmse:11.206
# (k, beta, rho) = (11.000, 0.120, 0.690) with rmse:11.556
# (k, beta, rho) = (11.000, 0.120, 0.540) with rmse:10.503
# (k, beta, rho) = (11.000, 0.120, 0.740) with rmse:11.564
# (k, beta, rho) = (11.000, 0.320, 0.640) with rmse:42.515
# (k, beta, rho) = (11.000, 0.320, 0.630) with rmse:42.622
# (k, beta, rho) = (11.000, 0.320, 0.650) with rmse:42.374
# (k, beta, rho) = (11.000, 0.320, 0.590) with rmse:43.328
# (k, beta, rho) = (11.000, 0.320, 0.690) with rmse:42.015
# (k, beta, rho) = (11.000, 0.320, 0.540) with rmse:43.803
# (k, beta, rho) = (11.000, 0.320, 0.740) with rmse:41.342
# I'm moving...
# (k, beta, rho)=(9, 0.21, 0.63) tabu
# iteration 14...
# (k, beta, rho) = (8.000, 0.210, 0.630) with rmse:8.796
# (k, beta, rho) = (8.000, 0.210, 0.620) with rmse:8.745
# (k, beta, rho) = (8.000, 0.210, 0.640) with rmse:8.430
# (k, beta, rho) = (8.000, 0.210, 0.580) with rmse:8.700
# (k, beta, rho) = (8.000, 0.210, 0.680) with rmse:8.997
# (k, beta, rho) = (8.000, 0.210, 0.530) with rmse:8.826
# (k, beta, rho) = (8.000, 0.210, 0.730) with rmse:9.217
# (k, beta, rho) = (8.000, 0.200, 0.630) with rmse:8.333
# (k, beta, rho) = (8.000, 0.200, 0.620) with rmse:8.272
# (k, beta, rho) = (8.000, 0.200, 0.640) with rmse:8.088
# (k, beta, rho) = (8.000, 0.200, 0.580) with rmse:8.274
# (k, beta, rho) = (8.000, 0.200, 0.680) with rmse:8.792
# (k, beta, rho) = (8.000, 0.200, 0.530) with rmse:8.450
# (k, beta, rho) = (8.000, 0.200, 0.730) with rmse:8.996
# (k, beta, rho) = (8.000, 0.220, 0.630) with rmse:9.700
# (k, beta, rho) = (8.000, 0.220, 0.620) with rmse:9.668
# (k, beta, rho) = (8.000, 0.220, 0.640) with rmse:9.319
# (k, beta, rho) = (8.000, 0.220, 0.580) with rmse:9.642
# (k, beta, rho) = (8.000, 0.220, 0.680) with rmse:9.184
# (k, beta, rho) = (8.000, 0.220, 0.530) with rmse:9.853
# (k, beta, rho) = (8.000, 0.220, 0.730) with rmse:9.260
# (k, beta, rho) = (8.000, 0.160, 0.630) with rmse:9.554
# (k, beta, rho) = (8.000, 0.160, 0.620) with rmse:9.415
# (k, beta, rho) = (8.000, 0.160, 0.640) with rmse:9.418
# (k, beta, rho) = (8.000, 0.160, 0.580) with rmse:9.229
# (k, beta, rho) = (8.000, 0.160, 0.680) with rmse:10.511
# (k, beta, rho) = (8.000, 0.160, 0.530) with rmse:9.159
# (k, beta, rho) = (8.000, 0.160, 0.730) with rmse:10.792
# (k, beta, rho) = (8.000, 0.260, 0.630) with rmse:16.686
# (k, beta, rho) = (8.000, 0.260, 0.620) with rmse:16.746
# (k, beta, rho) = (8.000, 0.260, 0.640) with rmse:16.268
# (k, beta, rho) = (8.000, 0.260, 0.580) with rmse:16.881
# (k, beta, rho) = (8.000, 0.260, 0.680) with rmse:14.814
# (k, beta, rho) = (8.000, 0.260, 0.530) with rmse:17.402
# (k, beta, rho) = (8.000, 0.260, 0.730) with rmse:14.695
# (k, beta, rho) = (8.000, 0.110, 0.630) with rmse:11.832
# (k, beta, rho) = (8.000, 0.110, 0.620) with rmse:11.823
# (k, beta, rho) = (8.000, 0.110, 0.640) with rmse:11.746
# (k, beta, rho) = (8.000, 0.110, 0.580) with rmse:11.550
# (k, beta, rho) = (8.000, 0.110, 0.680) with rmse:12.242
# (k, beta, rho) = (8.000, 0.110, 0.530) with rmse:11.538
# (k, beta, rho) = (8.000, 0.110, 0.730) with rmse:12.386
# (k, beta, rho) = (8.000, 0.310, 0.630) with rmse:26.113
# (k, beta, rho) = (8.000, 0.310, 0.620) with rmse:26.175
# (k, beta, rho) = (8.000, 0.310, 0.640) with rmse:25.832
# (k, beta, rho) = (8.000, 0.310, 0.580) with rmse:26.354
# (k, beta, rho) = (8.000, 0.310, 0.680) with rmse:24.199
# (k, beta, rho) = (8.000, 0.310, 0.530) with rmse:26.821
# (k, beta, rho) = (8.000, 0.310, 0.730) with rmse:23.890
# (k, beta, rho) = (7.000, 0.210, 0.630) with rmse:12.682
# (k, beta, rho) = (7.000, 0.210, 0.620) with rmse:12.682
# (k, beta, rho) = (7.000, 0.210, 0.640) with rmse:12.682
# (k, beta, rho) = (7.000, 0.210, 0.580) with rmse:12.579
# (k, beta, rho) = (7.000, 0.210, 0.680) with rmse:12.693
# (k, beta, rho) = (7.000, 0.210, 0.530) with rmse:12.432
# (k, beta, rho) = (7.000, 0.210, 0.730) with rmse:12.710
# (k, beta, rho) = (7.000, 0.200, 0.630) with rmse:12.967
# (k, beta, rho) = (7.000, 0.200, 0.620) with rmse:12.967
# (k, beta, rho) = (7.000, 0.200, 0.640) with rmse:12.967
# (k, beta, rho) = (7.000, 0.200, 0.580) with rmse:12.930
# (k, beta, rho) = (7.000, 0.200, 0.680) with rmse:12.978
# (k, beta, rho) = (7.000, 0.200, 0.530) with rmse:12.800
# (k, beta, rho) = (7.000, 0.200, 0.730) with rmse:12.978
# (k, beta, rho) = (7.000, 0.220, 0.630) with rmse:12.648
# (k, beta, rho) = (7.000, 0.220, 0.620) with rmse:12.648
# (k, beta, rho) = (7.000, 0.220, 0.640) with rmse:12.649
# (k, beta, rho) = (7.000, 0.220, 0.580) with rmse:12.523
# (k, beta, rho) = (7.000, 0.220, 0.680) with rmse:12.668
# (k, beta, rho) = (7.000, 0.220, 0.530) with rmse:12.351
# (k, beta, rho) = (7.000, 0.220, 0.730) with rmse:12.684
# (k, beta, rho) = (7.000, 0.160, 0.630) with rmse:13.536
# (k, beta, rho) = (7.000, 0.160, 0.620) with rmse:13.536
# (k, beta, rho) = (7.000, 0.160, 0.640) with rmse:13.536
# (k, beta, rho) = (7.000, 0.160, 0.580) with rmse:13.186
# (k, beta, rho) = (7.000, 0.160, 0.680) with rmse:13.536
# (k, beta, rho) = (7.000, 0.160, 0.530) with rmse:13.089
# (k, beta, rho) = (7.000, 0.160, 0.730) with rmse:13.536
# (k, beta, rho) = (7.000, 0.260, 0.630) with rmse:11.495
# (k, beta, rho) = (7.000, 0.260, 0.620) with rmse:11.495
# (k, beta, rho) = (7.000, 0.260, 0.640) with rmse:11.505
# (k, beta, rho) = (7.000, 0.260, 0.580) with rmse:10.110
# (k, beta, rho) = (7.000, 0.260, 0.680) with rmse:11.548
# (k, beta, rho) = (7.000, 0.260, 0.530) with rmse:9.486
# (k, beta, rho) = (7.000, 0.260, 0.730) with rmse:11.764
# (k, beta, rho) = (7.000, 0.110, 0.630) with rmse:13.555
# (k, beta, rho) = (7.000, 0.110, 0.620) with rmse:13.555
# (k, beta, rho) = (7.000, 0.110, 0.640) with rmse:13.555
# (k, beta, rho) = (7.000, 0.110, 0.580) with rmse:13.267
# (k, beta, rho) = (7.000, 0.110, 0.680) with rmse:13.557
# (k, beta, rho) = (7.000, 0.110, 0.530) with rmse:13.228
# (k, beta, rho) = (7.000, 0.110, 0.730) with rmse:13.557
# (k, beta, rho) = (7.000, 0.310, 0.630) with rmse:8.550
# (k, beta, rho) = (7.000, 0.310, 0.620) with rmse:8.530
# (k, beta, rho) = (7.000, 0.310, 0.640) with rmse:8.330
# (k, beta, rho) = (7.000, 0.310, 0.580) with rmse:9.040
# (k, beta, rho) = (7.000, 0.310, 0.680) with rmse:8.416
# (k, beta, rho) = (7.000, 0.310, 0.530) with rmse:8.886
# (k, beta, rho) = (7.000, 0.310, 0.730) with rmse:8.639
# (k, beta, rho) = (9.000, 0.210, 0.620) with rmse:4.287
# (k, beta, rho) = (9.000, 0.210, 0.640) with rmse:4.310
# (k, beta, rho) = (9.000, 0.210, 0.580) with rmse:4.480
# (k, beta, rho) = (9.000, 0.210, 0.680) with rmse:4.502
# (k, beta, rho) = (9.000, 0.210, 0.530) with rmse:4.100
# (k, beta, rho) = (9.000, 0.210, 0.730) with rmse:4.771
# (k, beta, rho) = (9.000, 0.200, 0.630) with rmse:5.686
# (k, beta, rho) = (9.000, 0.200, 0.620) with rmse:5.693
# (k, beta, rho) = (9.000, 0.200, 0.640) with rmse:5.779
# (k, beta, rho) = (9.000, 0.200, 0.580) with rmse:5.721
# (k, beta, rho) = (9.000, 0.200, 0.680) with rmse:6.023
# (k, beta, rho) = (9.000, 0.200, 0.530) with rmse:4.999
# (k, beta, rho) = (9.000, 0.200, 0.730) with rmse:6.222
# (k, beta, rho) = (9.000, 0.220, 0.630) with rmse:4.340
# (k, beta, rho) = (9.000, 0.220, 0.620) with rmse:4.376
# (k, beta, rho) = (9.000, 0.220, 0.640) with rmse:4.294
# (k, beta, rho) = (9.000, 0.220, 0.580) with rmse:4.379
# (k, beta, rho) = (9.000, 0.220, 0.680) with rmse:4.444
# (k, beta, rho) = (9.000, 0.220, 0.530) with rmse:4.415
# (k, beta, rho) = (9.000, 0.220, 0.730) with rmse:4.471
# (k, beta, rho) = (9.000, 0.160, 0.630) with rmse:11.647
# (k, beta, rho) = (9.000, 0.160, 0.620) with rmse:11.647
# (k, beta, rho) = (9.000, 0.160, 0.640) with rmse:11.805
# (k, beta, rho) = (9.000, 0.160, 0.580) with rmse:11.630
# (k, beta, rho) = (9.000, 0.160, 0.680) with rmse:11.899
# (k, beta, rho) = (9.000, 0.160, 0.530) with rmse:11.150
# (k, beta, rho) = (9.000, 0.160, 0.730) with rmse:12.037
# (k, beta, rho) = (9.000, 0.260, 0.630) with rmse:8.069
# (k, beta, rho) = (9.000, 0.260, 0.620) with rmse:8.113
# (k, beta, rho) = (9.000, 0.260, 0.640) with rmse:8.022
# (k, beta, rho) = (9.000, 0.260, 0.580) with rmse:8.242
# (k, beta, rho) = (9.000, 0.260, 0.680) with rmse:8.043
# (k, beta, rho) = (9.000, 0.260, 0.530) with rmse:9.274
# (k, beta, rho) = (9.000, 0.260, 0.730) with rmse:7.925
# (k, beta, rho) = (9.000, 0.110, 0.630) with rmse:13.338
# (k, beta, rho) = (9.000, 0.110, 0.620) with rmse:13.338
# (k, beta, rho) = (9.000, 0.110, 0.640) with rmse:13.429
# (k, beta, rho) = (9.000, 0.110, 0.580) with rmse:13.338
# (k, beta, rho) = (9.000, 0.110, 0.680) with rmse:13.494
# (k, beta, rho) = (9.000, 0.110, 0.530) with rmse:13.326
# (k, beta, rho) = (9.000, 0.110, 0.730) with rmse:13.494
# (k, beta, rho) = (9.000, 0.310, 0.630) with rmse:17.917
# (k, beta, rho) = (9.000, 0.310, 0.620) with rmse:17.968
# (k, beta, rho) = (9.000, 0.310, 0.640) with rmse:17.792
# (k, beta, rho) = (9.000, 0.310, 0.580) with rmse:18.300
# (k, beta, rho) = (9.000, 0.310, 0.680) with rmse:17.636
# (k, beta, rho) = (9.000, 0.310, 0.530) with rmse:19.441
# (k, beta, rho) = (9.000, 0.310, 0.730) with rmse:17.518
# (k, beta, rho) = (10.000, 0.210, 0.630) with rmse:9.117
# (k, beta, rho) = (10.000, 0.210, 0.620) with rmse:9.213
# (k, beta, rho) = (10.000, 0.210, 0.640) with rmse:9.133
# (k, beta, rho) = (10.000, 0.210, 0.580) with rmse:9.170
# (k, beta, rho) = (10.000, 0.210, 0.680) with rmse:9.400
# (k, beta, rho) = (10.000, 0.210, 0.530) with rmse:9.067
# (k, beta, rho) = (10.000, 0.210, 0.730) with rmse:9.548
# (k, beta, rho) = (10.000, 0.200, 0.630) with rmse:8.683
# (k, beta, rho) = (10.000, 0.200, 0.620) with rmse:8.693
# (k, beta, rho) = (10.000, 0.200, 0.640) with rmse:8.690
# (k, beta, rho) = (10.000, 0.200, 0.580) with rmse:8.606
# (k, beta, rho) = (10.000, 0.200, 0.680) with rmse:8.937
# (k, beta, rho) = (10.000, 0.200, 0.530) with rmse:8.554
# (k, beta, rho) = (10.000, 0.200, 0.730) with rmse:9.133
# (k, beta, rho) = (10.000, 0.220, 0.630) with rmse:11.946
# (k, beta, rho) = (10.000, 0.220, 0.620) with rmse:12.154
# (k, beta, rho) = (10.000, 0.220, 0.640) with rmse:11.967
# (k, beta, rho) = (10.000, 0.220, 0.580) with rmse:12.234
# (k, beta, rho) = (10.000, 0.220, 0.680) with rmse:12.088
# (k, beta, rho) = (10.000, 0.220, 0.530) with rmse:12.402
# (k, beta, rho) = (10.000, 0.220, 0.730) with rmse:11.952
# (k, beta, rho) = (10.000, 0.160, 0.630) with rmse:9.043
# (k, beta, rho) = (10.000, 0.160, 0.620) with rmse:8.649
# (k, beta, rho) = (10.000, 0.160, 0.640) with rmse:9.058
# (k, beta, rho) = (10.000, 0.160, 0.580) with rmse:8.529
# (k, beta, rho) = (10.000, 0.160, 0.680) with rmse:9.093
# (k, beta, rho) = (10.000, 0.160, 0.530) with rmse:8.271
# (k, beta, rho) = (10.000, 0.160, 0.730) with rmse:9.211
# (k, beta, rho) = (10.000, 0.260, 0.630) with rmse:16.377
# (k, beta, rho) = (10.000, 0.260, 0.620) with rmse:16.508
# (k, beta, rho) = (10.000, 0.260, 0.640) with rmse:16.342
# (k, beta, rho) = (10.000, 0.260, 0.580) with rmse:16.709
# (k, beta, rho) = (10.000, 0.260, 0.680) with rmse:16.345
# (k, beta, rho) = (10.000, 0.260, 0.530) with rmse:17.019
# (k, beta, rho) = (10.000, 0.260, 0.730) with rmse:16.232
# (k, beta, rho) = (10.000, 0.110, 0.630) with rmse:11.888
# (k, beta, rho) = (10.000, 0.110, 0.620) with rmse:11.870
# (k, beta, rho) = (10.000, 0.110, 0.640) with rmse:11.896
# (k, beta, rho) = (10.000, 0.110, 0.580) with rmse:11.714
# (k, beta, rho) = (10.000, 0.110, 0.680) with rmse:12.048
# (k, beta, rho) = (10.000, 0.110, 0.530) with rmse:11.576
# (k, beta, rho) = (10.000, 0.110, 0.730) with rmse:12.423
# (k, beta, rho) = (10.000, 0.310, 0.630) with rmse:25.393
# (k, beta, rho) = (10.000, 0.310, 0.620) with rmse:25.503
# (k, beta, rho) = (10.000, 0.310, 0.640) with rmse:25.220
# (k, beta, rho) = (10.000, 0.310, 0.580) with rmse:25.853
# (k, beta, rho) = (10.000, 0.310, 0.680) with rmse:25.107
# (k, beta, rho) = (10.000, 0.310, 0.530) with rmse:26.188
# (k, beta, rho) = (10.000, 0.310, 0.730) with rmse:24.940
# (k, beta, rho) = (11.000, 0.210, 0.630) with rmse:11.266
# (k, beta, rho) = (11.000, 0.210, 0.620) with rmse:11.368
# (k, beta, rho) = (11.000, 0.210, 0.640) with rmse:11.231
# (k, beta, rho) = (11.000, 0.210, 0.580) with rmse:11.906
# (k, beta, rho) = (11.000, 0.210, 0.680) with rmse:10.862
# (k, beta, rho) = (11.000, 0.210, 0.530) with rmse:12.489
# (k, beta, rho) = (11.000, 0.210, 0.730) with rmse:10.275
# (k, beta, rho) = (11.000, 0.200, 0.630) with rmse:9.833
# (k, beta, rho) = (11.000, 0.200, 0.620) with rmse:9.985
# (k, beta, rho) = (11.000, 0.200, 0.640) with rmse:9.812
# (k, beta, rho) = (11.000, 0.200, 0.580) with rmse:10.546
# (k, beta, rho) = (11.000, 0.200, 0.680) with rmse:9.289
# (k, beta, rho) = (11.000, 0.200, 0.530) with rmse:11.044
# (k, beta, rho) = (11.000, 0.200, 0.730) with rmse:8.805
# (k, beta, rho) = (11.000, 0.220, 0.630) with rmse:14.146
# (k, beta, rho) = (11.000, 0.220, 0.620) with rmse:14.242
# (k, beta, rho) = (11.000, 0.220, 0.640) with rmse:14.068
# (k, beta, rho) = (11.000, 0.220, 0.580) with rmse:14.786
# (k, beta, rho) = (11.000, 0.220, 0.680) with rmse:13.481
# (k, beta, rho) = (11.000, 0.220, 0.530) with rmse:15.411
# (k, beta, rho) = (11.000, 0.220, 0.730) with rmse:12.917
# (k, beta, rho) = (11.000, 0.160, 0.630) with rmse:7.478
# (k, beta, rho) = (11.000, 0.160, 0.620) with rmse:7.571
# (k, beta, rho) = (11.000, 0.160, 0.640) with rmse:7.487
# (k, beta, rho) = (11.000, 0.160, 0.580) with rmse:7.298
# (k, beta, rho) = (11.000, 0.160, 0.680) with rmse:7.898
# (k, beta, rho) = (11.000, 0.160, 0.530) with rmse:7.618
# (k, beta, rho) = (11.000, 0.160, 0.730) with rmse:7.947
# (k, beta, rho) = (11.000, 0.260, 0.630) with rmse:24.765
# (k, beta, rho) = (11.000, 0.260, 0.620) with rmse:24.887
# (k, beta, rho) = (11.000, 0.260, 0.640) with rmse:24.516
# (k, beta, rho) = (11.000, 0.260, 0.580) with rmse:25.720
# (k, beta, rho) = (11.000, 0.260, 0.680) with rmse:24.078
# (k, beta, rho) = (11.000, 0.260, 0.530) with rmse:26.214
# (k, beta, rho) = (11.000, 0.260, 0.730) with rmse:23.486
# (k, beta, rho) = (11.000, 0.110, 0.630) with rmse:12.277
# (k, beta, rho) = (11.000, 0.110, 0.620) with rmse:12.292
# (k, beta, rho) = (11.000, 0.110, 0.640) with rmse:12.284
# (k, beta, rho) = (11.000, 0.110, 0.580) with rmse:12.314
# (k, beta, rho) = (11.000, 0.110, 0.680) with rmse:12.312
# (k, beta, rho) = (11.000, 0.110, 0.530) with rmse:11.988
# (k, beta, rho) = (11.000, 0.110, 0.730) with rmse:12.322
# (k, beta, rho) = (11.000, 0.310, 0.630) with rmse:39.090
# (k, beta, rho) = (11.000, 0.310, 0.620) with rmse:39.214
# (k, beta, rho) = (11.000, 0.310, 0.640) with rmse:38.880
# (k, beta, rho) = (11.000, 0.310, 0.580) with rmse:40.011
# (k, beta, rho) = (11.000, 0.310, 0.680) with rmse:38.495
# (k, beta, rho) = (11.000, 0.310, 0.530) with rmse:40.457
# (k, beta, rho) = (11.000, 0.310, 0.730) with rmse:37.789
# I'm moving...
# (k, beta, rho)=(9, 0.21, 0.62) tabu

# %% [markdown]
# Once again, now that the new simulation has found the best configuration of $(k, \beta, \rho)$, we can run the best simulation of the H1N1 pandemic in Sweden 2009. Specifically:
# 1. initialize our best configuration of parameters;
# 2. generate a new random graph with the best k we found;
# 3. simulate our pandemic once again, for 15 weeks, considering 100 iterations to have more stable results.

# %%
# 1) Best paramters (k, beta, rho)
#best_k_beta_rho = best_sol
best_k_beta_rho = [9, 0.21, 0.55]
print("Our best parameters (k, beta, rho) =", best_k_beta_rho)

# 2) Generate a new random graph with the new k 
random_G = generate_random_graph(best_k_beta_rho[0], pandemic["N"])

# 3) Our best simulation
# Increase number of steps to have more stable results
pandemic["n_steps"] = 100

# Simulation loop
simulations = simulate_pandemic(random_G, best_k_beta_rho[1], best_k_beta_rho[2], 
                                pandemic["n_steps"], pandemic["n_weeks"],
                                pandemic["I0"][0], pandemic["n_states"], pandemic["vax_scheme"])
# Out:
# Our best parameters (k, beta, rho) = [9, 0.21, 0.55]

# %% [markdown]
# We can plot the average number of newly infected individuals each week according to the model (with your best parameters) compared to the true value of newly infected individuals each week.

# %%
simulation_week_i = np.zeros([pandemic["n_steps"], pandemic["n_weeks"]])

for i in range(simulations.shape[0]):
    
    cases_i = np.zeros(simulations[i].shape[0])
    
    for case in range(simulations[i].shape[0]):
                
        if case == 0:
            cases_i[case] = int(np.argwhere(simulations[i, case] == 1).shape[0])
        
        else:
            cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i,case-1]<simulations[i,case]) ) ).shape[0]) 
    
    simulation_week_i[i] =  cases_i
    
avg_x_week = np.mean(simulation_week_i ,axis=0)

plt.figure(figsize = (8 ,5))
plt.plot(range(pandemic["n_weeks"]), avg_x_week, label="predicted") 
plt.plot(range(pandemic["n_weeks"]), pandemic["I0"], label = "actual") 
plt.xlabel("week")
plt.ylabel("cases")
plt.grid()
weeks_plot = [x for x in range(42, 53)] + [x for x in range(1,6)]
plt.xticks(range(pandemic["n_weeks"]), weeks_plot)
plt.legend()
plt.savefig("5-1.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 5.2) A better random graph
# Now that we have foudn a better algorithm, we will define a new method to define a random graph without the preferential attachment of the exercise 4. Notice that, once again, we are trying to represent the network for the pandemic in the most accurate way in order to have the predicted behavior in line with the actual one.
#
# This method is based on the **Small World** graphic representation offered by `networkx`.

# %%
initial_combination = [[params["k0"], params["beta0"], params["rho0"]]]
temp_sol, temp_rmse, _ = tabu_search_algorithm(initial_combination, pandemic, "sw")
best_sol, best_rmse = temp_sol, temp_rmse 

tabu_list = []
n_iter = 0
print("Starting...")

# Loop of deltas reduction search
while n_iter < 15: 
    print("iteration {}...".format(n_iter))
    
    # If the taboo list length is equal to the maximum one remove the first element
    if len(tabu_list) == 25:
        tabu_list.pop(0)
        
    # Generate the neighborhood
    list_neighbors = neighbors(temp_sol)
    
    # Evalute the neighborhood and get the best one with a list of indexes sorted by the RMSE
    temp_sol, temp_rmse, sorted_index = tabu_search_algorithm(list_neighbors,  pandemic, "sw")
    
    # If a better solution is found update
    if temp_rmse < best_rmse: 
        best_sol, best_rmse = temp_sol, temp_rmse 
        print("NEW BEST (k, beta, rho)={} with rmse = {:.3f}]".format(best_sol, best_rmse))
    
    # if no better solution is found prepare a taboo move
    else :
        
        # take a new solution if is note in taboo list 
        for i_s in sorted_index:
            temp_sol = list_neighbors[i_s]
            
            if temp_sol not in tabu_list:
                break
                
        # update the taboo list
        print("Tabu move")
        tabu_list.append(temp_sol)
        print("(k, beta, rho)=({}, {}, {})TABU".format(temp_sol[0], temp_sol[1], temp_sol[2]))
        
    n_iter += 1
# Out:
# (k, beta, rho) = (10.000, 0.300, 0.600) with rmse:31.947
# Starting...
# iteration 0...
# (k, beta, rho) = (9.000, 0.300, 0.600) with rmse:10.130
# (k, beta, rho) = (9.000, 0.300, 0.590) with rmse:11.804
# (k, beta, rho) = (9.000, 0.300, 0.610) with rmse:19.244
# (k, beta, rho) = (9.000, 0.300, 0.550) with rmse:14.001
# (k, beta, rho) = (9.000, 0.300, 0.650) with rmse:13.685
# (k, beta, rho) = (9.000, 0.300, 0.500) with rmse:16.948
# (k, beta, rho) = (9.000, 0.300, 0.700) with rmse:14.435
# (k, beta, rho) = (9.000, 0.290, 0.600) with rmse:13.190
# (k, beta, rho) = (9.000, 0.290, 0.590) with rmse:14.227
# (k, beta, rho) = (9.000, 0.290, 0.610) with rmse:14.854
# (k, beta, rho) = (9.000, 0.290, 0.550) with rmse:16.106
# (k, beta, rho) = (9.000, 0.290, 0.650) with rmse:15.773
# (k, beta, rho) = (9.000, 0.290, 0.500) with rmse:19.540
# (k, beta, rho) = (9.000, 0.290, 0.700) with rmse:12.261
# (k, beta, rho) = (9.000, 0.310, 0.600) with rmse:23.603
# (k, beta, rho) = (9.000, 0.310, 0.590) with rmse:12.886
# (k, beta, rho) = (9.000, 0.310, 0.610) with rmse:13.938
# (k, beta, rho) = (9.000, 0.310, 0.550) with rmse:8.259
# (k, beta, rho) = (9.000, 0.310, 0.650) with rmse:21.847
# (k, beta, rho) = (9.000, 0.310, 0.500) with rmse:16.995
# (k, beta, rho) = (9.000, 0.310, 0.700) with rmse:15.455
# (k, beta, rho) = (9.000, 0.250, 0.600) with rmse:10.731
# (k, beta, rho) = (9.000, 0.250, 0.590) with rmse:10.868
# (k, beta, rho) = (9.000, 0.250, 0.610) with rmse:9.996
# (k, beta, rho) = (9.000, 0.250, 0.550) with rmse:10.346
# (k, beta, rho) = (9.000, 0.250, 0.650) with rmse:9.009
# (k, beta, rho) = (9.000, 0.250, 0.500) with rmse:10.473
# (k, beta, rho) = (9.000, 0.250, 0.700) with rmse:8.099
# (k, beta, rho) = (9.000, 0.350, 0.600) with rmse:16.365
# (k, beta, rho) = (9.000, 0.350, 0.590) with rmse:25.695
# (k, beta, rho) = (9.000, 0.350, 0.610) with rmse:25.909
# (k, beta, rho) = (9.000, 0.350, 0.550) with rmse:26.486
# (k, beta, rho) = (9.000, 0.350, 0.650) with rmse:29.192
# (k, beta, rho) = (9.000, 0.350, 0.500) with rmse:26.567
# (k, beta, rho) = (9.000, 0.350, 0.700) with rmse:32.897
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:9.075
# (k, beta, rho) = (9.000, 0.200, 0.590) with rmse:9.609
# (k, beta, rho) = (9.000, 0.200, 0.610) with rmse:8.001
# (k, beta, rho) = (9.000, 0.200, 0.550) with rmse:9.002
# (k, beta, rho) = (9.000, 0.200, 0.650) with rmse:9.759
# (k, beta, rho) = (9.000, 0.200, 0.500) with rmse:10.084
# (k, beta, rho) = (9.000, 0.200, 0.700) with rmse:10.900
# (k, beta, rho) = (9.000, 0.400, 0.600) with rmse:46.104
# (k, beta, rho) = (9.000, 0.400, 0.590) with rmse:24.427
# (k, beta, rho) = (9.000, 0.400, 0.610) with rmse:22.203
# (k, beta, rho) = (9.000, 0.400, 0.550) with rmse:36.135
# (k, beta, rho) = (9.000, 0.400, 0.650) with rmse:40.173
# (k, beta, rho) = (9.000, 0.400, 0.500) with rmse:38.225
# (k, beta, rho) = (9.000, 0.400, 0.700) with rmse:29.015
# (k, beta, rho) = (8.000, 0.300, 0.600) with rmse:11.663
# (k, beta, rho) = (8.000, 0.300, 0.590) with rmse:19.214
# (k, beta, rho) = (8.000, 0.300, 0.610) with rmse:15.700
# (k, beta, rho) = (8.000, 0.300, 0.550) with rmse:13.446
# (k, beta, rho) = (8.000, 0.300, 0.650) with rmse:18.373
# (k, beta, rho) = (8.000, 0.300, 0.500) with rmse:15.701
# (k, beta, rho) = (8.000, 0.300, 0.700) with rmse:13.989
# (k, beta, rho) = (8.000, 0.290, 0.600) with rmse:17.132
# (k, beta, rho) = (8.000, 0.290, 0.590) with rmse:15.550
# (k, beta, rho) = (8.000, 0.290, 0.610) with rmse:17.425
# (k, beta, rho) = (8.000, 0.290, 0.550) with rmse:14.699
# (k, beta, rho) = (8.000, 0.290, 0.650) with rmse:13.012
# (k, beta, rho) = (8.000, 0.290, 0.500) with rmse:16.581
# (k, beta, rho) = (8.000, 0.290, 0.700) with rmse:12.763
# (k, beta, rho) = (8.000, 0.310, 0.600) with rmse:20.013
# (k, beta, rho) = (8.000, 0.310, 0.590) with rmse:16.742
# (k, beta, rho) = (8.000, 0.310, 0.610) with rmse:14.827
# (k, beta, rho) = (8.000, 0.310, 0.550) with rmse:14.509
# (k, beta, rho) = (8.000, 0.310, 0.650) with rmse:17.318
# (k, beta, rho) = (8.000, 0.310, 0.500) with rmse:15.765
# (k, beta, rho) = (8.000, 0.310, 0.700) with rmse:15.729
# (k, beta, rho) = (8.000, 0.250, 0.600) with rmse:11.240
# (k, beta, rho) = (8.000, 0.250, 0.590) with rmse:10.787
# (k, beta, rho) = (8.000, 0.250, 0.610) with rmse:9.359
# (k, beta, rho) = (8.000, 0.250, 0.550) with rmse:9.283
# (k, beta, rho) = (8.000, 0.250, 0.650) with rmse:8.997
# (k, beta, rho) = (8.000, 0.250, 0.500) with rmse:8.408
# (k, beta, rho) = (8.000, 0.250, 0.700) with rmse:8.417
# (k, beta, rho) = (8.000, 0.350, 0.600) with rmse:19.579
# (k, beta, rho) = (8.000, 0.350, 0.590) with rmse:24.208
# (k, beta, rho) = (8.000, 0.350, 0.610) with rmse:25.179
# (k, beta, rho) = (8.000, 0.350, 0.550) with rmse:20.263
# (k, beta, rho) = (8.000, 0.350, 0.650) with rmse:22.132
# (k, beta, rho) = (8.000, 0.350, 0.500) with rmse:23.941
# (k, beta, rho) = (8.000, 0.350, 0.700) with rmse:21.924
# (k, beta, rho) = (8.000, 0.200, 0.600) with rmse:10.865
# (k, beta, rho) = (8.000, 0.200, 0.590) with rmse:9.817
# (k, beta, rho) = (8.000, 0.200, 0.610) with rmse:10.127
# (k, beta, rho) = (8.000, 0.200, 0.550) with rmse:9.858
# (k, beta, rho) = (8.000, 0.200, 0.650) with rmse:8.639
# (k, beta, rho) = (8.000, 0.200, 0.500) with rmse:9.274
# (k, beta, rho) = (8.000, 0.200, 0.700) with rmse:8.324
# (k, beta, rho) = (8.000, 0.400, 0.600) with rmse:41.705
# (k, beta, rho) = (8.000, 0.400, 0.590) with rmse:43.851
# (k, beta, rho) = (8.000, 0.400, 0.610) with rmse:40.755
# (k, beta, rho) = (8.000, 0.400, 0.550) with rmse:32.557
# (k, beta, rho) = (8.000, 0.400, 0.650) with rmse:29.012
# (k, beta, rho) = (8.000, 0.400, 0.500) with rmse:32.855
# (k, beta, rho) = (8.000, 0.400, 0.700) with rmse:35.167
# (k, beta, rho) = (10.000, 0.300, 0.590) with rmse:24.809
# (k, beta, rho) = (10.000, 0.300, 0.610) with rmse:26.249
# (k, beta, rho) = (10.000, 0.300, 0.550) with rmse:27.209
# (k, beta, rho) = (10.000, 0.300, 0.650) with rmse:29.733
# (k, beta, rho) = (10.000, 0.300, 0.500) with rmse:32.333
# (k, beta, rho) = (10.000, 0.300, 0.700) with rmse:16.254
# (k, beta, rho) = (10.000, 0.290, 0.600) with rmse:24.002
# (k, beta, rho) = (10.000, 0.290, 0.590) with rmse:27.720
# (k, beta, rho) = (10.000, 0.290, 0.610) with rmse:20.571
# (k, beta, rho) = (10.000, 0.290, 0.550) with rmse:35.489
# (k, beta, rho) = (10.000, 0.290, 0.650) with rmse:19.580
# (k, beta, rho) = (10.000, 0.290, 0.500) with rmse:35.274
# (k, beta, rho) = (10.000, 0.290, 0.700) with rmse:22.818
# (k, beta, rho) = (10.000, 0.310, 0.600) with rmse:29.348
# (k, beta, rho) = (10.000, 0.310, 0.590) with rmse:25.008
# (k, beta, rho) = (10.000, 0.310, 0.610) with rmse:34.202
# (k, beta, rho) = (10.000, 0.310, 0.550) with rmse:36.884
# (k, beta, rho) = (10.000, 0.310, 0.650) with rmse:32.859
# (k, beta, rho) = (10.000, 0.310, 0.500) with rmse:43.188
# (k, beta, rho) = (10.000, 0.310, 0.700) with rmse:30.286
# (k, beta, rho) = (10.000, 0.250, 0.600) with rmse:20.398
# (k, beta, rho) = (10.000, 0.250, 0.590) with rmse:24.092
# (k, beta, rho) = (10.000, 0.250, 0.610) with rmse:12.730
# (k, beta, rho) = (10.000, 0.250, 0.550) with rmse:20.395
# (k, beta, rho) = (10.000, 0.250, 0.650) with rmse:20.084
# (k, beta, rho) = (10.000, 0.250, 0.500) with rmse:22.316
# (k, beta, rho) = (10.000, 0.250, 0.700) with rmse:19.824
# (k, beta, rho) = (10.000, 0.350, 0.600) with rmse:54.306
# (k, beta, rho) = (10.000, 0.350, 0.590) with rmse:38.662
# (k, beta, rho) = (10.000, 0.350, 0.610) with rmse:40.367
# (k, beta, rho) = (10.000, 0.350, 0.550) with rmse:37.972
# (k, beta, rho) = (10.000, 0.350, 0.650) with rmse:36.679
# (k, beta, rho) = (10.000, 0.350, 0.500) with rmse:43.081
# (k, beta, rho) = (10.000, 0.350, 0.700) with rmse:38.726
# (k, beta, rho) = (10.000, 0.200, 0.600) with rmse:11.518
# (k, beta, rho) = (10.000, 0.200, 0.590) with rmse:12.244
# (k, beta, rho) = (10.000, 0.200, 0.610) with rmse:10.912
# (k, beta, rho) = (10.000, 0.200, 0.550) with rmse:12.139
# (k, beta, rho) = (10.000, 0.200, 0.650) with rmse:10.645
# (k, beta, rho) = (10.000, 0.200, 0.500) with rmse:10.055
# (k, beta, rho) = (10.000, 0.200, 0.700) with rmse:7.700
# (k, beta, rho) = (10.000, 0.400, 0.600) with rmse:60.585
# (k, beta, rho) = (10.000, 0.400, 0.590) with rmse:57.652
# (k, beta, rho) = (10.000, 0.400, 0.610) with rmse:57.571
# (k, beta, rho) = (10.000, 0.400, 0.550) with rmse:56.443
# (k, beta, rho) = (10.000, 0.400, 0.650) with rmse:55.828
# (k, beta, rho) = (10.000, 0.400, 0.500) with rmse:49.849
# (k, beta, rho) = (10.000, 0.400, 0.700) with rmse:62.945
# (k, beta, rho) = (11.000, 0.300, 0.600) with rmse:30.299
# (k, beta, rho) = (11.000, 0.300, 0.590) with rmse:33.522
# (k, beta, rho) = (11.000, 0.300, 0.610) with rmse:30.253
# (k, beta, rho) = (11.000, 0.300, 0.550) with rmse:32.886
# (k, beta, rho) = (11.000, 0.300, 0.650) with rmse:14.530
# (k, beta, rho) = (11.000, 0.300, 0.500) with rmse:36.840
# (k, beta, rho) = (11.000, 0.300, 0.700) with rmse:28.317
# (k, beta, rho) = (11.000, 0.290, 0.600) with rmse:25.826
# (k, beta, rho) = (11.000, 0.290, 0.590) with rmse:27.126
# (k, beta, rho) = (11.000, 0.290, 0.610) with rmse:25.113
# (k, beta, rho) = (11.000, 0.290, 0.550) with rmse:20.679
# (k, beta, rho) = (11.000, 0.290, 0.650) with rmse:26.582
# (k, beta, rho) = (11.000, 0.290, 0.500) with rmse:29.018
# (k, beta, rho) = (11.000, 0.290, 0.700) with rmse:23.855
# (k, beta, rho) = (11.000, 0.310, 0.600) with rmse:42.355
# (k, beta, rho) = (11.000, 0.310, 0.590) with rmse:35.253
# (k, beta, rho) = (11.000, 0.310, 0.610) with rmse:39.988
# (k, beta, rho) = (11.000, 0.310, 0.550) with rmse:41.357
# (k, beta, rho) = (11.000, 0.310, 0.650) with rmse:33.387
# (k, beta, rho) = (11.000, 0.310, 0.500) with rmse:41.971
# (k, beta, rho) = (11.000, 0.310, 0.700) with rmse:33.816
# (k, beta, rho) = (11.000, 0.250, 0.600) with rmse:25.657
# (k, beta, rho) = (11.000, 0.250, 0.590) with rmse:18.031
# (k, beta, rho) = (11.000, 0.250, 0.610) with rmse:20.947
# (k, beta, rho) = (11.000, 0.250, 0.550) with rmse:14.819
# (k, beta, rho) = (11.000, 0.250, 0.650) with rmse:9.782
# (k, beta, rho) = (11.000, 0.250, 0.500) with rmse:26.437
# (k, beta, rho) = (11.000, 0.250, 0.700) with rmse:18.648
# (k, beta, rho) = (11.000, 0.350, 0.600) with rmse:47.119
# (k, beta, rho) = (11.000, 0.350, 0.590) with rmse:33.886
# (k, beta, rho) = (11.000, 0.350, 0.610) with rmse:42.839
# (k, beta, rho) = (11.000, 0.350, 0.550) with rmse:51.692
# (k, beta, rho) = (11.000, 0.350, 0.650) with rmse:41.036
# (k, beta, rho) = (11.000, 0.350, 0.500) with rmse:46.877
# (k, beta, rho) = (11.000, 0.350, 0.700) with rmse:45.313
# (k, beta, rho) = (11.000, 0.200, 0.600) with rmse:9.239
# (k, beta, rho) = (11.000, 0.200, 0.590) with rmse:9.298
# (k, beta, rho) = (11.000, 0.200, 0.610) with rmse:11.647
# (k, beta, rho) = (11.000, 0.200, 0.550) with rmse:13.670
# (k, beta, rho) = (11.000, 0.200, 0.650) with rmse:9.587
# (k, beta, rho) = (11.000, 0.200, 0.500) with rmse:13.648
# (k, beta, rho) = (11.000, 0.200, 0.700) with rmse:8.189
# (k, beta, rho) = (11.000, 0.400, 0.600) with rmse:61.603
# (k, beta, rho) = (11.000, 0.400, 0.590) with rmse:40.816
# (k, beta, rho) = (11.000, 0.400, 0.610) with rmse:49.959
# (k, beta, rho) = (11.000, 0.400, 0.550) with rmse:56.329
# (k, beta, rho) = (11.000, 0.400, 0.650) with rmse:44.045
# (k, beta, rho) = (11.000, 0.400, 0.500) with rmse:52.860
# (k, beta, rho) = (11.000, 0.400, 0.700) with rmse:60.495
# (k, beta, rho) = (12.000, 0.300, 0.600) with rmse:44.428
# (k, beta, rho) = (12.000, 0.300, 0.590) with rmse:46.732
# (k, beta, rho) = (12.000, 0.300, 0.610) with rmse:50.247
# (k, beta, rho) = (12.000, 0.300, 0.550) with rmse:46.534
# (k, beta, rho) = (12.000, 0.300, 0.650) with rmse:42.254
# (k, beta, rho) = (12.000, 0.300, 0.500) with rmse:50.855
# (k, beta, rho) = (12.000, 0.300, 0.700) with rmse:39.371
# (k, beta, rho) = (12.000, 0.290, 0.600) with rmse:39.597
# (k, beta, rho) = (12.000, 0.290, 0.590) with rmse:44.694
# (k, beta, rho) = (12.000, 0.290, 0.610) with rmse:46.874
# (k, beta, rho) = (12.000, 0.290, 0.550) with rmse:49.657
# (k, beta, rho) = (12.000, 0.290, 0.650) with rmse:48.193
# (k, beta, rho) = (12.000, 0.290, 0.500) with rmse:46.678
# (k, beta, rho) = (12.000, 0.290, 0.700) with rmse:40.684
# (k, beta, rho) = (12.000, 0.310, 0.600) with rmse:56.192
# (k, beta, rho) = (12.000, 0.310, 0.590) with rmse:37.120
# (k, beta, rho) = (12.000, 0.310, 0.610) with rmse:55.708
# (k, beta, rho) = (12.000, 0.310, 0.550) with rmse:52.980
# (k, beta, rho) = (12.000, 0.310, 0.650) with rmse:58.235
# (k, beta, rho) = (12.000, 0.310, 0.500) with rmse:57.440
# (k, beta, rho) = (12.000, 0.310, 0.700) with rmse:51.231
# (k, beta, rho) = (12.000, 0.250, 0.600) with rmse:35.627
# (k, beta, rho) = (12.000, 0.250, 0.590) with rmse:30.677
# (k, beta, rho) = (12.000, 0.250, 0.610) with rmse:26.298
# (k, beta, rho) = (12.000, 0.250, 0.550) with rmse:27.051
# (k, beta, rho) = (12.000, 0.250, 0.650) with rmse:32.213
# (k, beta, rho) = (12.000, 0.250, 0.500) with rmse:38.662
# (k, beta, rho) = (12.000, 0.250, 0.700) with rmse:29.600
# (k, beta, rho) = (12.000, 0.350, 0.600) with rmse:48.953
# (k, beta, rho) = (12.000, 0.350, 0.590) with rmse:68.592
# (k, beta, rho) = (12.000, 0.350, 0.610) with rmse:69.808
# (k, beta, rho) = (12.000, 0.350, 0.550) with rmse:52.924
# (k, beta, rho) = (12.000, 0.350, 0.650) with rmse:60.936
# (k, beta, rho) = (12.000, 0.350, 0.500) with rmse:72.918
# (k, beta, rho) = (12.000, 0.350, 0.700) with rmse:59.377
# (k, beta, rho) = (12.000, 0.200, 0.600) with rmse:15.671
# (k, beta, rho) = (12.000, 0.200, 0.590) with rmse:24.541
# (k, beta, rho) = (12.000, 0.200, 0.610) with rmse:11.309
# (k, beta, rho) = (12.000, 0.200, 0.550) with rmse:10.154
# (k, beta, rho) = (12.000, 0.200, 0.650) with rmse:15.325
# (k, beta, rho) = (12.000, 0.200, 0.500) with rmse:15.590
# (k, beta, rho) = (12.000, 0.200, 0.700) with rmse:18.600
# (k, beta, rho) = (12.000, 0.400, 0.600) with rmse:67.456
# (k, beta, rho) = (12.000, 0.400, 0.590) with rmse:76.399
# (k, beta, rho) = (12.000, 0.400, 0.610) with rmse:67.264
# (k, beta, rho) = (12.000, 0.400, 0.550) with rmse:69.085
# (k, beta, rho) = (12.000, 0.400, 0.650) with rmse:68.519
# (k, beta, rho) = (12.000, 0.400, 0.500) with rmse:60.574
# (k, beta, rho) = (12.000, 0.400, 0.700) with rmse:78.541
# NEW BEST (k, beta, rho)=[10, 0.2, 0.7] with rmse = 7.700]
# iteration 1...
# (k, beta, rho) = (9.000, 0.200, 0.700) with rmse:9.744
# (k, beta, rho) = (9.000, 0.200, 0.690) with rmse:8.469
# (k, beta, rho) = (9.000, 0.200, 0.710) with rmse:9.956
# (k, beta, rho) = (9.000, 0.200, 0.650) with rmse:8.395
# (k, beta, rho) = (9.000, 0.200, 0.750) with rmse:9.715
# (k, beta, rho) = (9.000, 0.200, 0.600) with rmse:8.728
# (k, beta, rho) = (9.000, 0.200, 0.800) with rmse:10.977
# (k, beta, rho) = (9.000, 0.190, 0.700) with rmse:11.607
# (k, beta, rho) = (9.000, 0.190, 0.690) with rmse:7.718
# (k, beta, rho) = (9.000, 0.190, 0.710) with rmse:11.949
# (k, beta, rho) = (9.000, 0.190, 0.650) with rmse:9.796
# (k, beta, rho) = (9.000, 0.190, 0.750) with rmse:10.693
# (k, beta, rho) = (9.000, 0.190, 0.600) with rmse:9.211
# (k, beta, rho) = (9.000, 0.190, 0.800) with rmse:11.217
# (k, beta, rho) = (9.000, 0.210, 0.700) with rmse:8.187
# (k, beta, rho) = (9.000, 0.210, 0.690) with rmse:8.395
# (k, beta, rho) = (9.000, 0.210, 0.710) with rmse:8.217
# (k, beta, rho) = (9.000, 0.210, 0.650) with rmse:9.224
# (k, beta, rho) = (9.000, 0.210, 0.750) with rmse:10.448
# (k, beta, rho) = (9.000, 0.210, 0.600) with rmse:8.075
# (k, beta, rho) = (9.000, 0.210, 0.800) with rmse:10.033
# (k, beta, rho) = (9.000, 0.150, 0.700) with rmse:12.058
# (k, beta, rho) = (9.000, 0.150, 0.690) with rmse:12.805
# (k, beta, rho) = (9.000, 0.150, 0.710) with rmse:12.118
# (k, beta, rho) = (9.000, 0.150, 0.650) with rmse:11.606
# (k, beta, rho) = (9.000, 0.150, 0.750) with rmse:12.960
# (k, beta, rho) = (9.000, 0.150, 0.600) with rmse:11.974
# (k, beta, rho) = (9.000, 0.150, 0.800) with rmse:12.411
# (k, beta, rho) = (9.000, 0.250, 0.700) with rmse:8.090
# (k, beta, rho) = (9.000, 0.250, 0.690) with rmse:8.228
# (k, beta, rho) = (9.000, 0.250, 0.710) with rmse:8.313
# (k, beta, rho) = (9.000, 0.250, 0.650) with rmse:10.167
# (k, beta, rho) = (9.000, 0.250, 0.750) with rmse:8.346
# (k, beta, rho) = (9.000, 0.250, 0.600) with rmse:8.498
# (k, beta, rho) = (9.000, 0.250, 0.800) with rmse:6.982
# (k, beta, rho) = (9.000, 0.100, 0.700) with rmse:13.461
# (k, beta, rho) = (9.000, 0.100, 0.690) with rmse:13.514
# (k, beta, rho) = (9.000, 0.100, 0.710) with rmse:13.201
# (k, beta, rho) = (9.000, 0.100, 0.650) with rmse:13.100
# (k, beta, rho) = (9.000, 0.100, 0.750) with rmse:13.552
# (k, beta, rho) = (9.000, 0.100, 0.600) with rmse:12.934
# (k, beta, rho) = (9.000, 0.100, 0.800) with rmse:13.387
# (k, beta, rho) = (9.000, 0.300, 0.700) with rmse:9.899
# (k, beta, rho) = (9.000, 0.300, 0.690) with rmse:13.022
# (k, beta, rho) = (9.000, 0.300, 0.710) with rmse:10.817
# (k, beta, rho) = (9.000, 0.300, 0.650) with rmse:16.491
# (k, beta, rho) = (9.000, 0.300, 0.750) with rmse:15.242
# (k, beta, rho) = (9.000, 0.300, 0.600) with rmse:10.094
# (k, beta, rho) = (9.000, 0.300, 0.800) with rmse:13.679
# (k, beta, rho) = (8.000, 0.200, 0.700) with rmse:9.555
# (k, beta, rho) = (8.000, 0.200, 0.690) with rmse:10.447
# (k, beta, rho) = (8.000, 0.200, 0.710) with rmse:9.243
# (k, beta, rho) = (8.000, 0.200, 0.650) with rmse:8.069
# (k, beta, rho) = (8.000, 0.200, 0.750) with rmse:10.353
# (k, beta, rho) = (8.000, 0.200, 0.600) with rmse:9.158
# (k, beta, rho) = (8.000, 0.200, 0.800) with rmse:9.948
# (k, beta, rho) = (8.000, 0.190, 0.700) with rmse:12.572
# (k, beta, rho) = (8.000, 0.190, 0.690) with rmse:11.020
# (k, beta, rho) = (8.000, 0.190, 0.710) with rmse:10.172
# (k, beta, rho) = (8.000, 0.190, 0.650) with rmse:10.287
# (k, beta, rho) = (8.000, 0.190, 0.750) with rmse:11.092
# (k, beta, rho) = (8.000, 0.190, 0.600) with rmse:10.417
# (k, beta, rho) = (8.000, 0.190, 0.800) with rmse:12.294
# (k, beta, rho) = (8.000, 0.210, 0.700) with rmse:9.236
# (k, beta, rho) = (8.000, 0.210, 0.690) with rmse:8.817
# (k, beta, rho) = (8.000, 0.210, 0.710) with rmse:10.285
# (k, beta, rho) = (8.000, 0.210, 0.650) with rmse:7.667
# (k, beta, rho) = (8.000, 0.210, 0.750) with rmse:8.195
# (k, beta, rho) = (8.000, 0.210, 0.600) with rmse:8.113
# (k, beta, rho) = (8.000, 0.210, 0.800) with rmse:7.626
# (k, beta, rho) = (8.000, 0.150, 0.700) with rmse:12.223
# (k, beta, rho) = (8.000, 0.150, 0.690) with rmse:12.634
# (k, beta, rho) = (8.000, 0.150, 0.710) with rmse:12.709
# (k, beta, rho) = (8.000, 0.150, 0.650) with rmse:12.306
# (k, beta, rho) = (8.000, 0.150, 0.750) with rmse:11.958
# (k, beta, rho) = (8.000, 0.150, 0.600) with rmse:12.315
# (k, beta, rho) = (8.000, 0.150, 0.800) with rmse:13.217
# (k, beta, rho) = (8.000, 0.250, 0.700) with rmse:7.077
# (k, beta, rho) = (8.000, 0.250, 0.690) with rmse:9.575
# (k, beta, rho) = (8.000, 0.250, 0.710) with rmse:8.969
# (k, beta, rho) = (8.000, 0.250, 0.650) with rmse:8.720
# (k, beta, rho) = (8.000, 0.250, 0.750) with rmse:7.299
# (k, beta, rho) = (8.000, 0.250, 0.600) with rmse:8.906
# (k, beta, rho) = (8.000, 0.250, 0.800) with rmse:8.398
# (k, beta, rho) = (8.000, 0.100, 0.700) with rmse:13.567
# (k, beta, rho) = (8.000, 0.100, 0.690) with rmse:13.176
# (k, beta, rho) = (8.000, 0.100, 0.710) with rmse:13.360
# (k, beta, rho) = (8.000, 0.100, 0.650) with rmse:13.445
# (k, beta, rho) = (8.000, 0.100, 0.750) with rmse:13.319
# (k, beta, rho) = (8.000, 0.100, 0.600) with rmse:13.113
# (k, beta, rho) = (8.000, 0.100, 0.800) with rmse:13.436
# (k, beta, rho) = (8.000, 0.300, 0.700) with rmse:11.160
# (k, beta, rho) = (8.000, 0.300, 0.690) with rmse:12.368
# (k, beta, rho) = (8.000, 0.300, 0.710) with rmse:10.906
# (k, beta, rho) = (8.000, 0.300, 0.650) with rmse:17.683
# (k, beta, rho) = (8.000, 0.300, 0.750) with rmse:8.296
# (k, beta, rho) = (8.000, 0.300, 0.600) with rmse:13.894
# (k, beta, rho) = (8.000, 0.300, 0.800) with rmse:10.187
# (k, beta, rho) = (10.000, 0.200, 0.690) with rmse:8.481
# (k, beta, rho) = (10.000, 0.200, 0.710) with rmse:9.293
# (k, beta, rho) = (10.000, 0.200, 0.650) with rmse:7.795
# (k, beta, rho) = (10.000, 0.200, 0.750) with rmse:8.565
# (k, beta, rho) = (10.000, 0.200, 0.600) with rmse:9.570
# (k, beta, rho) = (10.000, 0.200, 0.800) with rmse:7.452
# (k, beta, rho) = (10.000, 0.190, 0.700) with rmse:6.230
# (k, beta, rho) = (10.000, 0.190, 0.690) with rmse:9.582
# (k, beta, rho) = (10.000, 0.190, 0.710) with rmse:9.151
# (k, beta, rho) = (10.000, 0.190, 0.650) with rmse:10.434
# (k, beta, rho) = (10.000, 0.190, 0.750) with rmse:7.932
# (k, beta, rho) = (10.000, 0.190, 0.600) with rmse:9.306
# (k, beta, rho) = (10.000, 0.190, 0.800) with rmse:7.882
# (k, beta, rho) = (10.000, 0.210, 0.700) with rmse:8.352
# (k, beta, rho) = (10.000, 0.210, 0.690) with rmse:9.336
# (k, beta, rho) = (10.000, 0.210, 0.710) with rmse:9.030
# (k, beta, rho) = (10.000, 0.210, 0.650) with rmse:11.626
# (k, beta, rho) = (10.000, 0.210, 0.750) with rmse:7.622
# (k, beta, rho) = (10.000, 0.210, 0.600) with rmse:9.735
# (k, beta, rho) = (10.000, 0.210, 0.800) with rmse:6.165
# (k, beta, rho) = (10.000, 0.150, 0.700) with rmse:8.673
# (k, beta, rho) = (10.000, 0.150, 0.690) with rmse:11.237
# (k, beta, rho) = (10.000, 0.150, 0.710) with rmse:10.399
# (k, beta, rho) = (10.000, 0.150, 0.650) with rmse:10.390
# (k, beta, rho) = (10.000, 0.150, 0.750) with rmse:9.873
# (k, beta, rho) = (10.000, 0.150, 0.600) with rmse:10.861
# (k, beta, rho) = (10.000, 0.150, 0.800) with rmse:9.403
# (k, beta, rho) = (10.000, 0.250, 0.700) with rmse:19.504
# (k, beta, rho) = (10.000, 0.250, 0.690) with rmse:15.268
# (k, beta, rho) = (10.000, 0.250, 0.710) with rmse:14.088
# (k, beta, rho) = (10.000, 0.250, 0.650) with rmse:14.489
# (k, beta, rho) = (10.000, 0.250, 0.750) with rmse:15.921
# (k, beta, rho) = (10.000, 0.250, 0.600) with rmse:19.666
# (k, beta, rho) = (10.000, 0.250, 0.800) with rmse:18.623
# (k, beta, rho) = (10.000, 0.100, 0.700) with rmse:12.745
# (k, beta, rho) = (10.000, 0.100, 0.690) with rmse:12.537
# (k, beta, rho) = (10.000, 0.100, 0.710) with rmse:13.236
# (k, beta, rho) = (10.000, 0.100, 0.650) with rmse:12.829
# (k, beta, rho) = (10.000, 0.100, 0.750) with rmse:13.169
# (k, beta, rho) = (10.000, 0.100, 0.600) with rmse:12.421
# (k, beta, rho) = (10.000, 0.100, 0.800) with rmse:13.313
# (k, beta, rho) = (10.000, 0.300, 0.700) with rmse:27.829
# (k, beta, rho) = (10.000, 0.300, 0.690) with rmse:30.199
# (k, beta, rho) = (10.000, 0.300, 0.710) with rmse:31.024
# (k, beta, rho) = (10.000, 0.300, 0.650) with rmse:29.392
# (k, beta, rho) = (10.000, 0.300, 0.750) with rmse:23.157
# (k, beta, rho) = (10.000, 0.300, 0.600) with rmse:34.913
# (k, beta, rho) = (10.000, 0.300, 0.800) with rmse:30.622
# (k, beta, rho) = (11.000, 0.200, 0.700) with rmse:7.542
# (k, beta, rho) = (11.000, 0.200, 0.690) with rmse:8.466
# (k, beta, rho) = (11.000, 0.200, 0.710) with rmse:8.098
# (k, beta, rho) = (11.000, 0.200, 0.650) with rmse:8.106
# (k, beta, rho) = (11.000, 0.200, 0.750) with rmse:6.119
# (k, beta, rho) = (11.000, 0.200, 0.600) with rmse:13.087
# (k, beta, rho) = (11.000, 0.200, 0.800) with rmse:7.405
# (k, beta, rho) = (11.000, 0.190, 0.700) with rmse:7.785
# (k, beta, rho) = (11.000, 0.190, 0.690) with rmse:7.450
# (k, beta, rho) = (11.000, 0.190, 0.710) with rmse:6.981
# (k, beta, rho) = (11.000, 0.190, 0.650) with rmse:8.896
# (k, beta, rho) = (11.000, 0.190, 0.750) with rmse:9.432
# (k, beta, rho) = (11.000, 0.190, 0.600) with rmse:7.715
# (k, beta, rho) = (11.000, 0.190, 0.800) with rmse:7.304
# (k, beta, rho) = (11.000, 0.210, 0.700) with rmse:10.824
# (k, beta, rho) = (11.000, 0.210, 0.690) with rmse:10.001
# (k, beta, rho) = (11.000, 0.210, 0.710) with rmse:12.078
# (k, beta, rho) = (11.000, 0.210, 0.650) with rmse:8.375
# (k, beta, rho) = (11.000, 0.210, 0.750) with rmse:9.853
# (k, beta, rho) = (11.000, 0.210, 0.600) with rmse:10.277
# (k, beta, rho) = (11.000, 0.210, 0.800) with rmse:9.760
# (k, beta, rho) = (11.000, 0.150, 0.700) with rmse:8.954
# (k, beta, rho) = (11.000, 0.150, 0.690) with rmse:11.212
# (k, beta, rho) = (11.000, 0.150, 0.710) with rmse:10.948
# (k, beta, rho) = (11.000, 0.150, 0.650) with rmse:7.775
# (k, beta, rho) = (11.000, 0.150, 0.750) with rmse:10.737
# (k, beta, rho) = (11.000, 0.150, 0.600) with rmse:10.291
# (k, beta, rho) = (11.000, 0.150, 0.800) with rmse:11.713
# (k, beta, rho) = (11.000, 0.250, 0.700) with rmse:19.624
# (k, beta, rho) = (11.000, 0.250, 0.690) with rmse:16.189
# (k, beta, rho) = (11.000, 0.250, 0.710) with rmse:14.974
# (k, beta, rho) = (11.000, 0.250, 0.650) with rmse:15.740
# (k, beta, rho) = (11.000, 0.250, 0.750) with rmse:14.299
# (k, beta, rho) = (11.000, 0.250, 0.600) with rmse:17.736
# (k, beta, rho) = (11.000, 0.250, 0.800) with rmse:16.479
# (k, beta, rho) = (11.000, 0.100, 0.700) with rmse:13.183
# (k, beta, rho) = (11.000, 0.100, 0.690) with rmse:13.080
# (k, beta, rho) = (11.000, 0.100, 0.710) with rmse:13.492
# (k, beta, rho) = (11.000, 0.100, 0.650) with rmse:12.616
# (k, beta, rho) = (11.000, 0.100, 0.750) with rmse:13.201
# (k, beta, rho) = (11.000, 0.100, 0.600) with rmse:12.979
# (k, beta, rho) = (11.000, 0.100, 0.800) with rmse:12.859
# (k, beta, rho) = (11.000, 0.300, 0.700) with rmse:27.625
# (k, beta, rho) = (11.000, 0.300, 0.690) with rmse:35.531
# (k, beta, rho) = (11.000, 0.300, 0.710) with rmse:37.759
# (k, beta, rho) = (11.000, 0.300, 0.650) with rmse:37.645
# (k, beta, rho) = (11.000, 0.300, 0.750) with rmse:32.183
# (k, beta, rho) = (11.000, 0.300, 0.600) with rmse:25.777
# (k, beta, rho) = (11.000, 0.300, 0.800) with rmse:28.192
# (k, beta, rho) = (12.000, 0.200, 0.700) with rmse:14.211
# (k, beta, rho) = (12.000, 0.200, 0.690) with rmse:16.946
# (k, beta, rho) = (12.000, 0.200, 0.710) with rmse:17.405
# (k, beta, rho) = (12.000, 0.200, 0.650) with rmse:11.552
# (k, beta, rho) = (12.000, 0.200, 0.750) with rmse:12.438
# (k, beta, rho) = (12.000, 0.200, 0.600) with rmse:17.795
# (k, beta, rho) = (12.000, 0.200, 0.800) with rmse:19.616
# (k, beta, rho) = (12.000, 0.190, 0.700) with rmse:8.337
# (k, beta, rho) = (12.000, 0.190, 0.690) with rmse:13.028
# (k, beta, rho) = (12.000, 0.190, 0.710) with rmse:12.561
# (k, beta, rho) = (12.000, 0.190, 0.650) with rmse:15.915
# (k, beta, rho) = (12.000, 0.190, 0.750) with rmse:10.956
# (k, beta, rho) = (12.000, 0.190, 0.600) with rmse:18.113
# (k, beta, rho) = (12.000, 0.190, 0.800) with rmse:9.319
# (k, beta, rho) = (12.000, 0.210, 0.700) with rmse:16.667
# (k, beta, rho) = (12.000, 0.210, 0.690) with rmse:21.013
# (k, beta, rho) = (12.000, 0.210, 0.710) with rmse:19.585
# (k, beta, rho) = (12.000, 0.210, 0.650) with rmse:11.569
# (k, beta, rho) = (12.000, 0.210, 0.750) with rmse:20.555
# (k, beta, rho) = (12.000, 0.210, 0.600) with rmse:23.784
# (k, beta, rho) = (12.000, 0.210, 0.800) with rmse:16.291
# (k, beta, rho) = (12.000, 0.150, 0.700) with rmse:7.621
# (k, beta, rho) = (12.000, 0.150, 0.690) with rmse:7.813
# (k, beta, rho) = (12.000, 0.150, 0.710) with rmse:7.954
# (k, beta, rho) = (12.000, 0.150, 0.650) with rmse:9.950
# (k, beta, rho) = (12.000, 0.150, 0.750) with rmse:5.967
# (k, beta, rho) = (12.000, 0.150, 0.600) with rmse:11.182
# (k, beta, rho) = (12.000, 0.150, 0.800) with rmse:10.458
# (k, beta, rho) = (12.000, 0.250, 0.700) with rmse:32.479
# (k, beta, rho) = (12.000, 0.250, 0.690) with rmse:33.199
# (k, beta, rho) = (12.000, 0.250, 0.710) with rmse:31.280
# (k, beta, rho) = (12.000, 0.250, 0.650) with rmse:31.301
# (k, beta, rho) = (12.000, 0.250, 0.750) with rmse:31.026
# (k, beta, rho) = (12.000, 0.250, 0.600) with rmse:37.211
# (k, beta, rho) = (12.000, 0.250, 0.800) with rmse:28.845
# (k, beta, rho) = (12.000, 0.100, 0.700) with rmse:11.538
# (k, beta, rho) = (12.000, 0.100, 0.690) with rmse:11.052
# (k, beta, rho) = (12.000, 0.100, 0.710) with rmse:12.040
# (k, beta, rho) = (12.000, 0.100, 0.650) with rmse:12.485
# (k, beta, rho) = (12.000, 0.100, 0.750) with rmse:11.578
# (k, beta, rho) = (12.000, 0.100, 0.600) with rmse:11.216
# (k, beta, rho) = (12.000, 0.100, 0.800) with rmse:13.052
# (k, beta, rho) = (12.000, 0.300, 0.700) with rmse:55.011
# (k, beta, rho) = (12.000, 0.300, 0.690) with rmse:45.707
# (k, beta, rho) = (12.000, 0.300, 0.710) with rmse:45.243
# (k, beta, rho) = (12.000, 0.300, 0.650) with rmse:40.609
# (k, beta, rho) = (12.000, 0.300, 0.750) with rmse:44.481
# (k, beta, rho) = (12.000, 0.300, 0.600) with rmse:54.228
# (k, beta, rho) = (12.000, 0.300, 0.800) with rmse:51.014
# NEW BEST (k, beta, rho)=[12, 0.15, 0.75] with rmse = 5.967]
# iteration 2...
# (k, beta, rho) = (11.000, 0.150, 0.750) with rmse:9.930
# (k, beta, rho) = (11.000, 0.150, 0.740) with rmse:10.565
# (k, beta, rho) = (11.000, 0.150, 0.760) with rmse:9.620
# (k, beta, rho) = (11.000, 0.150, 0.700) with rmse:10.849
# (k, beta, rho) = (11.000, 0.150, 0.800) with rmse:10.140
# (k, beta, rho) = (11.000, 0.150, 0.650) with rmse:9.223
# (k, beta, rho) = (11.000, 0.150, 0.850) with rmse:12.025
# (k, beta, rho) = (11.000, 0.140, 0.750) with rmse:11.052
# (k, beta, rho) = (11.000, 0.140, 0.740) with rmse:11.088
# (k, beta, rho) = (11.000, 0.140, 0.760) with rmse:11.754
# (k, beta, rho) = (11.000, 0.140, 0.700) with rmse:10.578
# (k, beta, rho) = (11.000, 0.140, 0.800) with rmse:11.081
# (k, beta, rho) = (11.000, 0.140, 0.650) with rmse:11.450
# (k, beta, rho) = (11.000, 0.140, 0.850) with rmse:11.670
# (k, beta, rho) = (11.000, 0.160, 0.750) with rmse:8.353
# (k, beta, rho) = (11.000, 0.160, 0.740) with rmse:7.706
# (k, beta, rho) = (11.000, 0.160, 0.760) with rmse:9.034
# (k, beta, rho) = (11.000, 0.160, 0.700) with rmse:7.925
# (k, beta, rho) = (11.000, 0.160, 0.800) with rmse:9.069
# (k, beta, rho) = (11.000, 0.160, 0.650) with rmse:9.687
# (k, beta, rho) = (11.000, 0.160, 0.850) with rmse:9.134
# (k, beta, rho) = (11.000, 0.100, 0.750) with rmse:13.085
# (k, beta, rho) = (11.000, 0.100, 0.740) with rmse:13.230
# (k, beta, rho) = (11.000, 0.100, 0.760) with rmse:13.050
# (k, beta, rho) = (11.000, 0.100, 0.700) with rmse:13.089
# (k, beta, rho) = (11.000, 0.100, 0.800) with rmse:13.257
# (k, beta, rho) = (11.000, 0.100, 0.650) with rmse:13.136
# (k, beta, rho) = (11.000, 0.100, 0.850) with rmse:13.344
# (k, beta, rho) = (11.000, 0.200, 0.750) with rmse:7.195
# (k, beta, rho) = (11.000, 0.200, 0.740) with rmse:10.146
# (k, beta, rho) = (11.000, 0.200, 0.760) with rmse:7.869
# (k, beta, rho) = (11.000, 0.200, 0.700) with rmse:8.795
# (k, beta, rho) = (11.000, 0.200, 0.800) with rmse:7.302
# (k, beta, rho) = (11.000, 0.200, 0.650) with rmse:8.710
# (k, beta, rho) = (11.000, 0.200, 0.850) with rmse:7.354
# (k, beta, rho) = (11.000, 0.050, 0.750) with rmse:13.581
# (k, beta, rho) = (11.000, 0.050, 0.740) with rmse:13.571
# (k, beta, rho) = (11.000, 0.050, 0.760) with rmse:13.593
# (k, beta, rho) = (11.000, 0.050, 0.700) with rmse:13.572
# (k, beta, rho) = (11.000, 0.050, 0.800) with rmse:13.516
# (k, beta, rho) = (11.000, 0.050, 0.650) with rmse:13.493
# (k, beta, rho) = (11.000, 0.050, 0.850) with rmse:13.585
# (k, beta, rho) = (11.000, 0.250, 0.750) with rmse:20.812
# (k, beta, rho) = (11.000, 0.250, 0.740) with rmse:9.798
# (k, beta, rho) = (11.000, 0.250, 0.760) with rmse:19.266
# (k, beta, rho) = (11.000, 0.250, 0.700) with rmse:23.524
# (k, beta, rho) = (11.000, 0.250, 0.800) with rmse:16.729
# (k, beta, rho) = (11.000, 0.250, 0.650) with rmse:21.773
# (k, beta, rho) = (11.000, 0.250, 0.850) with rmse:16.829
# (k, beta, rho) = (10.000, 0.150, 0.750) with rmse:9.595
# (k, beta, rho) = (10.000, 0.150, 0.740) with rmse:11.890
# (k, beta, rho) = (10.000, 0.150, 0.760) with rmse:11.505
# (k, beta, rho) = (10.000, 0.150, 0.700) with rmse:10.339
# (k, beta, rho) = (10.000, 0.150, 0.800) with rmse:10.775
# (k, beta, rho) = (10.000, 0.150, 0.650) with rmse:10.880
# (k, beta, rho) = (10.000, 0.150, 0.850) with rmse:11.272
# (k, beta, rho) = (10.000, 0.140, 0.750) with rmse:10.027
# (k, beta, rho) = (10.000, 0.140, 0.740) with rmse:10.721
# (k, beta, rho) = (10.000, 0.140, 0.760) with rmse:10.612
# (k, beta, rho) = (10.000, 0.140, 0.700) with rmse:12.312
# (k, beta, rho) = (10.000, 0.140, 0.800) with rmse:11.680
# (k, beta, rho) = (10.000, 0.140, 0.650) with rmse:9.752
# (k, beta, rho) = (10.000, 0.140, 0.850) with rmse:11.690
# (k, beta, rho) = (10.000, 0.160, 0.750) with rmse:10.412
# (k, beta, rho) = (10.000, 0.160, 0.740) with rmse:10.755
# (k, beta, rho) = (10.000, 0.160, 0.760) with rmse:9.669
# (k, beta, rho) = (10.000, 0.160, 0.700) with rmse:8.451
# (k, beta, rho) = (10.000, 0.160, 0.800) with rmse:8.967
# (k, beta, rho) = (10.000, 0.160, 0.650) with rmse:9.374
# (k, beta, rho) = (10.000, 0.160, 0.850) with rmse:10.481
# (k, beta, rho) = (10.000, 0.100, 0.750) with rmse:13.266
# (k, beta, rho) = (10.000, 0.100, 0.740) with rmse:13.135
# (k, beta, rho) = (10.000, 0.100, 0.760) with rmse:13.239
# (k, beta, rho) = (10.000, 0.100, 0.700) with rmse:12.739
# (k, beta, rho) = (10.000, 0.100, 0.800) with rmse:13.086
# (k, beta, rho) = (10.000, 0.100, 0.650) with rmse:13.323
# (k, beta, rho) = (10.000, 0.100, 0.850) with rmse:13.416
# (k, beta, rho) = (10.000, 0.200, 0.750) with rmse:8.982
# (k, beta, rho) = (10.000, 0.200, 0.740) with rmse:7.776
# (k, beta, rho) = (10.000, 0.200, 0.760) with rmse:7.932
# (k, beta, rho) = (10.000, 0.200, 0.700) with rmse:7.639
# (k, beta, rho) = (10.000, 0.200, 0.800) with rmse:8.550
# (k, beta, rho) = (10.000, 0.200, 0.650) with rmse:9.393
# (k, beta, rho) = (10.000, 0.200, 0.850) with rmse:7.752
# (k, beta, rho) = (10.000, 0.050, 0.750) with rmse:13.481
# (k, beta, rho) = (10.000, 0.050, 0.740) with rmse:13.515
# (k, beta, rho) = (10.000, 0.050, 0.760) with rmse:13.578
# (k, beta, rho) = (10.000, 0.050, 0.700) with rmse:13.584
# (k, beta, rho) = (10.000, 0.050, 0.800) with rmse:13.567
# (k, beta, rho) = (10.000, 0.050, 0.650) with rmse:13.577
# (k, beta, rho) = (10.000, 0.050, 0.850) with rmse:13.506
# (k, beta, rho) = (10.000, 0.250, 0.750) with rmse:10.123
# (k, beta, rho) = (10.000, 0.250, 0.740) with rmse:13.866
# (k, beta, rho) = (10.000, 0.250, 0.760) with rmse:10.013
# (k, beta, rho) = (10.000, 0.250, 0.700) with rmse:18.338
# (k, beta, rho) = (10.000, 0.250, 0.800) with rmse:14.990
# (k, beta, rho) = (10.000, 0.250, 0.650) with rmse:17.512
# (k, beta, rho) = (10.000, 0.250, 0.850) with rmse:13.602
# (k, beta, rho) = (12.000, 0.150, 0.740) with rmse:9.840
# (k, beta, rho) = (12.000, 0.150, 0.760) with rmse:6.235
# (k, beta, rho) = (12.000, 0.150, 0.700) with rmse:8.790
# (k, beta, rho) = (12.000, 0.150, 0.800) with rmse:7.863
# (k, beta, rho) = (12.000, 0.150, 0.650) with rmse:8.919
# (k, beta, rho) = (12.000, 0.150, 0.850) with rmse:7.492
# (k, beta, rho) = (12.000, 0.140, 0.750) with rmse:7.926
# (k, beta, rho) = (12.000, 0.140, 0.740) with rmse:9.120
# (k, beta, rho) = (12.000, 0.140, 0.760) with rmse:8.073
# (k, beta, rho) = (12.000, 0.140, 0.700) with rmse:8.304
# (k, beta, rho) = (12.000, 0.140, 0.800) with rmse:8.034
# (k, beta, rho) = (12.000, 0.140, 0.650) with rmse:10.574
# (k, beta, rho) = (12.000, 0.140, 0.850) with rmse:9.741
# (k, beta, rho) = (12.000, 0.160, 0.750) with rmse:7.802
# (k, beta, rho) = (12.000, 0.160, 0.740) with rmse:9.588
# (k, beta, rho) = (12.000, 0.160, 0.760) with rmse:9.519
# (k, beta, rho) = (12.000, 0.160, 0.700) with rmse:8.414
# (k, beta, rho) = (12.000, 0.160, 0.800) with rmse:5.978
# (k, beta, rho) = (12.000, 0.160, 0.650) with rmse:8.723
# (k, beta, rho) = (12.000, 0.160, 0.850) with rmse:6.788
# (k, beta, rho) = (12.000, 0.100, 0.750) with rmse:12.712
# (k, beta, rho) = (12.000, 0.100, 0.740) with rmse:12.496
# (k, beta, rho) = (12.000, 0.100, 0.760) with rmse:11.118
# (k, beta, rho) = (12.000, 0.100, 0.700) with rmse:11.668
# (k, beta, rho) = (12.000, 0.100, 0.800) with rmse:11.571
# (k, beta, rho) = (12.000, 0.100, 0.650) with rmse:12.352
# (k, beta, rho) = (12.000, 0.100, 0.850) with rmse:12.515
# (k, beta, rho) = (12.000, 0.200, 0.750) with rmse:12.421
# (k, beta, rho) = (12.000, 0.200, 0.740) with rmse:10.573
# (k, beta, rho) = (12.000, 0.200, 0.760) with rmse:16.852
# (k, beta, rho) = (12.000, 0.200, 0.700) with rmse:17.806
# (k, beta, rho) = (12.000, 0.200, 0.800) with rmse:17.263
# (k, beta, rho) = (12.000, 0.200, 0.650) with rmse:15.739
# (k, beta, rho) = (12.000, 0.200, 0.850) with rmse:11.045
# (k, beta, rho) = (12.000, 0.050, 0.750) with rmse:13.490
# (k, beta, rho) = (12.000, 0.050, 0.740) with rmse:13.565
# (k, beta, rho) = (12.000, 0.050, 0.760) with rmse:13.534
# (k, beta, rho) = (12.000, 0.050, 0.700) with rmse:13.401
# (k, beta, rho) = (12.000, 0.050, 0.800) with rmse:13.582
# (k, beta, rho) = (12.000, 0.050, 0.650) with rmse:13.530
# (k, beta, rho) = (12.000, 0.050, 0.850) with rmse:13.547
# (k, beta, rho) = (12.000, 0.250, 0.750) with rmse:37.212
# (k, beta, rho) = (12.000, 0.250, 0.740) with rmse:32.281
# (k, beta, rho) = (12.000, 0.250, 0.760) with rmse:41.810
# (k, beta, rho) = (12.000, 0.250, 0.700) with rmse:36.402
# (k, beta, rho) = (12.000, 0.250, 0.800) with rmse:33.436
# (k, beta, rho) = (12.000, 0.250, 0.650) with rmse:30.356
# (k, beta, rho) = (12.000, 0.250, 0.850) with rmse:27.658
# (k, beta, rho) = (13.000, 0.150, 0.750) with rmse:7.693
# (k, beta, rho) = (13.000, 0.150, 0.740) with rmse:7.612
# (k, beta, rho) = (13.000, 0.150, 0.760) with rmse:5.899
# (k, beta, rho) = (13.000, 0.150, 0.700) with rmse:7.887
# (k, beta, rho) = (13.000, 0.150, 0.800) with rmse:8.209
# (k, beta, rho) = (13.000, 0.150, 0.650) with rmse:8.221
# (k, beta, rho) = (13.000, 0.150, 0.850) with rmse:6.967
# (k, beta, rho) = (13.000, 0.140, 0.750) with rmse:9.801
# (k, beta, rho) = (13.000, 0.140, 0.740) with rmse:9.263
# (k, beta, rho) = (13.000, 0.140, 0.760) with rmse:8.026
# (k, beta, rho) = (13.000, 0.140, 0.700) with rmse:8.262
# (k, beta, rho) = (13.000, 0.140, 0.800) with rmse:7.923
# (k, beta, rho) = (13.000, 0.140, 0.650) with rmse:8.675
# (k, beta, rho) = (13.000, 0.140, 0.850) with rmse:8.190
# (k, beta, rho) = (13.000, 0.160, 0.750) with rmse:8.159
# (k, beta, rho) = (13.000, 0.160, 0.740) with rmse:5.831
# (k, beta, rho) = (13.000, 0.160, 0.760) with rmse:6.065
# (k, beta, rho) = (13.000, 0.160, 0.700) with rmse:8.465
# (k, beta, rho) = (13.000, 0.160, 0.800) with rmse:7.088
# (k, beta, rho) = (13.000, 0.160, 0.650) with rmse:9.791
# (k, beta, rho) = (13.000, 0.160, 0.850) with rmse:6.274
# (k, beta, rho) = (13.000, 0.100, 0.750) with rmse:12.143
# (k, beta, rho) = (13.000, 0.100, 0.740) with rmse:11.493
# (k, beta, rho) = (13.000, 0.100, 0.760) with rmse:12.424
# (k, beta, rho) = (13.000, 0.100, 0.700) with rmse:11.723
# (k, beta, rho) = (13.000, 0.100, 0.800) with rmse:12.829
# (k, beta, rho) = (13.000, 0.100, 0.650) with rmse:11.667
# (k, beta, rho) = (13.000, 0.100, 0.850) with rmse:12.899
# (k, beta, rho) = (13.000, 0.200, 0.750) with rmse:10.530
# (k, beta, rho) = (13.000, 0.200, 0.740) with rmse:12.305
# (k, beta, rho) = (13.000, 0.200, 0.760) with rmse:14.375
# (k, beta, rho) = (13.000, 0.200, 0.700) with rmse:17.761
# (k, beta, rho) = (13.000, 0.200, 0.800) with rmse:11.308
# (k, beta, rho) = (13.000, 0.200, 0.650) with rmse:23.513
# (k, beta, rho) = (13.000, 0.200, 0.850) with rmse:12.765
# (k, beta, rho) = (13.000, 0.050, 0.750) with rmse:13.564
# (k, beta, rho) = (13.000, 0.050, 0.740) with rmse:13.549
# (k, beta, rho) = (13.000, 0.050, 0.760) with rmse:13.573
# (k, beta, rho) = (13.000, 0.050, 0.700) with rmse:13.349
# (k, beta, rho) = (13.000, 0.050, 0.800) with rmse:13.361
# (k, beta, rho) = (13.000, 0.050, 0.650) with rmse:13.425
# (k, beta, rho) = (13.000, 0.050, 0.850) with rmse:13.578
# (k, beta, rho) = (13.000, 0.250, 0.750) with rmse:24.525
# (k, beta, rho) = (13.000, 0.250, 0.740) with rmse:26.839
# (k, beta, rho) = (13.000, 0.250, 0.760) with rmse:35.776
# (k, beta, rho) = (13.000, 0.250, 0.700) with rmse:33.123
# (k, beta, rho) = (13.000, 0.250, 0.800) with rmse:35.706
# (k, beta, rho) = (13.000, 0.250, 0.650) with rmse:34.518
# (k, beta, rho) = (13.000, 0.250, 0.850) with rmse:30.444
# (k, beta, rho) = (14.000, 0.150, 0.750) with rmse:7.459
# (k, beta, rho) = (14.000, 0.150, 0.740) with rmse:9.053
# (k, beta, rho) = (14.000, 0.150, 0.760) with rmse:8.949
# (k, beta, rho) = (14.000, 0.150, 0.700) with rmse:12.123
# (k, beta, rho) = (14.000, 0.150, 0.800) with rmse:8.106
# (k, beta, rho) = (14.000, 0.150, 0.650) with rmse:10.913
# (k, beta, rho) = (14.000, 0.150, 0.850) with rmse:6.790
# (k, beta, rho) = (14.000, 0.140, 0.750) with rmse:8.215
# (k, beta, rho) = (14.000, 0.140, 0.740) with rmse:10.090
# (k, beta, rho) = (14.000, 0.140, 0.760) with rmse:8.553
# (k, beta, rho) = (14.000, 0.140, 0.700) with rmse:8.387
# (k, beta, rho) = (14.000, 0.140, 0.800) with rmse:5.794
# (k, beta, rho) = (14.000, 0.140, 0.650) with rmse:11.427
# (k, beta, rho) = (14.000, 0.140, 0.850) with rmse:7.803
# (k, beta, rho) = (14.000, 0.160, 0.750) with rmse:10.296
# (k, beta, rho) = (14.000, 0.160, 0.740) with rmse:11.711
# (k, beta, rho) = (14.000, 0.160, 0.760) with rmse:11.401
# (k, beta, rho) = (14.000, 0.160, 0.700) with rmse:15.100
# (k, beta, rho) = (14.000, 0.160, 0.800) with rmse:11.193
# (k, beta, rho) = (14.000, 0.160, 0.650) with rmse:15.088
# (k, beta, rho) = (14.000, 0.160, 0.850) with rmse:9.248
# (k, beta, rho) = (14.000, 0.100, 0.750) with rmse:11.076
# (k, beta, rho) = (14.000, 0.100, 0.740) with rmse:10.442
# (k, beta, rho) = (14.000, 0.100, 0.760) with rmse:10.042
# (k, beta, rho) = (14.000, 0.100, 0.700) with rmse:11.048
# (k, beta, rho) = (14.000, 0.100, 0.800) with rmse:11.323
# (k, beta, rho) = (14.000, 0.100, 0.650) with rmse:10.452
# (k, beta, rho) = (14.000, 0.100, 0.850) with rmse:11.645
# (k, beta, rho) = (14.000, 0.200, 0.750) with rmse:28.895
# (k, beta, rho) = (14.000, 0.200, 0.740) with rmse:29.546
# (k, beta, rho) = (14.000, 0.200, 0.760) with rmse:33.869
# (k, beta, rho) = (14.000, 0.200, 0.700) with rmse:33.087
# (k, beta, rho) = (14.000, 0.200, 0.800) with rmse:22.848
# (k, beta, rho) = (14.000, 0.200, 0.650) with rmse:33.649
# (k, beta, rho) = (14.000, 0.200, 0.850) with rmse:27.492
# (k, beta, rho) = (14.000, 0.050, 0.750) with rmse:13.487
# (k, beta, rho) = (14.000, 0.050, 0.740) with rmse:13.542
# (k, beta, rho) = (14.000, 0.050, 0.760) with rmse:13.525
# (k, beta, rho) = (14.000, 0.050, 0.700) with rmse:13.369
# (k, beta, rho) = (14.000, 0.050, 0.800) with rmse:13.500
# (k, beta, rho) = (14.000, 0.050, 0.650) with rmse:13.333
# (k, beta, rho) = (14.000, 0.050, 0.850) with rmse:13.537
# (k, beta, rho) = (14.000, 0.250, 0.750) with rmse:46.780
# (k, beta, rho) = (14.000, 0.250, 0.740) with rmse:49.837
# (k, beta, rho) = (14.000, 0.250, 0.760) with rmse:51.364
# (k, beta, rho) = (14.000, 0.250, 0.700) with rmse:57.309
# (k, beta, rho) = (14.000, 0.250, 0.800) with rmse:47.917
# (k, beta, rho) = (14.000, 0.250, 0.650) with rmse:31.457
# (k, beta, rho) = (14.000, 0.250, 0.850) with rmse:41.358
# NEW BEST (k, beta, rho)=[14, 0.14, 0.8] with rmse = 5.794]
# iteration 3...
# (k, beta, rho) = (13.000, 0.140, 0.800) with rmse:9.546
# (k, beta, rho) = (13.000, 0.140, 0.790) with rmse:8.904
# (k, beta, rho) = (13.000, 0.140, 0.810) with rmse:9.765
# (k, beta, rho) = (13.000, 0.140, 0.750) with rmse:9.519
# (k, beta, rho) = (13.000, 0.140, 0.850) with rmse:8.302
# (k, beta, rho) = (13.000, 0.140, 0.700) with rmse:8.463
# (k, beta, rho) = (13.000, 0.140, 0.900) with rmse:9.745
# (k, beta, rho) = (13.000, 0.130, 0.800) with rmse:10.153
# (k, beta, rho) = (13.000, 0.130, 0.790) with rmse:10.553
# (k, beta, rho) = (13.000, 0.130, 0.810) with rmse:10.358
# (k, beta, rho) = (13.000, 0.130, 0.750) with rmse:8.361
# (k, beta, rho) = (13.000, 0.130, 0.850) with rmse:9.559
# (k, beta, rho) = (13.000, 0.130, 0.700) with rmse:9.678
# (k, beta, rho) = (13.000, 0.130, 0.900) with rmse:10.172
# (k, beta, rho) = (13.000, 0.150, 0.800) with rmse:6.322
# (k, beta, rho) = (13.000, 0.150, 0.790) with rmse:6.832
# (k, beta, rho) = (13.000, 0.150, 0.810) with rmse:8.536
# (k, beta, rho) = (13.000, 0.150, 0.750) with rmse:8.377
# (k, beta, rho) = (13.000, 0.150, 0.850) with rmse:7.383
# (k, beta, rho) = (13.000, 0.150, 0.700) with rmse:8.615
# (k, beta, rho) = (13.000, 0.150, 0.900) with rmse:8.690
# (k, beta, rho) = (13.000, 0.090, 0.800) with rmse:12.220
# (k, beta, rho) = (13.000, 0.090, 0.790) with rmse:13.474
# (k, beta, rho) = (13.000, 0.090, 0.810) with rmse:13.149
# (k, beta, rho) = (13.000, 0.090, 0.750) with rmse:12.950
# (k, beta, rho) = (13.000, 0.090, 0.850) with rmse:12.732
# (k, beta, rho) = (13.000, 0.090, 0.700) with rmse:12.762
# (k, beta, rho) = (13.000, 0.090, 0.900) with rmse:13.076
# (k, beta, rho) = (13.000, 0.190, 0.800) with rmse:11.752
# (k, beta, rho) = (13.000, 0.190, 0.790) with rmse:13.043
# (k, beta, rho) = (13.000, 0.190, 0.810) with rmse:11.556
# (k, beta, rho) = (13.000, 0.190, 0.750) with rmse:6.966
# (k, beta, rho) = (13.000, 0.190, 0.850) with rmse:17.655
# (k, beta, rho) = (13.000, 0.190, 0.700) with rmse:10.171
# (k, beta, rho) = (13.000, 0.190, 0.900) with rmse:13.679
# (k, beta, rho) = (13.000, 0.040, 0.800) with rmse:13.568
# (k, beta, rho) = (13.000, 0.040, 0.790) with rmse:13.568
# (k, beta, rho) = (13.000, 0.040, 0.810) with rmse:13.588
# (k, beta, rho) = (13.000, 0.040, 0.750) with rmse:13.573
# (k, beta, rho) = (13.000, 0.040, 0.850) with rmse:13.582
# (k, beta, rho) = (13.000, 0.040, 0.700) with rmse:13.534
# (k, beta, rho) = (13.000, 0.040, 0.900) with rmse:13.485
# (k, beta, rho) = (13.000, 0.240, 0.800) with rmse:31.603
# (k, beta, rho) = (13.000, 0.240, 0.790) with rmse:24.749
# (k, beta, rho) = (13.000, 0.240, 0.810) with rmse:31.903
# (k, beta, rho) = (13.000, 0.240, 0.750) with rmse:22.217
# (k, beta, rho) = (13.000, 0.240, 0.850) with rmse:22.358
# (k, beta, rho) = (13.000, 0.240, 0.700) with rmse:34.149
# (k, beta, rho) = (13.000, 0.240, 0.900) with rmse:23.417
# (k, beta, rho) = (12.000, 0.140, 0.800) with rmse:8.609
# (k, beta, rho) = (12.000, 0.140, 0.790) with rmse:8.337
# (k, beta, rho) = (12.000, 0.140, 0.810) with rmse:8.547
# (k, beta, rho) = (12.000, 0.140, 0.750) with rmse:7.747
# (k, beta, rho) = (12.000, 0.140, 0.850) with rmse:9.548
# (k, beta, rho) = (12.000, 0.140, 0.700) with rmse:7.597
# (k, beta, rho) = (12.000, 0.140, 0.900) with rmse:8.213
# (k, beta, rho) = (12.000, 0.130, 0.800) with rmse:11.373
# (k, beta, rho) = (12.000, 0.130, 0.790) with rmse:8.054
# (k, beta, rho) = (12.000, 0.130, 0.810) with rmse:8.980
# (k, beta, rho) = (12.000, 0.130, 0.750) with rmse:10.075
# (k, beta, rho) = (12.000, 0.130, 0.850) with rmse:9.957
# (k, beta, rho) = (12.000, 0.130, 0.700) with rmse:9.729
# (k, beta, rho) = (12.000, 0.130, 0.900) with rmse:9.175
# (k, beta, rho) = (12.000, 0.150, 0.800) with rmse:7.005
# (k, beta, rho) = (12.000, 0.150, 0.790) with rmse:10.995
# (k, beta, rho) = (12.000, 0.150, 0.810) with rmse:8.649
# (k, beta, rho) = (12.000, 0.150, 0.750) with rmse:6.730
# (k, beta, rho) = (12.000, 0.150, 0.850) with rmse:7.432
# (k, beta, rho) = (12.000, 0.150, 0.700) with rmse:7.338
# (k, beta, rho) = (12.000, 0.150, 0.900) with rmse:7.012
# (k, beta, rho) = (12.000, 0.090, 0.800) with rmse:12.299
# (k, beta, rho) = (12.000, 0.090, 0.790) with rmse:13.101
# (k, beta, rho) = (12.000, 0.090, 0.810) with rmse:12.747
# (k, beta, rho) = (12.000, 0.090, 0.750) with rmse:12.743
# (k, beta, rho) = (12.000, 0.090, 0.850) with rmse:13.100
# (k, beta, rho) = (12.000, 0.090, 0.700) with rmse:12.397
# (k, beta, rho) = (12.000, 0.090, 0.900) with rmse:12.762
# (k, beta, rho) = (12.000, 0.190, 0.800) with rmse:12.357
# (k, beta, rho) = (12.000, 0.190, 0.790) with rmse:9.727
# (k, beta, rho) = (12.000, 0.190, 0.810) with rmse:5.668
# (k, beta, rho) = (12.000, 0.190, 0.750) with rmse:12.110
# (k, beta, rho) = (12.000, 0.190, 0.850) with rmse:10.606
# (k, beta, rho) = (12.000, 0.190, 0.700) with rmse:18.876
# (k, beta, rho) = (12.000, 0.190, 0.900) with rmse:10.505
# (k, beta, rho) = (12.000, 0.040, 0.800) with rmse:13.591
# (k, beta, rho) = (12.000, 0.040, 0.790) with rmse:13.587
# (k, beta, rho) = (12.000, 0.040, 0.810) with rmse:13.515
# (k, beta, rho) = (12.000, 0.040, 0.750) with rmse:13.579
# (k, beta, rho) = (12.000, 0.040, 0.850) with rmse:13.588
# (k, beta, rho) = (12.000, 0.040, 0.700) with rmse:13.574
# (k, beta, rho) = (12.000, 0.040, 0.900) with rmse:13.588
# (k, beta, rho) = (12.000, 0.240, 0.800) with rmse:35.618
# (k, beta, rho) = (12.000, 0.240, 0.790) with rmse:36.008
# (k, beta, rho) = (12.000, 0.240, 0.810) with rmse:22.828
# (k, beta, rho) = (12.000, 0.240, 0.750) with rmse:23.604
# (k, beta, rho) = (12.000, 0.240, 0.850) with rmse:21.344
# (k, beta, rho) = (12.000, 0.240, 0.700) with rmse:28.267
# (k, beta, rho) = (12.000, 0.240, 0.900) with rmse:26.174
# (k, beta, rho) = (14.000, 0.140, 0.790) with rmse:9.001
# (k, beta, rho) = (14.000, 0.140, 0.810) with rmse:7.022
# (k, beta, rho) = (14.000, 0.140, 0.750) with rmse:7.775
# (k, beta, rho) = (14.000, 0.140, 0.850) with rmse:6.643
# (k, beta, rho) = (14.000, 0.140, 0.700) with rmse:8.345
# (k, beta, rho) = (14.000, 0.140, 0.900) with rmse:7.109
# (k, beta, rho) = (14.000, 0.130, 0.800) with rmse:7.289
# (k, beta, rho) = (14.000, 0.130, 0.790) with rmse:7.479
# (k, beta, rho) = (14.000, 0.130, 0.810) with rmse:6.808
# (k, beta, rho) = (14.000, 0.130, 0.750) with rmse:7.894
# (k, beta, rho) = (14.000, 0.130, 0.850) with rmse:6.628
# (k, beta, rho) = (14.000, 0.130, 0.700) with rmse:7.948
# (k, beta, rho) = (14.000, 0.130, 0.900) with rmse:6.173
# (k, beta, rho) = (14.000, 0.150, 0.800) with rmse:11.448
# ...
# (k, beta, rho) = (14.000, 0.170, 0.860) with rmse:7.205
# (k, beta, rho) = (14.000, 0.170, 0.850) with rmse:10.778
# (k, beta, rho) = (14.000, 0.170, 0.870) with rmse:14.733
# (k, beta, rho) = (14.000, 0.170, 0.810) with rmse:13.470
# (k, beta, rho) = (14.000, 0.170, 0.910) with rmse:13.877
# (k, beta, rho) = (14.000, 0.170, 0.760) with rmse:10.700
# (k, beta, rho) = (14.000, 0.170, 0.960) with rmse:15.029
# (k, beta, rho) = (14.000, 0.110, 0.860) with rmse:12.145
# (k, beta, rho) = (14.000, 0.110, 0.850) with rmse:10.356
# (k, beta, rho) = (14.000, 0.110, 0.870) with rmse:10.498
# (k, beta, rho) = (14.000, 0.110, 0.810) with rmse:9.115
# (k, beta, rho) = (14.000, 0.110, 0.910) with rmse:10.313
# (k, beta, rho) = (14.000, 0.110, 0.760) with rmse:9.808
# (k, beta, rho) = (14.000, 0.110, 0.960) with rmse:9.746
# (k, beta, rho) = (14.000, 0.210, 0.860) with rmse:34.515
# (k, beta, rho) = (14.000, 0.210, 0.850) with rmse:35.270
# (k, beta, rho) = (14.000, 0.210, 0.870) with rmse:33.618
# (k, beta, rho) = (14.000, 0.210, 0.810) with rmse:29.361
# (k, beta, rho) = (14.000, 0.210, 0.910) with rmse:30.882
# (k, beta, rho) = (14.000, 0.210, 0.760) with rmse:33.184
# (k, beta, rho) = (14.000, 0.210, 0.960) with rmse:25.848
# (k, beta, rho) = (14.000, 0.060, 0.860) with rmse:13.484
# (k, beta, rho) = (14.000, 0.060, 0.850) with rmse:13.558
# (k, beta, rho) = (14.000, 0.060, 0.870) with rmse:13.568
# (k, beta, rho) = (14.000, 0.060, 0.810) with rmse:13.117
# (k, beta, rho) = (14.000, 0.060, 0.910) with rmse:13.403
# (k, beta, rho) = (14.000, 0.060, 0.760) with rmse:13.348
# (k, beta, rho) = (14.000, 0.060, 0.960) with rmse:13.333
# (k, beta, rho) = (14.000, 0.260, 0.860) with rmse:51.243
# (k, beta, rho) = (14.000, 0.260, 0.850) with rmse:48.407
# (k, beta, rho) = (14.000, 0.260, 0.870) with rmse:41.240
# (k, beta, rho) = (14.000, 0.260, 0.810) with rmse:47.862
# (k, beta, rho) = (14.000, 0.260, 0.910) with rmse:42.533
# (k, beta, rho) = (14.000, 0.260, 0.760) with rmse:56.683
# (k, beta, rho) = (14.000, 0.260, 0.960) with rmse:45.210
# Tabu move
# (k, beta, rho)=(11, 0.21, 0.96)TABU
# iteration 12...
# (k, beta, rho) = (10.000, 0.210, 0.960) with rmse:6.735
# (k, beta, rho) = (10.000, 0.210, 0.950) with rmse:6.113
# (k, beta, rho) = (10.000, 0.210, 0.970) with rmse:6.402
# (k, beta, rho) = (10.000, 0.210, 0.910) with rmse:8.121
# (k, beta, rho) = (10.000, 0.210, 0.860) with rmse:6.466
# (k, beta, rho) = (10.000, 0.200, 0.960) with rmse:6.915
# (k, beta, rho) = (10.000, 0.200, 0.950) with rmse:7.666
# (k, beta, rho) = (10.000, 0.200, 0.970) with rmse:6.404
# (k, beta, rho) = (10.000, 0.200, 0.910) with rmse:7.657
# (k, beta, rho) = (10.000, 0.200, 0.860) with rmse:6.978
# (k, beta, rho) = (10.000, 0.220, 0.960) with rmse:6.539
# (k, beta, rho) = (10.000, 0.220, 0.950) with rmse:6.764
# (k, beta, rho) = (10.000, 0.220, 0.970) with rmse:6.949
# (k, beta, rho) = (10.000, 0.220, 0.910) with rmse:5.627
# (k, beta, rho) = (10.000, 0.220, 0.860) with rmse:7.021
# (k, beta, rho) = (10.000, 0.160, 0.960) with rmse:10.906
# (k, beta, rho) = (10.000, 0.160, 0.950) with rmse:10.854
# (k, beta, rho) = (10.000, 0.160, 0.970) with rmse:9.476
# (k, beta, rho) = (10.000, 0.160, 0.910) with rmse:9.851
# (k, beta, rho) = (10.000, 0.160, 0.860) with rmse:10.533
# (k, beta, rho) = (10.000, 0.260, 0.960) with rmse:17.462
# (k, beta, rho) = (10.000, 0.260, 0.950) with rmse:11.910
# (k, beta, rho) = (10.000, 0.260, 0.970) with rmse:14.180
# (k, beta, rho) = (10.000, 0.260, 0.910) with rmse:14.276
# (k, beta, rho) = (10.000, 0.260, 0.860) with rmse:18.867
# (k, beta, rho) = (10.000, 0.110, 0.960) with rmse:13.095
# (k, beta, rho) = (10.000, 0.110, 0.950) with rmse:13.407
# (k, beta, rho) = (10.000, 0.110, 0.970) with rmse:13.028
# (k, beta, rho) = (10.000, 0.110, 0.910) with rmse:13.481
# (k, beta, rho) = (10.000, 0.110, 0.860) with rmse:12.596
# (k, beta, rho) = (10.000, 0.310, 0.960) with rmse:22.689
# (k, beta, rho) = (10.000, 0.310, 0.950) with rmse:24.053
# (k, beta, rho) = (10.000, 0.310, 0.970) with rmse:32.075
# (k, beta, rho) = (10.000, 0.310, 0.910) with rmse:29.540
# (k, beta, rho) = (10.000, 0.310, 0.860) with rmse:17.717
# (k, beta, rho) = (9.000, 0.210, 0.960) with rmse:11.635
# (k, beta, rho) = (9.000, 0.210, 0.950) with rmse:10.719
# (k, beta, rho) = (9.000, 0.210, 0.970) with rmse:10.420
# (k, beta, rho) = (9.000, 0.210, 0.910) with rmse:10.657
# (k, beta, rho) = (9.000, 0.210, 0.860) with rmse:10.597
# (k, beta, rho) = (9.000, 0.200, 0.960) with rmse:10.828
# (k, beta, rho) = (9.000, 0.200, 0.950) with rmse:11.323
# (k, beta, rho) = (9.000, 0.200, 0.970) with rmse:12.229
# (k, beta, rho) = (9.000, 0.200, 0.910) with rmse:11.126
# (k, beta, rho) = (9.000, 0.200, 0.860) with rmse:10.228
# (k, beta, rho) = (9.000, 0.220, 0.960) with rmse:10.257
# (k, beta, rho) = (9.000, 0.220, 0.950) with rmse:9.541
# (k, beta, rho) = (9.000, 0.220, 0.970) with rmse:8.770
# (k, beta, rho) = (9.000, 0.220, 0.910) with rmse:9.753
# (k, beta, rho) = (9.000, 0.220, 0.860) with rmse:8.447
# (k, beta, rho) = (9.000, 0.160, 0.960) with rmse:13.229
# (k, beta, rho) = (9.000, 0.160, 0.950) with rmse:11.954
# (k, beta, rho) = (9.000, 0.160, 0.970) with rmse:13.476
# (k, beta, rho) = (9.000, 0.160, 0.910) with rmse:12.220
# (k, beta, rho) = (9.000, 0.160, 0.860) with rmse:12.659
# (k, beta, rho) = (9.000, 0.260, 0.960) with rmse:7.662
# (k, beta, rho) = (9.000, 0.260, 0.950) with rmse:5.434
# (k, beta, rho) = (9.000, 0.260, 0.970) with rmse:6.916
# (k, beta, rho) = (9.000, 0.260, 0.910) with rmse:5.937
# (k, beta, rho) = (9.000, 0.260, 0.860) with rmse:6.388
# (k, beta, rho) = (9.000, 0.110, 0.960) with rmse:13.523
# (k, beta, rho) = (9.000, 0.110, 0.950) with rmse:13.418
# (k, beta, rho) = (9.000, 0.110, 0.970) with rmse:13.356
# (k, beta, rho) = (9.000, 0.110, 0.910) with rmse:13.357
# (k, beta, rho) = (9.000, 0.110, 0.860) with rmse:13.293
# (k, beta, rho) = (9.000, 0.310, 0.960) with rmse:10.017
# (k, beta, rho) = (9.000, 0.310, 0.950) with rmse:7.659
# (k, beta, rho) = (9.000, 0.310, 0.970) with rmse:7.916
# (k, beta, rho) = (9.000, 0.310, 0.910) with rmse:8.118
# (k, beta, rho) = (9.000, 0.310, 0.860) with rmse:11.474
# (k, beta, rho) = (11.000, 0.210, 0.950) with rmse:6.404
# (k, beta, rho) = (11.000, 0.210, 0.970) with rmse:5.758
# (k, beta, rho) = (11.000, 0.210, 0.910) with rmse:6.834
# (k, beta, rho) = (11.000, 0.210, 0.860) with rmse:6.013
# (k, beta, rho) = (11.000, 0.200, 0.960) with rmse:6.575
# (k, beta, rho) = (11.000, 0.200, 0.950) with rmse:8.738
# (k, beta, rho) = (11.000, 0.200, 0.970) with rmse:6.736
# (k, beta, rho) = (11.000, 0.200, 0.910) with rmse:7.131
# (k, beta, rho) = (11.000, 0.200, 0.860) with rmse:7.659
# (k, beta, rho) = (11.000, 0.220, 0.960) with rmse:6.910
# (k, beta, rho) = (11.000, 0.220, 0.950) with rmse:6.047
# (k, beta, rho) = (11.000, 0.220, 0.970) with rmse:11.264
# (k, beta, rho) = (11.000, 0.220, 0.910) with rmse:6.990
# (k, beta, rho) = (11.000, 0.220, 0.860) with rmse:9.710
# (k, beta, rho) = (11.000, 0.160, 0.960) with rmse:11.408
# (k, beta, rho) = (11.000, 0.160, 0.950) with rmse:10.439
# (k, beta, rho) = (11.000, 0.160, 0.970) with rmse:9.978
# (k, beta, rho) = (11.000, 0.160, 0.910) with rmse:9.795
# (k, beta, rho) = (11.000, 0.160, 0.860) with rmse:12.182
# (k, beta, rho) = (11.000, 0.260, 0.960) with rmse:14.118
# (k, beta, rho) = (11.000, 0.260, 0.950) with rmse:10.528
# (k, beta, rho) = (11.000, 0.260, 0.970) with rmse:10.613
# (k, beta, rho) = (11.000, 0.260, 0.910) with rmse:10.516
# (k, beta, rho) = (11.000, 0.260, 0.860) with rmse:17.412
# (k, beta, rho) = (11.000, 0.110, 0.960) with rmse:13.299
# (k, beta, rho) = (11.000, 0.110, 0.950) with rmse:13.181
# (k, beta, rho) = (11.000, 0.110, 0.970) with rmse:13.059
# (k, beta, rho) = (11.000, 0.110, 0.910) with rmse:13.272
# (k, beta, rho) = (11.000, 0.110, 0.860) with rmse:13.253
# (k, beta, rho) = (11.000, 0.310, 0.960) with rmse:23.627
# (k, beta, rho) = (11.000, 0.310, 0.950) with rmse:32.975
# (k, beta, rho) = (11.000, 0.310, 0.970) with rmse:31.471
# (k, beta, rho) = (11.000, 0.310, 0.910) with rmse:32.432
# (k, beta, rho) = (11.000, 0.310, 0.860) with rmse:22.332
# (k, beta, rho) = (12.000, 0.210, 0.960) with rmse:9.691
# (k, beta, rho) = (12.000, 0.210, 0.950) with rmse:14.907
# (k, beta, rho) = (12.000, 0.210, 0.970) with rmse:13.505
# (k, beta, rho) = (12.000, 0.210, 0.910) with rmse:9.091
# (k, beta, rho) = (12.000, 0.210, 0.860) with rmse:13.624
# (k, beta, rho) = (12.000, 0.200, 0.960) with rmse:16.479
# (k, beta, rho) = (12.000, 0.200, 0.950) with rmse:4.725
# (k, beta, rho) = (12.000, 0.200, 0.970) with rmse:12.419
# (k, beta, rho) = (12.000, 0.200, 0.910) with rmse:8.634
# (k, beta, rho) = (12.000, 0.200, 0.860) with rmse:9.488
# (k, beta, rho) = (12.000, 0.220, 0.960) with rmse:20.615
# (k, beta, rho) = (12.000, 0.220, 0.950) with rmse:13.217
# (k, beta, rho) = (12.000, 0.220, 0.970) with rmse:15.462
# (k, beta, rho) = (12.000, 0.220, 0.910) with rmse:13.015
# (k, beta, rho) = (12.000, 0.220, 0.860) with rmse:17.499
# (k, beta, rho) = (12.000, 0.160, 0.960) with rmse:9.097
# (k, beta, rho) = (12.000, 0.160, 0.950) with rmse:8.494
# (k, beta, rho) = (12.000, 0.160, 0.970) with rmse:7.161
# (k, beta, rho) = (12.000, 0.160, 0.910) with rmse:5.671
# (k, beta, rho) = (12.000, 0.160, 0.860) with rmse:6.689
# (k, beta, rho) = (12.000, 0.260, 0.960) with rmse:31.397
# (k, beta, rho) = (12.000, 0.260, 0.950) with rmse:26.880
# (k, beta, rho) = (12.000, 0.260, 0.970) with rmse:23.814
# (k, beta, rho) = (12.000, 0.260, 0.910) with rmse:29.162
# (k, beta, rho) = (12.000, 0.260, 0.860) with rmse:34.555
# (k, beta, rho) = (12.000, 0.110, 0.960) with rmse:12.690
# (k, beta, rho) = (12.000, 0.110, 0.950) with rmse:10.284
# (k, beta, rho) = (12.000, 0.110, 0.970) with rmse:12.740
# (k, beta, rho) = (12.000, 0.110, 0.910) with rmse:12.806
# (k, beta, rho) = (12.000, 0.110, 0.860) with rmse:12.739
# (k, beta, rho) = (12.000, 0.310, 0.960) with rmse:41.754
# (k, beta, rho) = (12.000, 0.310, 0.950) with rmse:57.679
# (k, beta, rho) = (12.000, 0.310, 0.970) with rmse:45.488
# (k, beta, rho) = (12.000, 0.310, 0.910) with rmse:54.854
# (k, beta, rho) = (12.000, 0.310, 0.860) with rmse:47.164
# (k, beta, rho) = (13.000, 0.210, 0.960) with rmse:13.665
# (k, beta, rho) = (13.000, 0.210, 0.950) with rmse:18.634
# (k, beta, rho) = (13.000, 0.210, 0.970) with rmse:13.060
# (k, beta, rho) = (13.000, 0.210, 0.910) with rmse:13.631
# (k, beta, rho) = (13.000, 0.210, 0.860) with rmse:18.921
# (k, beta, rho) = (13.000, 0.200, 0.960) with rmse:15.927
# (k, beta, rho) = (13.000, 0.200, 0.950) with rmse:7.925
# (k, beta, rho) = (13.000, 0.200, 0.970) with rmse:12.855
# (k, beta, rho) = (13.000, 0.200, 0.910) with rmse:9.835
# (k, beta, rho) = (13.000, 0.200, 0.860) with rmse:14.058
# (k, beta, rho) = (13.000, 0.220, 0.960) with rmse:12.344
# (k, beta, rho) = (13.000, 0.220, 0.950) with rmse:19.740
# (k, beta, rho) = (13.000, 0.220, 0.970) with rmse:13.031
# (k, beta, rho) = (13.000, 0.220, 0.910) with rmse:22.498
# (k, beta, rho) = (13.000, 0.220, 0.860) with rmse:11.196
# (k, beta, rho) = (13.000, 0.160, 0.960) with rmse:7.181
# (k, beta, rho) = (13.000, 0.160, 0.950) with rmse:8.411
# (k, beta, rho) = (13.000, 0.160, 0.970) with rmse:8.322
# (k, beta, rho) = (13.000, 0.160, 0.910) with rmse:6.921
# (k, beta, rho) = (13.000, 0.160, 0.860) with rmse:7.870
# (k, beta, rho) = (13.000, 0.260, 0.960) with rmse:29.928
# (k, beta, rho) = (13.000, 0.260, 0.950) with rmse:30.307
# (k, beta, rho) = (13.000, 0.260, 0.970) with rmse:37.610
# (k, beta, rho) = (13.000, 0.260, 0.910) with rmse:21.371
# (k, beta, rho) = (13.000, 0.260, 0.860) with rmse:31.941
# (k, beta, rho) = (13.000, 0.110, 0.960) with rmse:12.505
# (k, beta, rho) = (13.000, 0.110, 0.950) with rmse:12.156
# (k, beta, rho) = (13.000, 0.110, 0.970) with rmse:12.532
# (k, beta, rho) = (13.000, 0.110, 0.910) with rmse:12.712
# (k, beta, rho) = (13.000, 0.110, 0.860) with rmse:12.294
# (k, beta, rho) = (13.000, 0.310, 0.960) with rmse:52.573
# (k, beta, rho) = (13.000, 0.310, 0.950) with rmse:47.791
# (k, beta, rho) = (13.000, 0.310, 0.970) with rmse:47.893
# (k, beta, rho) = (13.000, 0.310, 0.910) with rmse:49.055
# (k, beta, rho) = (13.000, 0.310, 0.860) with rmse:44.266
# Tabu move
# (k, beta, rho)=(11, 0.2, 1.06)TABU
# iteration 13...
# (k, beta, rho) = (10.000, 0.200, 0.960) with rmse:8.170
# (k, beta, rho) = (10.000, 0.190, 0.960) with rmse:6.712
# (k, beta, rho) = (10.000, 0.210, 0.960) with rmse:7.066
# (k, beta, rho) = (10.000, 0.150, 0.960) with rmse:10.976
# (k, beta, rho) = (10.000, 0.250, 0.960) with rmse:9.602
# (k, beta, rho) = (10.000, 0.100, 0.960) with rmse:13.376
# (k, beta, rho) = (10.000, 0.300, 0.960) with rmse:28.926
# (k, beta, rho) = (9.000, 0.200, 0.960) with rmse:10.033
# (k, beta, rho) = (9.000, 0.190, 0.960) with rmse:10.785
# (k, beta, rho) = (9.000, 0.210, 0.960) with rmse:11.790
# (k, beta, rho) = (9.000, 0.150, 0.960) with rmse:12.606
# (k, beta, rho) = (9.000, 0.250, 0.960) with rmse:6.734
# (k, beta, rho) = (9.000, 0.100, 0.960) with rmse:13.521
# (k, beta, rho) = (9.000, 0.300, 0.960) with rmse:11.882
# (k, beta, rho) = (11.000, 0.200, 0.960) with rmse:7.882
# (k, beta, rho) = (11.000, 0.190, 0.960) with rmse:9.404
# (k, beta, rho) = (11.000, 0.210, 0.960) with rmse:6.258
# (k, beta, rho) = (11.000, 0.150, 0.960) with rmse:10.873
# (k, beta, rho) = (11.000, 0.250, 0.960) with rmse:9.971
# (k, beta, rho) = (11.000, 0.100, 0.960) with rmse:13.179
# (k, beta, rho) = (11.000, 0.300, 0.960) with rmse:25.960
# (k, beta, rho) = (12.000, 0.200, 0.960) with rmse:11.082
# (k, beta, rho) = (12.000, 0.190, 0.960) with rmse:8.450
# (k, beta, rho) = (12.000, 0.210, 0.960) with rmse:10.574
# (k, beta, rho) = (12.000, 0.150, 0.960) with rmse:9.056
# (k, beta, rho) = (12.000, 0.250, 0.960) with rmse:23.929
# (k, beta, rho) = (12.000, 0.100, 0.960) with rmse:12.917
# (k, beta, rho) = (12.000, 0.300, 0.960) with rmse:47.768
# (k, beta, rho) = (13.000, 0.200, 0.960) with rmse:6.290
# (k, beta, rho) = (13.000, 0.190, 0.960) with rmse:9.787
# (k, beta, rho) = (13.000, 0.210, 0.960) with rmse:16.325
# (k, beta, rho) = (13.000, 0.150, 0.960) with rmse:8.259
# (k, beta, rho) = (13.000, 0.250, 0.960) with rmse:25.563
# (k, beta, rho) = (13.000, 0.100, 0.960) with rmse:12.386
# (k, beta, rho) = (13.000, 0.300, 0.960) with rmse:40.032
# Tabu move
# (k, beta, rho)=(10, 0.21, 1.07)TABU
# iteration 14...
# (k, beta, rho) = (9.000, 0.210, 0.970) with rmse:10.020
# (k, beta, rho) = (9.000, 0.200, 0.970) with rmse:11.277
# (k, beta, rho) = (9.000, 0.220, 0.970) with rmse:11.227
# (k, beta, rho) = (9.000, 0.160, 0.970) with rmse:12.779
# (k, beta, rho) = (9.000, 0.260, 0.970) with rmse:7.149
# (k, beta, rho) = (9.000, 0.110, 0.970) with rmse:13.456
# (k, beta, rho) = (9.000, 0.310, 0.970) with rmse:12.826
# (k, beta, rho) = (8.000, 0.210, 0.970) with rmse:9.575
# (k, beta, rho) = (8.000, 0.200, 0.970) with rmse:11.028
# (k, beta, rho) = (8.000, 0.220, 0.970) with rmse:11.201
# (k, beta, rho) = (8.000, 0.160, 0.970) with rmse:12.787
# (k, beta, rho) = (8.000, 0.260, 0.970) with rmse:5.833
# (k, beta, rho) = (8.000, 0.110, 0.970) with rmse:13.434
# (k, beta, rho) = (8.000, 0.310, 0.970) with rmse:11.101
# (k, beta, rho) = (10.000, 0.210, 0.970) with rmse:7.080
# (k, beta, rho) = (10.000, 0.200, 0.970) with rmse:8.708
# (k, beta, rho) = (10.000, 0.220, 0.970) with rmse:5.576
# (k, beta, rho) = (10.000, 0.160, 0.970) with rmse:10.391
# (k, beta, rho) = (10.000, 0.260, 0.970) with rmse:9.869
# (k, beta, rho) = (10.000, 0.110, 0.970) with rmse:13.386
# (k, beta, rho) = (10.000, 0.310, 0.970) with rmse:33.606
# (k, beta, rho) = (11.000, 0.210, 0.970) with rmse:6.422
# (k, beta, rho) = (11.000, 0.200, 0.970) with rmse:6.027
# (k, beta, rho) = (11.000, 0.220, 0.970) with rmse:8.019
# (k, beta, rho) = (11.000, 0.160, 0.970) with rmse:11.433
# (k, beta, rho) = (11.000, 0.260, 0.970) with rmse:13.133
# (k, beta, rho) = (11.000, 0.110, 0.970) with rmse:13.395
# (k, beta, rho) = (11.000, 0.310, 0.970) with rmse:27.558
# (k, beta, rho) = (12.000, 0.210, 0.970) with rmse:9.815
# (k, beta, rho) = (12.000, 0.200, 0.970) with rmse:16.273
# (k, beta, rho) = (12.000, 0.220, 0.970) with rmse:13.626
# (k, beta, rho) = (12.000, 0.160, 0.970) with rmse:6.967
# (k, beta, rho) = (12.000, 0.260, 0.970) with rmse:33.795
# (k, beta, rho) = (12.000, 0.110, 0.970) with rmse:12.095
# (k, beta, rho) = (12.000, 0.310, 0.970) with rmse:40.150
# Tabu move
# (k, beta, rho)=(9, 0.22, 1.08)TABU

# %%
# 1) Best paramters (k, beta, rho)
#best_k_beta_rho = best_sol
best_k_beta_rho = best_sol
print("Our best parameters (k, beta, rho) =", best_k_beta_rho)

# 2) Generate a new random graph with the new k 
random_G = nx.newman_watts_strogatz_graph(pandemic["N"], best_k_beta_rho[0], p=0.5, seed = 100)

# 3) Our best simulation
# Increase number of steps to have more stable results
pandemic["n_steps"] = 100

# Simulation loop
simulations = simulate_pandemic(random_G, best_k_beta_rho[1], best_k_beta_rho[2], 
                                pandemic["n_steps"], pandemic["n_weeks"],
                                pandemic["I0"][0], pandemic["n_states"], pandemic["vax_scheme"])
# Out:
# Our best parameters (k, beta, rho) = [12, 0.19, 0.86]

# %% [markdown]
# Once again, we plot the average number of newly infected individuals each week according to the model (with your best parameters) compared to the true value of newly infected individuals each week.

# %%
simulation_week_i = np.zeros([pandemic["n_steps"], pandemic["n_weeks"]])

for i in range(simulations.shape[0]):
    
    cases_i = np.zeros(simulations[i].shape[0])
    
    for case in range(simulations[i].shape[0]):
                
        if case == 0:
            cases_i[case] = int(np.argwhere(simulations[i, case] == 1).shape[0])
        
        else:
            cases_i[case] = int(np.argwhere(((simulations[i, case]==1) & (simulations[i,case-1]<simulations[i,case]) ) ).shape[0]) 
    
    simulation_week_i[i] =  cases_i
    
avg_x_week = np.mean(simulation_week_i ,axis=0)

plt.figure(figsize = (8 ,5))
plt.plot(range(pandemic["n_weeks"]), avg_x_week, label="predicted") 
plt.plot(range(pandemic["n_weeks"]), pandemic["I0"], label = "actual") 
plt.xlabel("week")
plt.ylabel("cases")
plt.grid()
weeks_plot = [x for x in range(42, 53)] + [x for x in range(1,6)]
plt.xticks(range(pandemic["n_weeks"]), weeks_plot)
plt.legend()
plt.savefig("5-2.png", dpi=300, bbox_inches='tight')
plt.show()
